# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '../../..')))
from seq2seq import *
import pandas as pd
import numpy as np
from bilstm_hyp import hyperparametersselection
from sklearn.model_selection import train_test_split 
from sklearn.utils import shuffle
from collections import Counter
import pickle
import torch
from sklearn.preprocessing import StandardScaler

# %%
def set_seeds(seed):
    np.random.seed(seed)

    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# %%
# Convert a string that simulates a list to a real list
def convert_string_list(element):
    # Delete [] of the string
    element = element[0:len(element)]
    # Create a list that contains each code as e.g. 'A'
    ATC_list = list(element.split('; '))
    for index, code in enumerate(ATC_list):
        # Delete '' of the code
        ATC_list[index] = code[0:len(code)]
    return ATC_list

# %%
def multiplicate_rows(df):
    # Duplicate each compound the number of ATC codes associated to it, copying its SMILES in new rows
    new_rows = []
    
    for _, row in df.iterrows():
        atc_codes = row['ATC Codes']
        atc_codes_list = convert_string_list(atc_codes)
        
        if len(atc_codes_list) > 1:
            for code in atc_codes_list:
                if len(code) == 5:
                    new_row = row.copy()
                    new_row['ATC Codes'] = code
                    new_rows.append(new_row)
        else:
            if len(atc_codes_list[0]) == 5:
                new_rows.append(row)
    
    new_set = pd.DataFrame(new_rows)
    new_set = new_set.reset_index(drop=True)

    return new_set

# Create vocabularies
# Tokenize the data
def source(df):
    source = []
    for compound in df['Neutralized SMILES']:
        # A list containing each SMILES character separated
        source.append(list(compound))
    return source
def target(df):
    target = []
    for codes in df['ATC Codes']:  
        code = convert_string_list(codes) 
        # A list of lists, each one containing each ATC code character separated 
        for c in code:
            list_c = list(c)
            target.append(list_c)
    return target

# %%
seeds = [42, 123, 47899, 2025, 1, 20, 99, 1020, 345, 78] 
columns = [
    'Seed', 
    'Precision', 'Recall', 'F1',
    'Precision level 1', 'Precision level 2', 'Precision level 3', 'Precision level 4',
    'Recall level 1', 'Recall level 2', 'Recall level 3', 'Recall level 4',
    '#Compounds that have at least one match'
]
metrics_df = pd.DataFrame(columns=columns)

for seed in seeds:
    set_seeds(seed)

    train_set = pd.read_csv(f'../Datasets/Rep_train_set{seed}.csv')
    test_set = pd.read_csv(f'../Datasets/Rep_test_set{seed}.csv')
    val_set = pd.read_csv(f'../Datasets/Rep_val_set{seed}.csv')
    
    new_train_set = multiplicate_rows(train_set)
    new_val_set = multiplicate_rows(val_set)
    new_test_set = multiplicate_rows(test_set)
    
    source_train = source(new_train_set)
    source_test = source(new_test_set)
    # Test set without duplicated compounds
    source_test2 = source(test_set)
    source_val = source(new_val_set)
    # Val set without duplicated compounds
    source_val2 = source(val_set)
    
    target_train = target(new_train_set)
    target_test = target(new_test_set)
    target_val = target(new_val_set)
    
    # An Index object represents a mapping from the vocabulary to integers (indices) to feed into the models
    source_index = index.Index(source_train)
    target_index = index.Index(target_train)
    
    # Create tensors
    X_train = source_index.text2tensor(source_train)
    y_train = target_index.text2tensor(target_train)
    X_val = source_index.text2tensor(source_val)
    X_val2 = source_index.text2tensor(source_val2)
    y_val = target_index.text2tensor(target_val)     
    X_test = source_index.text2tensor(source_test)
    X_test2 = source_index.text2tensor(source_test2)
    y_test = target_index.text2tensor(target_test)

    if torch.cuda.is_available():
        X_train = X_train.to("cuda")
        y_train = y_train.to("cuda")
        X_val = X_val.to("cuda")
        X_val2 = X_val2.to("cuda")
        y_val = y_val.to("cuda")
        X_test= X_test.to("cuda")
        y_test = y_test.to("cuda")
        X_test2 = X_test2.to("cuda")

    if os.path.exists(f"sortedbilstm_results{seed}.csv"):
        best_hyperparameters = (pd.read_csv(f"sortedbilstm_results{seed}.csv")).loc[0]
    else:
        best_hyperparameters = hyperparametersselection(seed, source_index, target_index, X_train, X_val, X_val2, y_train, y_val)

    model = models.BiLSTM(
                source_index, 
                target_index,
                encoder_embedding_dimension = best_hyperparameters['encoder_embedding_dim'],
                decoder_embedding_dimension = best_hyperparameters['decoder_embedding_dim'],
                encoder_hidden_units = int(best_hyperparameters['enc_hidden_units']), 
                encoder_layers = best_hyperparameters['enc_layers'],
                decoder_hidden_units = int(best_hyperparameters['dec_hidden_units']),
                decoder_layers = best_hyperparameters['dec_layers'],
                dropout = best_hyperparameters['dropout'])   
    model.to("cuda")
    q = model.fit(X_train, 
            y_train,
            X_val, 
            y_val, 
            batch_size = 32, 
            epochs = 150, 
            learning_rate = best_hyperparameters['learning_rate'], 
            weight_decay = best_hyperparameters['weight_decay'],
            progress_bar = 0, 
            save_path = None)
    model.load_state_dict(torch.load("best_model.pth", weights_only=True))
    loss, error_rate = model.evaluate(X_test, y_test, batch_size = 32) 

    predictions, log_probabilities = search_algorithms.beam_search(
        model, 
        X_test2, # Make predictions with test set 
        predictions = 6, # max length of the predicted sequence
        beam_width = 10,
        batch_size = 32, 
        progress_bar = 0
    )
    output_beam = [target_index.tensor2text(p) for p in predictions]

    predictions_clean = []
    for i, preds in enumerate(output_beam):
        smiles = test_set.loc[i, 'Neutralized SMILES']
        interm = []
        for pred in preds:
            clean_pred = pred.replace('<START>', '').replace('<END>', '')
            if len(clean_pred) == 5:
                comp_in_train  = train_set.loc[train_set['Neutralized SMILES'] == smiles, 'ATC Codes']
                if comp_in_train.empty:
                    comp_in_val = val_set.loc[val_set['Neutralized SMILES'] == smiles, 'ATC Codes']
                    if clean_pred not in convert_string_list(val_set.loc[val_set['Neutralized SMILES'] == smiles, 'ATC Codes'].iloc[0]):
                        interm.append(clean_pred)
                else:
                    if clean_pred not in convert_string_list(train_set.loc[train_set['Neutralized SMILES'] == smiles, 'ATC Codes'].iloc[0]):
                        interm.append(clean_pred)
            if len(interm) == 3:
                break
        predictions_clean.append(interm)
    precision_1, precision_2, precision_3, precision_4 = defined_metrics.precision(predictions_clean, f'../Datasets/Rep_test_set{seed}.csv', 'ATC Codes')
    recall_1, recall_2, recall_3, recall_4, counter_compound_match = defined_metrics.recall(predictions_clean, f'../Datasets/Rep_test_set{seed}.csv', 'ATC Codes')
    precisions, recalls, f1s = defined_metrics.complete_metrics(predictions_clean, f'../Datasets/Rep_test_set{seed}.csv', 'ATC Codes', 3)
    precisions_average = sum(precisions)/len(precisions)
    recalls_average = sum(recalls)/len(recalls)
    f1s_average = sum(f1s)/len(f1s)
    
    metrics = {
        'Precision': precisions_average, 
        'Recall': recalls_average,
        'F1': f1s_average,
        'Precision level 1': precision_1,
        'Precision level 2': precision_2,
        'Precision level 3': precision_3,
        'Precision level 4': precision_4,
        'Recall level 1': recall_1,
        'Recall level 2': recall_2,
        'Recall level 3': recall_3,
        'Recall level 4': recall_4,
        '#Compounds that have at least one match': counter_compound_match
    }
    
    # Build the row
    row = {
        'Seed': seed,
        **metrics
    }
    
    metrics_df = pd.concat([metrics_df, pd.DataFrame([row])], ignore_index=True)

    torch.cuda.empty_cache()

metrics_df.to_csv("bilstm_metrics.csv", index=False)
print("Mean:", metrics_df.mean(numeric_only=True))
print("Std:", metrics_df.std(numeric_only=True))
# Out:
# Model: Seq2Seq Bi-LSTM
# Source index: <Seq2Seq Index with 46 items>
# Target index: <Seq2Seq Index with 34 items>
# Encoder embedding dimension: 128
# Decoder embedding dimension: 128
# Encoder hidden units: 128
# Encoder layers: 2
# Decoder hidden units: 128
# Decoder layers: 2
# Dropout: 0.0
# Trainable parameters: 1,069,346
#
# Training started
# X_train.shape: torch.Size([3024, 702])
# Y_train.shape: torch.Size([3024, 7])
# X_dev.shape: torch.Size([538, 295])
# Y_dev.shape: torch.Size([538, 7])
# Epochs: 150
# Learning rate: 0.001
# Weight decay: 1e-05
# Epoch | Train                 | Development           | Minutes
#       | Loss     | Error Rate | Loss     | Error Rate |
# ---------------------------------------------------------------
#     1 |   2.0681 |     56.294 |   1.5027 |     46.097 |     0.0
#     2 |   1.4036 |     45.569 |   1.3538 |     46.004 |     0.1
#     3 |   1.3164 |     44.466 |   1.2979 |     43.897 |     0.1
#     4 |   1.2681 |     43.634 |   1.2587 |     43.587 |     0.2
#     5 |   1.2368 |     43.094 |   1.2327 |     42.441 |     0.2
#     6 |   1.2088 |     42.323 |   1.2090 |     42.937 |     0.2
#     7 |   1.1762 |     41.474 |   1.1807 |     41.233 |     0.3
#     8 |   1.1452 |     40.074 |   1.1455 |     39.932 |     0.3
#     9 |   1.1054 |     38.106 |   1.1238 |     39.374 |     0.3
#    10 |   1.0668 |     36.491 |   1.0887 |     38.011 |     0.4
#    11 |   1.0223 |     34.177 |   1.0495 |     35.812 |     0.4
#    12 |   0.9709 |     32.512 |   1.0288 |     36.059 |     0.5
#    13 |   0.9201 |     30.379 |   1.0037 |     34.542 |     0.5
#    14 |   0.8726 |     28.853 |   0.9706 |     32.931 |     0.5
#    15 |   0.8232 |     26.857 |   0.9478 |     32.001 |     0.6
#    16 |   0.7717 |     24.956 |   0.9356 |     30.514 |     0.6
#    17 |   0.7158 |     22.928 |   0.9245 |     29.616 |     0.6
#    18 |   0.6654 |     20.955 |   0.9149 |     29.926 |     0.7
#    19 |   0.6226 |     19.703 |   0.9043 |     29.089 |     0.7
#    20 |   0.5786 |     18.430 |   0.8937 |     28.222 |     0.8
#    21 |   0.5363 |     16.970 |   0.9007 |     27.757 |     0.8
#    22 |   0.4901 |     15.399 |   0.8939 |     27.292 |     0.8
#    23 |   0.4522 |     13.878 |   0.9061 |     27.014 |     0.9
#    24 |   0.4131 |     12.693 |   0.8938 |     25.682 |     0.9
# Early stopping
# C:\Users\trini\AppData\Local\Temp\ipykernel_144664\896121616.py:143: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   metrics_df = pd.concat([metrics_df, pd.DataFrame([row])], ignore_index=True)
# Model: Seq2Seq Bi-LSTM
# Source index: <Seq2Seq Index with 45 items>
# Target index: <Seq2Seq Index with 34 items>
# Encoder embedding dimension: 128
# Decoder embedding dimension: 128
# Encoder hidden units: 128
# Encoder layers: 4
# Decoder hidden units: 128
# Decoder layers: 2
# Dropout: 0.0
# Trainable parameters: 1,990,818
#
# Training started
# X_train.shape: torch.Size([3028, 649])
# Y_train.shape: torch.Size([3028, 7])
# X_dev.shape: torch.Size([534, 702])
# Y_dev.shape: torch.Size([534, 7])
# Epochs: 150
# Learning rate: 0.001
# Weight decay: 1e-05
# Epoch | Train                 | Development           | Minutes
#       | Loss     | Error Rate | Loss     | Error Rate |
# ---------------------------------------------------------------
#     1 |   2.0175 |     55.262 |   1.4916 |     45.350 |     0.1
#     2 |   1.4102 |     45.839 |   1.3426 |     44.507 |     0.1
#     3 |   1.3288 |     44.920 |   1.3006 |     43.883 |     0.2
#     4 |   1.2907 |     44.166 |   1.2610 |     43.227 |     0.3
#     5 |   1.2560 |     43.456 |   1.2388 |     42.478 |     0.4
#     6 |   1.2232 |     42.641 |   1.2105 |     41.916 |     0.4
#     7 |   1.1902 |     41.606 |   1.1775 |     40.793 |     0.5
#     8 |   1.1576 |     40.494 |   1.1529 |     40.543 |     0.6
#     9 |   1.1205 |     39.080 |   1.1173 |     38.577 |     0.7
#    10 |   1.0751 |     37.489 |   1.0781 |     36.735 |     0.7
#    11 |   1.0204 |     34.935 |   1.0501 |     35.456 |     0.8
#    12 |   0.9671 |     32.612 |   1.0149 |     33.739 |     0.9
#    13 |   0.9123 |     30.526 |   0.9928 |     33.458 |     1.0
#    14 |   0.8596 |     28.567 |   0.9753 |     32.303 |     1.0
#    15 |   0.8055 |     26.701 |   0.9501 |     31.617 |     1.1
#    16 |   0.7501 |     24.367 |   0.9306 |     30.275 |     1.2
#    17 |   0.6892 |     22.055 |   0.9015 |     29.494 |     1.2
#    18 |   0.6326 |     19.942 |   0.9146 |     28.308 |     1.3
#    19 |   0.5754 |     18.043 |   0.9165 |     28.839 |     1.4
#    20 |   0.5361 |     16.634 |   0.9250 |     27.965 |     1.5
#    21 |   0.4882 |     15.181 |   0.8965 |     26.748 |     1.5
#    22 |   0.4340 |     13.287 |   0.9149 |     27.403 |     1.6
#    23 |   0.3948 |     12.098 |   0.9692 |     27.341 |     1.7
#    24 |   0.3519 |     10.755 |   0.9682 |     26.529 |     1.8
#    25 |   0.3139 |      9.500 |   0.9851 |     27.060 |     1.8
# Early stopping
#
# Model: Seq2Seq Bi-LSTM
# Source index: <Seq2Seq Index with 44 items>
# Target index: <Seq2Seq Index with 34 items>
# Encoder embedding dimension: 64
# Decoder embedding dimension: 64
# Encoder hidden units: 128
# Encoder layers: 3
# Decoder hidden units: 128
# Decoder layers: 2
# Dropout: 0.0
# Trainable parameters: 1,426,594
#
# Training started
# X_train.shape: torch.Size([3021, 702])
# Y_train.shape: torch.Size([3021, 7])
# X_dev.shape: torch.Size([541, 250])
# Y_dev.shape: torch.Size([541, 7])
# Epochs: 150
# Learning rate: 0.001
# Weight decay: 1e-05
# Epoch | Train                 | Development           | Minutes
#       | Loss     | Error Rate | Loss     | Error Rate |
# ---------------------------------------------------------------
#     1 |   2.0498 |     55.440 |   1.5062 |     45.779 |     0.1
#     2 |   1.4291 |     45.724 |   1.3881 |     45.625 |     0.1
#     3 |   1.3576 |     45.393 |   1.3378 |     45.256 |     0.2
#     4 |   1.3182 |     44.969 |   1.3076 |     45.410 |     0.2
#     5 |   1.2875 |     44.124 |   1.2883 |     44.085 |     0.3
#     6 |   1.2642 |     43.518 |   1.2575 |     43.746 |     0.3
#     7 |   1.2348 |     42.944 |   1.2425 |     43.407 |     0.4
#     8 |   1.2068 |     42.166 |   1.2093 |     42.144 |     0.4
#     9 |   1.1727 |     40.892 |   1.1890 |     41.004 |     0.5
#    10 |   1.1443 |     40.014 |   1.1666 |     40.881 |     0.6
#    11 |   1.1102 |     38.425 |   1.1511 |     40.173 |     0.6
#    12 |   1.0781 |     37.383 |   1.1282 |     37.985 |     0.7
#    13 |   1.0400 |     35.452 |   1.0843 |     37.184 |     0.7
#    14 |   0.9995 |     34.040 |   1.0694 |     35.767 |     0.8
#    15 |   0.9531 |     31.949 |   1.0466 |     35.089 |     0.8
#    16 |   0.9012 |     30.200 |   1.0046 |     33.487 |     0.9
#    17 |   0.8604 |     28.578 |   1.0027 |     33.241 |     1.0
#    18 |   0.8015 |     26.090 |   0.9790 |     32.132 |     1.0
#    19 |   0.7504 |     24.236 |   0.9856 |     31.608 |     1.1
#    20 |   0.7010 |     22.636 |   0.9766 |     31.392 |     1.1
#    21 |   0.6536 |     20.606 |   0.9717 |     31.023 |     1.2
#    22 |   0.5974 |     18.708 |   0.9837 |     30.930 |     1.2
#    23 |   0.5609 |     17.731 |   0.9679 |     30.099 |     1.3
#    24 |   0.5151 |     15.773 |   0.9747 |     28.835 |     1.4
#    25 |   0.4699 |     14.581 |   1.0074 |     29.082 |     1.4
#    26 |   0.4240 |     13.031 |   1.0276 |     29.513 |     1.5
#    27 |   0.3848 |     11.387 |   1.0332 |     28.096 |     1.5
# Early stopping
#
# Model: Seq2Seq Bi-LSTM
# Source index: <Seq2Seq Index with 43 items>
# Target index: <Seq2Seq Index with 34 items>
# Encoder embedding dimension: 128
# Decoder embedding dimension: 128
# Encoder hidden units: 128
# Encoder layers: 3
# Decoder hidden units: 128
# Decoder layers: 2
# Dropout: 0.1
# Trainable parameters: 1,529,762
#
# Training started
# X_train.shape: torch.Size([3042, 702])
# Y_train.shape: torch.Size([3042, 7])
# X_dev.shape: torch.Size([520, 467])
# Y_dev.shape: torch.Size([520, 7])
# Epochs: 150
# Learning rate: 0.001
# Weight decay: 0.0001
# Epoch | Train                 | Development           | Minutes
#       | Loss     | Error Rate | Loss     | Error Rate |
# ---------------------------------------------------------------
#     1 |   2.
#    34 |   0.6111 |     20.244 |   0.9276 |     29.364 |     2.0
#    35 |   0.5786 |     19.167 |   0.9314 |     28.418 |     2.1
#    36 |   0.5510 |     17.909 |   0.9168 |     28.418 |     2.2
#    37 |   0.5315 |     17.447 |   0.9281 |     27.694 |     2.2
#    38 |   0.5082 |     16.469 |   0.9180 |     27.032 |     2.3
#    39 |   0.4931 |     15.787 |   0.9330 |     27.568 |     2.3
#    40 |   0.4725 |     15.370 |   0.9304 |     26.906 |     2.4
# Early stopping
#
# Model: Seq2Seq Bi-LSTM
# Source index: <Seq2Seq Index with 46 items>
# Target index: <Seq2Seq Index with 34 items>
# Encoder embedding dimension: 64
# Decoder embedding dimension: 128
# Encoder hidden units: 128
# Encoder layers: 3
# Decoder hidden units: 128
# Decoder layers: 2
# Dropout: 0.1
# Trainable parameters: 1,461,666
#
# Training started
# X_train.shape: torch.Size([3017, 702])
# Y_train.shape: torch.Size([3017, 7])
# X_dev.shape: torch.Size([545, 323])
# Y_dev.shape: torch.Size([545, 7])
# Epochs: 150
# Learning rate: 0.001
# Weight decay: 1e-05
# Epoch | Train                 | Development           | Minutes
#       | Loss     | Error Rate | Loss     | Error Rate |
# ---------------------------------------------------------------
#     1 |   2.0539 |     56.629 |   1.5018 |     45.841 |     0.1
#     2 |   1.4238 |     46.072 |   1.3519 |     45.229 |     0.1
#     3 |   1.3391 |     45.161 |   1.3187 |     44.740 |     0.2
#     4 |   1.2970 |     44.244 |   1.2777 |     44.006 |     0.2
#     5 |   1.2637 |     43.686 |   1.2550 |     43.333 |     0.3
#     6 |   1.2332 |     42.907 |   1.2306 |     42.936 |     0.4
#     7 |   1.2077 |     42.040 |   1.2069 |     42.202 |     0.4
#     8 |   1.1811 |     41.244 |   1.1999 |     41.070 |     0.5
#     9 |   1.1532 |     40.211 |   1.1681 |     40.092 |     0.5
#    10 |   1.1249 |     38.935 |   1.1440 |     39.021 |     0.6
#    11 |   1.0894 |     37.814 |   1.1268 |     38.226 |     0.7
#    12 |   1.0560 |     36.698 |   1.0931 |     37.003 |     0.7
#    13 |   1.0191 |     35.366 |   1.0825 |     37.064 |     0.8
#    14 |   0.9858 |     34.040 |   1.0640 |     35.719 |     0.8
#    15 |   0.9504 |     32.129 |   1.0295 |     35.168 |     0.9
#    16 |   0.9019 |     30.107 |   1.0041 |     33.884 |     1.0
#    17 |   0.8498 |     28.179 |   0.9969 |     33.486 |     1.0
#    18 |   0.8074 |     26.870 |   0.9727 |     32.141 |     1.1
#    19 |   0.7583 |     24.677 |   0.9530 |     31.284 |     1.1
#    20 |   0.7191 |     23.285 |   0.9442 |     30.703 |     1.2
#    21 |   0.6654 |     21.268 |   0.9435 |     30.092 |     1.3
#    22 |   0.6169 |     19.655 |   0.9361 |     29.205 |     1.3
#    23 |   0.5799 |     18.534 |   0.9167 |     29.633 |     1.4
#    24 |   0.5382 |     17.291 |   0.9229 |     28.318 |     1.4
#    25 |   0.4993 |     15.634 |   0.9109 |     28.777 |     1.5
#    26 |   0.4565 |     14.540 |   0.9324 |     28.685 |     1.6
#    27 |   0.4311 |     13.413 |   0.9205 |     28.073 |     1.6
#    28 |   0.4041 |     12.855 |   0.9344 |     27.584 |     1.7
#    29 |   0.3650 |     11.662 |   0.9626 |     27.523 |     1.7
# Early stopping
#
# Mean: Precision            0.134604
# Recall               0.345235
# F1                   0.188261
# Precision level 1    0.429566
# Precision level 2    0.734906
# Precision level 3    0.757185
# Precision level 4    0.690167
# Recall level 1       0.625883
# Recall level 2       0.821212
# Recall level 3       0.837622
# Recall level 4       0.795818
# dtype: float64
# Std: Precision            0.012379
# Recall               0.032864
# F1                   0.017453
# Precision level 1    0.036201
# Precision level 2    0.019750
# Precision level 3    0.019011
# Precision level 4    0.022599
# Recall level 1       0.040088
# Recall level 2       0.025465
# Recall level 3       0.010193
# Recall level 4       0.021418
# dtype: float64

# %%
predictions_clean
# Out:
# [['L02AX', 'B01AC', 'J05AX'],
#  ['L01XX', 'L01XE', 'L01EX'],
#  ['L01AD', 'L01XA', 'P01AX'],
#  ['M05BB', 'L01XX', 'D05BX'],
#  ['R03DA', 'C01EA', 'C01DA'],
#  ['M05BX', 'B05AX', 'A16AX'],
#  ['L01BA', 'J01MA', 'P01BA'],
#  ['D11AH', 'M05BB', 'D05AX'],
#  ['A16AX', 'A10BB', 'M01AX'],
#  ['A11CC', 'B05AX', 'A16AX'],
#  ['A10BX', 'A11HA', 'B01AC'],
#  ['C09CA', 'C09DB', 'C08CA'],
#  ['C09AA', 'C09BA', 'C08CA'],
#  ['D07AC', 'D07AB', 'S01BA'],
#  ['L02AE', 'B01AE', 'L04AE'],
#  ['N07XX', 'N02AX', 'N06DA'],
#  ['L01BB', 'D06BB', 'L01BC'],
#  ['C07AB', 'C07FX', 'C07BB'],
#  ['P02CA', 'B01AC', 'L02BC'],
#  ['J01FA', 'A02BD', 'D01AA'],
#  ['R03DA', 'C01DA', 'C01CA'],
#  ['J01DB', 'J01DD', 'J01CE'],
#  ['M01AX', 'C01DX', 'M01AH'],
#  ['C02AA', 'L01XX', 'L01CD'],
#  ['A02BD', 'D01AA', 'P01BF'],
#  ['A02BA', 'C10AD', 'A04AA'],
#  ['A03AD', 'B01AC', 'A10BB'],
#  ['C03BA', 'C02CA', 'P01CX'],
#  ['P01AB', 'S01AE', 'L01XD'],
#  ['R03AC', 'A08AA', 'C01CA'],
#  ['A10BB', 'B01AA', 'A16AX'],
#  ['C10BA', 'A10BX', 'A11HA'],
#  ['P01AX', 'L01XA', 'M01AE'],
#  ['L01EX', 'L01XE', 'L01EA'],
#  ['D01AC', 'D01AE', 'L01XX'],
#  ['D07XB', 'D07AC', 'H02AB'],
#  ['J05AB', 'L01BC', 'P01BB'],
#  ['A03AA', 'G03CA', 'A03FA'],
#  ['L01BC', 'S01AD', 'C01EB'],
#  ['G01AE', 'D06BA', 'J01EC'],
#  ['L01AA', 'S01AA', 'D01AA'],
#  ['L02BA', 'M02AA', 'C03DA'],
#  ['L01XX', 'N02AX', 'R01AA'],
#  ['G01AE', 'S01AB', 'J01EC'],
#  ['J01ED', 'J01EB', 'J01EC'],
#  ['C07BB', 'C07XB', 'C04AX'],
#  ['J01DC', 'J01DE', 'J01DI'],
#  ['S01BA', 'J01CA', 'D07AB'],
#  ['C09CA', 'C08CA', 'C01CA'],
#  ['R03DA', 'C01DA', 'C01CA'],
#  ['P01BA', 'N01BA', 'R05DB'],
#  ['R06AX', 'N02CC', 'S01GX'],
#  ['C01AA', 'C01AB', 'S01BA'],
#  ['N03AA', 'A02BA', 'A06AD'],
#  ['D06BB', 'L01BC', 'S01AD'],
#  ['J05AX', 'J01CA', 'J05AH'],
#  ['J01CF', 'J01CE', 'J01DF'],
#  ['G03DC', 'G03FA', 'G03AC'],
#  ['L01XX', 'L02BA', 'L04AA'],
#  ['G01AE', 'C02CC', 'S01AE'],
#  ['N05CA', 'N01AF', 'R05DB'],
#  ['M01AH', 'M01AX', 'M02AA'],
#  ['L01EX', 'L01EN', 'L01EK'],
#  ['N07XX', 'N06DA', 'N02AX'],
#  ['J01DC', 'J01DD', 'J01MA'],
#  ['R06AA', 'N04AA', 'N05AX'],
#  ['G03DB', 'L02AB', 'G03FB'],
#  ['N02AA', 'A07DA', 'N03AA'],
#  ['M01AB', 'B01AC', 'M02AA'],
#  ['L01XX', 'G01AX', 'B01AX'],
#  ['A07AA', 'B05CA', 'A10BB'],
#  ['R03BB', 'C01CA', 'R03AB'],
#  ['N01AX', 'N02AG', 'N02AJ'],
#  ['C07FX', 'C07CA', 'C07BA'],
#  ['D08AE', 'C02CC', 'D08AX'],
#  ['A02BC', 'A10BB', 'G04CA'],
#  ['L04AX', 'L02BA', 'L01XX'],
#  ['R06AE', 'R06AX', 'N05AE'],
#  ['L01CB', 'L01CA', 'B01AC'],
#  ['S01AA', 'L01DC', 'D16AX'],
#  ['A10BX', 'A10BJ', 'A10BG'],
#  ['L01EX', 'L01XX', 'L01XE'],
#  ['D06BA', 'J01EB', 'S01AB'],
#  ['G03DC', 'G03FA', 'G03AA'],
#  ['N03AX', 'M03BA', 'N05CM'],
#  ['R03CC', 'C04AA', 'C07CA'],
#  ['G03AC', 'G03AA', 'G03AD'],
#  ['C09BB', 'C07FB', 'C07AB'],
#  ['A03EA', 'L01XE', 'L01EE'],
#  ['N06BA', 'R01CA', 'C01CA'],
#  ['S01BA', 'H02AB', 'H02AA'],
#  ['G03DB', 'G03FB', 'G03AC'],
#  ['L01XE', 'L01XK', 'L01XX'],
#  ['M05BA', 'A16AX', 'A12AA'],
#  ['L01XD', 'L01XX', 'L02BA'],
#  ['L01AX', 'D01AX', 'D01AE'],
#  ['D06BX', 'A11DA', 'H05BA'],
#  ['A03AB', 'A08AB', 'A08AA'],
#  ['A03AA', 'D01AE', 'A10BD'],
#  ['P01CC', 'S01AB', 'C03CA'],
#  ['J01CA', 'J01CE', 'J01CG'],
#  ['J01CA', 'J01CE', 'J01CG'],
#  ['N05CB', 'M01AA', 'R05DA'],
#  ['S01FA', 'A03AB', 'A03BB'],
#  ['A16AX', 'L01AD', 'A16AA'],
#  ['J05AB', 'D06BB', 'L01BC'],
#  ['G01AE', 'C03BA', 'C03AB'],
#  ['S01AX', 'P01CX', 'L01EA'],
#  ['D07XB', 'D07AC', 'D07AB'],
#  ['D01AA', 'J01CA', 'L01AA'],
#  ['A03AC', 'A02CA', 'A10BB'],
#  ['J01GB', 'A07AA', 'D06AX'],
#  ['N02AX', 'A03AX', 'A08AA'],
#  ['C02KX', 'C02CA', 'L01EX'],
#  ['N02BX', 'N07XX', 'M01AA'],
#  ['N02AC', 'N03AG', 'M08AA'],
#  ['N06BA', 'N06AA', 'N02BC'],
#  ['M05CA', 'R05CA', 'R05DB'],
#  ['A07AA', 'S01AA', 'H01AB'],
#  ['P03AX', 'P01AX', 'P02CA'],
#  ['D08AX', 'L01XX', 'G01AC'],
#  ['J01DC', 'J01DI', 'J01CE'],
#  ['R03CB', 'C07AB', 'C07FX'],
#  ['C09AA', 'C09BB', 'C08CA'],
#  ['J05AP', 'L01XX', 'L04AA'],
#  ['N07XX', 'N02AX', 'N06DA'],
#  ['M01AG', 'N01BB', 'M01AX'],
#  ['J01MA', 'L01XX', 'J01MB'],
#  ['A16AA', 'A10BD', 'A16AX'],
#  ['N02AX', 'N07XX', 'N07AX'],
#  ['C09BX', 'C09AA', 'C09BA'],
#  ['R03CC', 'S01ED', 'C04AA'],
#  ['A11CA', 'B01AC', 'M05BB'],
#  ['C02AC', 'C03CA', 'C03XA'],
#  ['N01BH', 'N02AX', 'R05DB'],
#  ['C08CA', 'C07FB', 'C10BX'],
#  ['J01MA', 'L01ED', 'P01CX'],
#  ['N07XX', 'P01CA', 'M01CA'],
#  ['C09AA', 'C09BX', 'C08CA'],
#  ['D07XB', 'H02AB', 'D07BC'],
#  ['A16AX', 'M02AX', 'B01AA'],
#  ['M01AC', 'M03BA', 'D01AC'],
#  ['P01CX', 'L01EX', 'L01EK'],
#  ['L01XX', 'L01XK', 'L01XE'],
#  ['R03CB', 'C07AB', 'C07CA'],
#  ['A03BA', 'A03AB', 'A03BB'],
#  ['A08AA', 'R03CB', 'N02BC'],
#  ['C02AC', 'S01EA', 'C01CA'],
#  ['J01ED', 'J01EC', 'G01AE'],
#  ['J01CA', 'J01CE', 'J01CG'],
#  ['M01AX', 'P03AX', 'L01XX'],
#  ['C09AA', 'C09BX', 'C08CA'],
#  ['P03AX', 'N02BG', 'M03BA'],
#  ['A03FA', 'A03AA', 'B01AC'],
#  ['C02KX', 'G04CA', 'C04AX'],
#  ['D07AB', 'R03BA', 'H02AB'],
#  ['A01AB', 'S01AA', 'A02BD'],
#  ['D07XB', 'H02AB', 'D07AB'],
#  ['C04AA', 'C04AX', 'R03CC'],
#  ['N05CB', 'R05DB', 'M01AA'],
#  ['G03DB', 'G03AB', 'G03BA'],
#  ['C03AA', 'C03BA', 'C03EA'],
#  ['J05AJ', 'J01CA', 'J05AP'],
#  ['P01BA', 'N01BA', 'P01AA'],
#  ['C07AB', 'C07BB', 'R03CB'],
#  ['N01BA', 'R05DB', 'L01BA'],
#  ['J04AM', 'A07AA', 'S02AA'],
#  ['A01AB', 'S01AA', 'G01AA'],
#  ['L01EX', 'P01BA', 'L01XA'],
#  ['A14AA', 'A07EA', 'D07XA'],
#  ['G03AA', 'G03DC', 'G03AC'],
#  ['L01XA', 'L01DB', 'L01AD'],
#  ['L01XX', 'B01AE', 'L01AX'],
#  ['M04AC', 'A16AX', 'M02AA'],
#  ['P01CB', 'B05BB', 'B05BA'],
#  ['J01ED', 'G01AF', 'D10AF'],
#  ['A14AA', 'H02AB', 'D07CA'],
#  ['A10BX', 'C10AA', 'C10AB'],
#  ['N02AX', 'C01BD', 'R02AA'],
#  ['A02BD', 'J01FA', 'A01AB'],
#  ['L01DC', 'J05AH', 'J05AX'],
#  ['C01DA', 'C01CA', 'N06BB'],
#  ['G03AA', 'G03BA', 'G03CA'],
#  ['C08DA', 'R05DA', 'C04AX'],
#  ['D07AC', 'H02AB', 'D07BC'],
#  ['J01ED', 'S01AB', 'J01EE'],
#  ['C01CA', 'A08AA', 'R03CA'],
#  ['C02CC', 'C03BA', 'C02CA'],
#  ['J01DC', 'J01DB', 'L01XD'],
#  ['G01AF', 'G04BB', 'G01AE'],
#  ['C09CA', 'C01BD', 'C09DX'],
#  ['D01AA', 'G01AA', 'A02BD'],
#  ['A07AA', 'S01AA', 'J01GA'],
#  ['J05AB', 'L01AD', 'D06BB'],
#  ['G03AA', 'G03DC', 'G03AC'],
#  ['C09BB', 'C09BX', 'C09BA'],
#  ['L01DB', 'L01XD', 'J05AP'],
#  ['C03BA', 'C03BB', 'L01XX'],
#  ['G01AE', 'P01CD', 'G01AB'],
#  ['N06BX', 'A16AX', 'R03BB'],
#  ['C04AA', 'C04AX', 'C07AA'],
#  ['L01BC', 'D06BB', 'J05AH'],
#  ['C01DA', 'P01AB', 'B01AC'],
#  ['N02BA', 'P01AX', 'N03AX'],
#  ['J05AF', 'J01CE', 'G01AF'],
#  ['R06AX', 'D01AC', 'S01GX'],
#  ['C10AX', 'A11HA', 'M01CC'],
#  ['G03FA', 'G03AA', 'G03BA'],
#  ['P01BA', 'M01AA', 'R05DB'],
#  ['C08CA', 'C01BA', 'C09BX'],
#  ['A03CA', 'A03AB', 'A03CB'],
#  ['S01AA', 'L01AA', 'A01AB'],
#  ['R01AA', 'G01AC', 'R01AB'],
#  ['A02BC', 'B01AC', 'A03AD'],
#  ['J01CA', 'J01CE', 'J01CG'],
#  ['G03AA', 'G03DC', 'A14AA'],
#  ['B05CX', 'A16AX', 'A11HA'],
#  ['A03CB', 'A03BA', 'A03AB'],
#  ['C02CC', 'D08AC', 'C02DC'],
#  ['A11CA', 'D11AH', 'B01AC'],
#  ['S01AA', 'G01AA', 'D06AA'],
#  ['N05CM', 'N05CH', 'N05CB'],
#  ['N06AA', 'N05AA', 'N05AX'],
#  ['G02AD', 'B01AC', 'A02BB'],
#  ['C03AB', 'C03AX', 'C03EA'],
#  ['A03AA', 'R03AB', 'A02BB'],
#  ['G03CC', 'G03BA', 'G03CB'],
#  ['D06BB', 'L01BC', 'C01EB'],
#  ['M01AX', 'N02AX', 'P02CA'],
#  ['C01CA', 'C01BB', 'C01BA'],
#  ['N06AC', 'D04AA', 'R05DB'],
#  ['N05CA', 'N03AB', 'N03AA'],
#  ['P01CA', 'L01XX', 'J04AK'],
#  ['R01AB', 'R01AA', 'R02AA'],
#  ['N07CA', 'N07BC', 'N07CB'],
#  ['C03BA', 'J01MA', 'P01CC'],
#  ['C01EB', 'C01DB', 'L01BC'],
#  ['M01AA', 'P02CA', 'N02AA'],
#  ['N01AB', 'N02AC', 'N02AD'],
#  ['M01AX', 'P01BB', 'N02BX'],
#  ['R03AB', 'C01CA', 'C03CA'],
#  ['S01EC', 'G01AB', 'G01AF'],
#  ['N05CD', 'N05CA', 'N05CC'],
#  ['M03AA', 'N07CA', 'L03AA'],
#  ['J01FA', 'J01XX', 'J01XF'],
#  ['A10BX', 'S01AA', 'A06AX'],
#  ['G01AE', 'A11HA', 'G04BX'],
#  ['D07AB', 'R03BA', 'S01BA'],
#  ['M05BA', 'D11AX', 'B05BA'],
#  ['N05CA', 'N05CD', 'N03AA'],
#  ['A03AA', 'D01AC', 'D01CC'],
#  ['A14AA', 'G03AA', 'G03CA'],
#  ['B01AC', 'L02AX', 'J05AX'],
#  ['L01CC', 'G01AF', 'C02CA'],
#  ['N03AX', 'R03AC', 'M03CC'],
#  ['C09DB', 'C08CA', 'C01CA'],
#  ['L01EG', 'L01XG', 'L02AX'],
#  ['D11AX', 'A10BA', 'L01CX'],
#  ['D06BB', 'L01BC', 'J05AB'],
#  ['G01AE', 'C03AB', 'C03AX'],
#  ['C09BB', 'C09BA', 'C09BX'],
#  ['S01AA', 'R01AB', 'L01AB'],
#  ['A16AX', 'A12AA', 'N05CM'],
#  ['C03BA', 'C03DA', 'C03BB'],
#  ['M01AB', 'L02BA', 'D01AC'],
#  ['D06BA', 'J01EC', 'J01EB'],
#  ['N01BB', 'N01BH', 'C01BD'],
#  ['D07AC', 'S01BA', 'G03DA'],
#  ['N02AE', 'N02AX', 'N02CX'],
#  ['C03AA', 'C03AB', 'C03AX'],
#  ['L01AX', 'J01MA', 'A10BB'],
#  ['J05AP', 'B01AF', 'J05AX'],
#  ['C02CC', 'S01AX', 'D08AC'],
#  ['L01XX', 'L04AX', 'L01XD'],
#  ['R05DB', 'D01AC', 'R06AX'],
#  ['N07XX', 'N07BC', 'M03BA'],
#  ['B01AC', 'J02AX', 'A10BD'],
#  ['R01AB', 'R01AD', 'N01BB'],
#  ['M04AC', 'A16AX', 'C10AD'],
#  ['R03AK', 'C07AA', 'C04AX'],
#  ['M01AX', 'N01BB', 'N05CM'],
#  ['M01AX', 'M02AA', 'P03BA'],
#  ['J01CA', 'J01CE', 'J01CG'],
#  ['S01CC', 'D01AE', 'P02CA'],
#  ['A07AA', 'S01AA', 'J01CG'],
#  ['N07XX', 'N06DA', 'N02AX'],
#  ['G03DC', 'G03AC', 'G03AB'],
#  ['D07XB', 'D07AC', 'D07AB'],
#  ['C07AB', 'R03CB', 'C07BA'],
#  ['C09CA', 'C08CA', 'C09DA'],
#  ['D01AC', 'R05DB', 'R06AX'],
#  ['C10AD', 'A16AX', 'M01AB'],
#  ['G03DC', 'G03FA', 'G03AC'],
#  ['P01CX', 'L01EX', 'S01AE'],
#  ['A11CA', 'D11AH', 'L01XF'],
#  ['R03AC', 'N07XX', 'C01CA'],
#  ['A03CA', 'R03AB', 'A03BB'],
#  ['J05AF', 'P01BC', 'L01BB'],
#  ['N03AC', 'N03AB', 'N02CC'],
#  ['C03AA', 'C03AB', 'C03AG'],
#  ['N03AX', 'R03AC', 'C04AX'],
#  ['R03XA', 'N07XX', 'R03AC'],
#  ['D06BB', 'L01BC', 'S01AD'],
#  ['D01AC', 'S02AA', 'L01XX'],
#  ['N02BA', 'N03AX', 'M02AA'],
#  ['J01ED', 'S01AB', 'J01EB'],
#  ['S01AA', 'G01AA', 'J01AB'],
#  ['C03AB', 'C03BA', 'C03EA'],
#  ['C09BX', 'C09DB', 'C09DX'],
#  ['L01XX', 'P01BC', 'L02BB'],
#  ['J01MA', 'G01AE', 'D10AF'],
#  ['C09CA', 'C08CA', 'C09DA'],
#  ['L01CA', 'L01CX', 'L01CC'],
#  ['N01BB', 'M01AB', 'P01BB'],
#  ['L01BC', 'J04AB', 'L01BA'],
#  ['C10BA', 'C10AA', 'C10AD'],
#  ['N05CA', 'R05CA', 'N05CB'],
#  ['J01MA', 'P01AF', 'G01AF'],
#  ['A07AA', 'J04AB', 'S02AA'],
#  ['H02AA', 'S01BA', 'D07CB'],
#  ['L01DC', 'D11AX', 'L01XX'],
#  ['M02AA', 'D01AE', 'R07AX'],
#  ['J01CA', 'J01CG', 'S01AA'],
#  ['C09DB', 'C07FB', 'C09BX'],
#  ['J01MA', 'J01MB', 'P01CX'],
#  ['J01CR', 'J01CE', 'J01CG'],
#  ['J01CA', 'J01CE', 'J01CG'],
#  ['C01CA', 'C03CA', 'C04AX'],
#  ['N06AA', 'R05DB', 'N06AX'],
#  ['J05AP', 'L01XX', 'J05AJ'],
#  ['N06AA', 'N06AX', 'R06AB'],
#  ['C10AB', 'C10AX', 'C10AD'],
#  ['P01CB', 'A05BB', 'P01BB'],
#  ['J01GB', 'A07AA', 'S01AA'],
#  ['N07XX', 'N06AX', 'N03AX'],
#  ['M02AA', 'P02CA', 'B01AC'],
#  ['L01XX', 'L01CD', 'C01BA'],
#  ['L01EX', 'L01XX', 'P02CA'],
#  ['G01AX', 'A10BD', 'J01MA'],
#  ['G01AE', 'S01AE', 'S01BC'],
#  ['L01CA', 'C01BA', 'L04AA'],
#  ['L01XX', 'D01AE', 'D01AF'],
#  ['J01DD', 'J01DE', 'J01DI'],
#  ['A02BC', 'D01AE', 'A10BB'],
#  ['C09BB', 'C09DB', 'C10BX'],
#  ['L01XX', 'B01AX', 'L01XD'],
#  ['J01MA', 'S01AB', 'G01AE'],
#  ['G01AE', 'D08AX', 'J01DD'],
#  ['A16AX', 'B01AC', 'A06AX'],
#  ['L04AA', 'L01XX', 'L02BG'],
#  ['D01AC', 'S02AA', 'L01XX'],
#  ['L01AE', 'L01AX', 'L02AX'],
#  ['A03AD', 'A03AA', 'A03AC'],
#  ['A10BG', 'A16AX', 'A10BX'],
#  ['C07AX', 'C07AA', 'C07AB'],
#  ['J01MA', 'G01AE', 'C02CA'],
#  ['N06AA', 'R06AA', 'N04AA'],
#  ['C03AA', 'C03BA', 'G01AE'],
#  ['J01CE', 'J05AF', 'L01CF'],
#  ['D01AC', 'L01XX', 'S02AA'],
#  ['R03AC', 'R03CA', 'A03AX'],
#  ['P01BA', 'M01AA', 'R05DB'],
#  ['G01AE', 'G01AF', 'P01AE'],
#  ['A07AA', 'D08AC', 'A10BA'],
#  ['S01AA', 'J01GA', 'H01AA'],
#  ['N02AX', 'R06AX', 'R07AX'],
#  ['N05CB', 'N05CA', 'N03AB'],
#  ['C02AA', 'L01XX', 'L01CD'],
#  ['A07DA', 'N02AF', 'A06AH'],
#  ['D01AE', 'L01XX', 'S01XA'],
#  ['J01FF', 'S01AA', 'A02BD'],
#  ['C07FX', 'C08CA', 'C04AX'],
#  ['C01BA', 'A03AA', 'G04BD'],
#  ['N02AX', 'N03AX', 'N07XX'],
#  ['L04AD', 'L04AX', 'L01XX'],
#  ['C07AA', 'R03CC', 'S01ED'],
#  ['J01FA', 'S01AA', 'D01AA'],
#  ['C07AA', 'R03CC', 'C07AB'],
#  ['A08AA', 'J05AE', 'A10BH'],
#  ['J04AM', 'D06AX', 'J04AB'],
#  ['D07AC', 'S01BA', 'D07AB'],
#  ['D07AC', 'D07BC', 'R03BA'],
#  ['L01EM', 'L01EN', 'L01EX'],
#  ['L01EM', 'L01EJ', 'L01EG'],
#  ['D07AC', 'R03BA', 'H02AB'],
#  ['A10BH', 'A10BX', 'A08AA'],
#  ['J05AP', 'J05AE', 'L01CC'],
#  ['A03FA', 'C01BA', 'N05AL'],
#  ['N07BA', 'N06AA', 'N06BA'],
#  ['C03DB', 'C03BA', 'R02AX'],
#  ['C04AX', 'C04AA', 'N03AX'],
#  ['R03CC', 'R03AK', 'N03AX'],
#  ['J01ED', 'S01AB', 'J01EC'],
#  ['C03AA', 'C03BA', 'C02CA'],
#  ['G01AE', 'P03BA', 'L02BB'],
#  ['C09BB', 'C09AA', 'C09BX'],
#  ['N05CB', 'R05DB', 'N03AA'],
#  ['C07AA', 'R03CC', 'C04AA'],
#  ['R02CA', 'R03CB', 'R03DB'],
#  ['C07AA', 'R03CB', 'C04AA'],
#  ['G01AE', 'G04CA', 'S01AE'],
#  ['G03DC', 'G03BA', 'G03FA'],
#  ['N06AA', 'N02CC', 'N07CA'],
#  ['C04AA', 'S01ED', 'C04AX'],
#  ['A03BB', 'A03CB', 'A03CA'],
#  ['S01CA', 'S01BA', 'J05AF'],
#  ['J01DD', 'J01DI', 'J01DC'],
#  ['A10BB', 'M01AB', 'C03BA'],
#  ['D05AX', 'L01XX', 'P03BA'],
#  ['N07XX', 'N06DA', 'N02AX'],
#  ['R03CC', 'R03CA', 'C08CA'],
#  ['G01AE', 'S01AB', 'J01EC'],
#  ['C03CA', 'P01CX', 'S01EA'],
#  ['L01EG', 'L01XG', 'L02AX'],
#  ['R07AX', 'S01EC', 'R06AX'],
#  ['J01CR', 'J01DB', 'J01CE'],
#  ['J01DI', 'J05AP', 'J01DC'],
#  ['J01CA', 'J01CE', 'J01CG'],
#  ['J01CR', 'J01CG', 'J01CE'],
#  ['J01CR', 'J01CE', 'J01CG'],
#  ['R06AA', 'R05DB', 'N06AB'],
#  ['A03AB', 'A03AA', 'C01BA'],
#  ['R03CB', 'R03CC', 'R03DC'],
#  ['A16AX', 'B05BC', 'A11HA'],
#  ['D01AE', 'R03DB', 'R02BX'],
#  ['G03AA', 'G03DC', 'G03AC'],
#  ['D09AA', 'A01AB', 'R02AA'],
#  ['A11DA', 'A11CA', 'A10BX'],
#  ['S01EA', 'J04AA', 'H03BA'],
#  ['M02AA', 'M01AB', 'D01AE'],
#  ['A14AA', 'A14AB', 'A12AA'],
#  ['C03BA', 'C03BB', 'G01AE'],
#  ['R02AA', 'D09AA', 'D08AX'],
#  ['N05CA', 'N05BA', 'P02CA'],
#  ['A16AX', 'B02AA', 'B05CB'],
#  ['S01AX', 'C02CC', 'G01AX'],
#  ['D01AC', 'L01XX', 'C03XA'],
#  ['M01AX', 'D01AE', 'M01AG'],
#  ['G03AA', 'G03CA', 'G03CB'],
#  ['L01XX', 'P01BA', 'J01MA'],
#  ['D08AE', 'D09AA', 'G01AC'],
#  ['D08AE', 'D08AX', 'D10AA'],
#  ['B01AA', 'A16AX', 'A10BA'],
#  ['R06AE', 'R06AX', 'R05DB'],
#  ['G03DB', 'G03FB', 'G03AC'],
#  ['C01CA', 'A03AC', 'A03AX'],
#  ['L01EX', 'L01EE', 'L01EM'],
#  ['L04AA', 'A16AX', 'A16AH'],
#  ['P01CA', 'J05AX', 'B03XA'],
#  ['R03AX', 'R03AC', 'R03AD'],
#  ['G01AF', 'J01MA', 'G01AE'],
#  ['G03AA', 'G03DC', 'G03BA'],
#  ['J01FA', 'C01AA', 'S01AA'],
#  ['J01EC', 'J01EB', 'S01AB'],
#  ['S01AB', 'G01AE', 'J01EC'],
#  ['P01AX', 'L04AX', 'P01BA'],
#  ['R03CC', 'C04AX', 'R03AC'],
#  ['J01MA', 'L01XX', 'P01BA'],
#  ['M05BA', 'B05BA', 'M05BB'],
#  ['A10BB', 'G04BE', 'A10BH'],
#  ['L01DB', 'L01CA', 'L01DC'],
#  ['B01AC', 'L01DB', 'J05AP'],
#  ['A10BH', 'B02AA', 'H03BX'],
#  ['C04AX', 'R03AC', 'C07FX'],
#  ['L01EA', 'L01XE', 'L01EG'],
#  ['L04AA', 'L01XK', 'L01EX'],
#  ['L01EX', 'L01EN', 'L01EA'],
#  ['L01XK', 'L01XX', 'N05BA'],
#  ['R06AX', 'R05DB', 'R07AC'],
#  ['N01BB', 'R01AA', 'D01AB'],
#  ['L01CD', 'L01XD', 'L01DC'],
#  ['G03AA', 'G03DC', 'G03CA'],
#  ['N01BB', 'S01GA', 'D01AA'],
#  ['G01AE', 'D06BA', 'J01EC'],
#  ['M02AA', 'N02BG', 'M03BA'],
#  ['C03DB', 'C02DB', 'C03BA'],
#  ['D11AH', 'L01XF', 'B01AC'],
#  ['A08AB', 'A16AA', 'A07AB'],
#  ['C02KX', 'L01EX', 'L01EG'],
#  ['R01AA', 'N01BB', 'N01BA'],
#  ['N02BG', 'N02BX', 'M02AA'],
#  ['S01BA', 'D07CC', 'H02AB'],
#  ['S01AB', 'D06BA', 'D08AB'],
#  ['J01MA', 'J01XA', 'L01XX'],
#  ['J05AX', 'L04AA', 'L01XX'],
#  ['A12CC', 'A11CC', 'M02AA'],
#  ['S01AB', 'G01AE', 'J01EC'],
#  ['G01AE', 'C03BA', 'C03AB'],
#  ['D08AE', 'D10AB', 'D08AX'],
#  ['N07CA', 'N06AX', 'C04AX'],
#  ['R06AX', 'R05DB', 'R05DA'],
#  ['J05AH', 'J05AF', 'J01DC'],
#  ['C08CA', 'C09DX', 'C01CA'],
#  ['P01BA', 'N02BA', 'M01AH'],
#  ['M02AA', 'R05CA', 'N02AJ'],
#  ['L01EX', 'L01EA', 'L01XX'],
#  ['L04AA', 'L01EX', 'L01XX'],
#  ['G03DB', 'L02AB', 'D07CB'],
#  ['N02AX', 'R02AA', 'M02AA'],
#  ['L01EK', 'L01XE', 'L01XK'],
#  ['B02CC', 'L01XX', 'H03BX'],
#  ['L04AA', 'L04AX', 'L01XX'],
#  ['P01BA', 'C01DX', 'L01EM'],
#  ['B01AC', 'A10BB', 'A10BD'],
#  ['L02AE', 'B01AE', 'L04AE'],
#  ['L01EX', 'L01XX', 'A08AA'],
#  ['L01XK', 'L01EX', 'L01XX'],
#  ['N07BB', 'M03BB', 'A08CA'],
#  ['L01EX', 'L01XX', 'P01BA'],
#  ['D07XB', 'D07AC', 'H02AB'],
#  ['A10BG', 'G01AF', 'D01AC'],
#  ['P02CX', 'P02BX', 'P03BX'],
#  ['L01XE', 'L01EK', 'L01EX'],
#  ['L01XX', 'L01XA', 'P01CC'],
#  ['L01XF', 'L01EX', 'L01XK'],
#  ['J05AP', 'J02AC', 'J01XX'],
#  ['J05AF', 'J05AB', 'J01CA'],
#  ['D01AC', 'S02AA', 'L01XX'],
#  ['A16AX', 'A10BD', 'A10BH'],
#  ['D07XB', 'D07AB', 'D07CB'],
#  ['M01AX', 'B01AF', 'M01AE'],
#  ['J01CR', 'L01XX', 'J02AX'],
#  ['N05CX', 'R05DB', 'L04AA'],
#  ['A10BC', 'A10BK', 'A10BG'],
#  ['L01EN', 'L01EB', 'L01EL'],
#  ['L01XM', 'P01CA', 'L01XE'],
#  ['L01XX', 'J05AP', 'G01AE'],
#  ['M01CB', 'R05CB', 'N01CB'],
#  ['L01EX', 'L01XX', 'L01XK'],
#  ['L04AX', 'N07XX', 'L04AA'],
#  ['N07XX', 'R03AK', 'R03AX'],
#  ['L01XE', 'L01EK', 'L01XX'],
#  ['L01XX', 'L01XK', 'L01EX'],
#  ['R03AK', 'C04AX', 'R03AL'],
#  ['R03AC', 'R03AL', 'N07XX'],
#  ['R03AC', 'R03AK', 'C07XX'],
#  ['A03AX', 'R05DA', 'R05DB'],
#  ['N01BB', 'N01AB', 'N02AD'],
#  ['G03AA', 'G03DC', 'G03BA'],
#  ['A01AB', 'G01AA', 'A02BD'],
#  ['D07XB', 'H02AB', 'D07AB'],
#  ['B01AF', 'J05AP', 'A16AX'],
#  ['J05AP', 'L01XX', 'P01BA'],
#  ['G03CA', 'G03BA', 'A14AA'],
#  ['G03DB', 'G03AC', 'G03AA'],
#  ['L01EA', 'L01EX', 'P01BA'],
#  ['L01EX', 'L01XE', 'L01EK'],
#  ['R03AK', 'N05CM', 'N07XX'],
#  ['M01AE', 'D01AE', 'R07AX'],
#  ['M01AE', 'N02AX', 'R02AX'],
#  ['C09BB', 'C07FB', 'C09DB'],
#  ['C02CA', 'C03CA', 'P01AX'],
#  ['J01FA', 'S01BA', 'C01AA'],
#  ['J05AX', 'J01CA', 'J05AH'],
#  ['A02BB', 'G03BB', 'A03AB'],
#  ['J01CR', 'J01CE', 'J01CG'],
#  ['C09BX', 'C01BD', 'C01BC'],
#  ['A10BX', 'A11DA', 'M01CB'],
#  ['G03DC', 'G03AC', 'G03AA'],
#  ['A16AX', 'B01AC', 'A07AB'],
#  ['D08AA', 'R02AA', 'S01AA'],
#  ['D11AX', 'G01AE', 'G01AC'],
#  ['D01AE', 'A08AA', 'A10BX'],
#  ['D11AX', 'D08AX', 'D10AX'],
#  ['R06AX', 'R05DB', 'R07AC'],
#  ['A03BB', 'A03CA', 'R03BB'],
#  ['N01AH', 'A08AA', 'N01AX'],
#  ['L02AB', 'D07CB', 'H02AB'],
#  ['J01FA', 'C01AA', 'S01AA'],
#  ['L01XX', 'L04AA', 'N02BG'],
#  ['D07XB', 'H02AB', 'D07AC'],
#  ['J04AM', 'L04AA', 'A07XA'],
#  ['B01AC', 'A08AA', 'B01AE'],
#  ['N02CC', 'N01AA', 'N04AA'],
#  ['B01AC', 'J05AP', 'B01AF'],
#  ['L01XE', 'L01EX', 'L01EK'],
#  ['R07AX', 'S01EE', 'C10AB'],
#  ['L01XE', 'L01XX', 'L01EB'],
#  ['L01XD', 'L01XH', 'L02BB'],
#  ['L01EX', 'J01MA', 'L01EA'],
#  ['J01DC', 'J01DD', 'J01DB'],
#  ['L01XE', 'L02BG', 'L01EX'],
#  ['G03AA', 'G03AC', 'G03FB'],
#  ['L01EA', 'L01EM', 'L01EH'],
#  ['J05AX', 'B01AC', 'J04AX'],
#  ['P01AB', 'L01XD', 'J01MA'],
#  ['C02DB', 'C03DB', 'C03BA'],
#  ['D07XB', 'H02AB', 'D07AC'],
#  ['C01CA', 'C04AX', 'C01BA'],
#  ['A16AX', 'A12CC', 'M02AA'],
#  ['P01CA', 'L01XX', 'M01CA'],
#  ['G01AE', 'S01EC', 'P01CC'],
#  ['J01GB', 'A07AA', 'B02AA'],
#  ['C02KX', 'P01CX', 'C03CA'],
#  ['P03AA', 'A03AA', 'L03AA'],
#  ['M01AG', 'C01BB', 'M01AB'],
#  ['J01CR', 'J01CA', 'J01CC'],
#  ['N02AX', 'N02BX', 'M01AA'],
#  ['M01AB', 'P02CC', 'P03AX'],
#  ['G01AE', 'C03AA', 'C03BA'],
#  ['A12AA', 'B05CX', 'B05BC'],
#  ['A03AB', 'A03BB', 'A03DA'],
#  ['D07XB', 'H02AB', 'D07BC'],
#  ['R06AX', 'C04AX', 'R07AX'],
#  ['L01EX', 'L04AA', 'R06AX'],
#  ['A12CC', 'A16AX', 'M01CB'],
#  ['B03XA', 'L01XX', 'J05AX'],
#  ['D07XB', 'H02AB', 'D07BC'],
#  ['D07AC', 'S01BA', 'D07CC'],
#  ['A14AA', 'H02AB', 'A07EA'],
#  ['N05CD', 'N05BA', 'N07XX'],
#  ['L01EA', 'L01EX', 'C04AX'],
#  ['L01EX', 'L01XX', 'B01AE'],
#  ['L01EX', 'L04AX', 'L01EG'],
#  ['N02AX', 'N06AX', 'R06AX'],
#  ['L01BC', 'S01AD', 'J05AB'],
#  ['G01AE', 'J01ED', 'S01AB'],
#  ['L01ED', 'L01EA', 'L01EM'],
#  ['G01AF', 'L01XX', 'S02AA'],
#  ['L01CA', 'C01BA', 'B01CA'],
#  ['D07AC', 'D07CC', 'H02AA'],
#  ['R03BB', 'C01CA', 'N03AX'],
#  ['L01XX', 'D01AC', 'S01AA'],
#  ['D01AE', 'R07AX', 'R05DB'],
#  ['N05CA', 'M02AA', 'N05CB'],
#  ['N01AA', 'N01AC', 'M02AA'],
#  ['L01AA', 'S01AA', 'D01AA'],
#  ['C02CC', 'L01XX', 'C02CA'],
#  ['D07AC', 'S01BA', 'D07AB'],
#  ['R03CB', 'C03CA', 'C04AX'],
#  ['S01AE', 'G01AE', 'P01AF'],
#  ['M02AA', 'M01AE', 'N02AX'],
#  ['B05BA', 'B05XB', 'M05BB'],
#  ['R03CC', 'N03AX', 'N03CC'],
#  ['A03CA', 'A03BB', 'A03DA'],
#  ['N03AX', 'N03CC', 'S01ED'],
#  ['D01AC', 'S02AA', 'L01XX'],
#  ['R03CB', 'C01CA', 'C03CA'],
#  ['L01BA', 'A02BA', 'B05CA'],
#  ['C07AB', 'C07AA', 'R03CB'],
#  ['L01BC', 'C01EB', 'R05CB'],
#  ['D01AC', 'S02AA', 'L01XX'],
#  ['N03AX', 'C04AX', 'S01ED'],
#  ['S01BA', 'D07AB', 'R03BA'],
#  ['A16AX', 'A11AA', 'B05XA'],
#  ['L01XX', 'C01CA', 'C03BA'],
#  ['A03CA', 'A03BB', 'A03AD'],
#  ['N02CC', 'D01AC', 'R05DB'],
#  ['S01BA', 'H02AB', 'D07AB'],
#  ['G03DB', 'G03FB', 'G03AA'],
#  ['A03CB', 'S01FA', 'A03AB'],
#  ['N01AX', 'N01AA', 'M02AA'],
#  ['S01GX', 'D01AC', 'R05DB'],
#  ['A16AX', 'A12BA', 'G02AD'],
#  ['D01AC', 'L01XX', 'S01AA'],
#  ['C07AA', 'R03CB', 'C04AX'],
#  ['M01AE', 'N02AX', 'N02AJ'],
#  ['R01AX', 'C01CA', 'N03AX'],
#  ['G01AX', 'L01XX', 'S01GX'],
#  ['G01AF', 'L01XX', 'S02AA'],
#  ['R06AB', 'R06AA', 'R05DB'],
#  ['C01CA', 'R03AB', 'C03CA'],
#  ['N02AC', 'M02AA', 'N01AF'],
#  ['N02AX', 'N06AX', 'N04AA'],
#  ['A03CA', 'A03BB', 'A03DA'],
#  ['S01AD', 'L01BC', 'L01BB'],
#  ['G01AX', 'R06AX', 'S01GX'],
#  ['N01BA', 'N01BB', 'C01BA'],
#  ['G01AF', 'L01XX', 'D01AF'],
#  ['N03AX', 'C04AX', 'N03CC'],
#  ['B05XB', 'D11AX', 'B05BA'],
#  ['G02AD', 'B01AC', 'A16AA'],
#  ['M01AE', 'N02AX', 'N02AJ'],
#  ['L01BB', 'L01BA', 'J04AB'],
#  ['A07AA', 'A02BA', 'B05CA'],
#  ['N07XX', 'N02BX', 'M01AA'],
#  ['A16AX', 'A11AA', 'A14AD'],
#  ['A03CA', 'A03BB', 'A03AD'],
#  ['J01MA', 'G01AE', 'P01AF'],
#  ['C07AA', 'R03CC', 'C04AA'],
#  ['C07AA', 'R03CC', 'C04AA'],
#  ['G02AD', 'B01AC', 'A16AX'],
#  ['N05CA', 'M02AA', 'N02AC'],
#  ['N02BA', 'L01XX', 'C02CC'],
#  ['D11AX', 'D08AX', 'L01XX'],
#  ['R06AB', 'R06AA', 'R05DB'],
#  ['N07XX', 'N02BX', 'P03AX'],
#  ['A03AB', 'A08AB', 'C01BA'],
#  ['R03AB', 'C03CA', 'C04AX'],
#  ['G01AF', 'D01AC', 'L01XX'],
#  ['N01AF', 'M02AA', 'N02AC'],
#  ['A03CB', 'A03CA', 'S01FA'],
#  ['N01BA', 'N01BB', 'C01BA'],
#  ['G01AE', 'J01RA', 'C02CA'],
#  ['P01AB', 'L01XD', 'J01MA'],
#  ['C02CC', 'S01AX', 'G01AX'],
#  ['C02CA', 'R05CA', 'C02KX'],
#  ['D09AA', 'R02AA', 'A01AA'],
#  ['A03BB', 'A03CA', 'A03AB'],
#  ['N03AC', 'N02CB', 'N02CC'],
#  ['C07AB', 'C08CA', 'C09BX'],
#  ['R06AE', 'R06AX', 'S01GX'],
#  ['A16AX', 'M04AC', 'P03AX'],
#  ['L01AD', 'L01AB', 'N02BA'],
#  ['M02AA', 'N05CA', 'N02AA'],
#  ['R05DB', 'R06AB', 'D04AA'],
#  ['G01AF', 'S02AA', 'L01XX'],
#  ['L02BA', 'L02BX', 'P01CC'],
#  ['G03DB', 'G03FB', 'D07CB'],
#  ['L01BC', 'S01AD', 'J05AB'],
#  ['N07XX', 'M02AA', 'P03AX'],
#  ['G03AA', 'G03DC', 'G03FA'],
#  ['D07AC', 'H02AB', 'D07AB'],
#  ['C04AA', 'C04AX', 'S01ED'],
#  ['M01AA', 'N05CM', 'N05CF'],
#  ['J01XX', 'L01AD', 'J01MA'],
#  ['J01MA', 'G01AE', 'P01CD'],
#  ['D11AX', 'D10AB', 'D10AX'],
#  ['A05AA', 'A06AX', 'A11DA'],
#  ['M01AA', 'P03AA', 'M01AB'],
#  ['N07XX', 'N06AX', 'R05CB'],
#  ['C04AX', 'C01CA', 'C02KX'],
#  ['B01AC', 'L01XX', 'A06AX'],
#  ['C03DA', 'C03CA', 'C01CA'],
#  ['L01AX', 'L01XX', 'D01AX'],
#  ['A03AB', 'G03AB', 'R03AB'],
#  ['C01CA', 'R03DC', 'R03CB'],
#  ['G02AD', 'A02BB', 'D02BA'],
#  ['J01GB', 'J01GA', 'S01AA'],
#  ['D07AC', 'D07CC', 'H02AB'],
#  ['P03AX', 'N02BG', 'P02CC'],
#  ['L02BB', 'L01CC', 'L02BC'],
#  ['D08AJ', 'A01AB', 'D08AA'],
#  ['N06AA', 'R06AD', 'N06AB'],
#  ['R03AC', 'N06BX', 'R03AK'],
#  ['A08AA', 'C01CA', 'R03CA'],
#  ['A16AX', 'A06AD', 'A11HA'],
#  ['C04AD', 'C03CA', 'C02BX'],
#  ['N07XX', 'M04AC', 'M01AG'],
#  ['D01AC', 'R02AA', 'R01AA'],
#  ['N02BA', 'P01BA', 'N01AF'],
#  ['N05CX', 'M01AA', 'M01AX'],
#  ['R06AC', 'R07DA', 'R05DB'],
#  ['A14AA', 'H02AB', 'D07XA'],
#  ['C04AX', 'C02CA', 'R06AX'],
#  ['C01CA', 'R03AK', 'R03AL'],
#  ['G01AE', 'C03AB', 'C03AX'],
#  ['M02AA', 'M01CC', 'L01XX'],
#  ['R03CA', 'R03CB', 'N07CA'],
#  ['P01BA', 'G01AE', 'C03CA'],
#  ['J05AX', 'L01XX', 'P01CB'],
#  ['M02AA', 'M01AE', 'N02AX'],
#  ['A12AA', 'D07AB', 'D07AA'],
#  ['S01AX', 'D08AC', 'A07AB'],
#  ['C04AA', 'C07AA', 'S01ED'],
#  ['N06BA', 'N07BB', 'N06AA'],
#  ['N05BX', 'N07XX', 'N06AX'],
#  ['N07BC', 'N07XX', 'N06DA'],
#  ['L01XX', 'L02BG', 'H02AB'],
#  ['D08AC', 'C02CC', 'G01AX'],
#  ['D08AJ', 'D09AA', 'R02AA']]
