# %%
import os
import sys
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '../..')))
from seq2seq import *

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from collections import defaultdict
import seaborn as sns

from sklearn import preprocessing
from sklearn.utils import class_weight
from sklearn.preprocessing import StandardScaler, MinMaxScaler, MultiLabelBinarizer
from sklearn.model_selection import train_test_split 
from sklearn.metrics import precision_recall_curve, average_precision_score, multilabel_confusion_matrix, classification_report

import tensorflow as tf
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout

import random

# %%
def set_seeds(seed):
    np.random.seed(seed)
    random.seed(seed)
    keras.utils.set_random_seed(seed)
    tf.random.set_seed(seed)                
    os.environ["PYTHONHASHSEED"] = str(seed) 
    os.environ["TF_DETERMINISTIC_OPS"] = "1" 
    os.environ["TF_CUDNN_DETERMINISTIC"] = "1" 
# Convert a string that simulates a list to a real list
def convert_string_list(element):
    # Delete [] of the string
    element = element[1:len(element)-1]
    # Create a list that contains each code as e.g. 'A'
    ATC_list = list(element.split(', '))
    for index, code in enumerate(ATC_list):
        # Delete '' of the code
        ATC_list[index] = code[1:len(code)-1]
    return ATC_list

# %% [markdown]
# ## SETS

# %%
def train_test_1(seed):
    train_set = pd.read_csv(f'train_set.csv')
    val_set = pd.read_csv(f'val_set.csv')
    test_set = pd.read_csv(f'test_set.csv')
    train_set = pd.concat([train_set, val_set], ignore_index=True)
    # Delete unnecessary columns from train set
    train_set.drop('Neutralized SMILES', axis = 1, inplace = True)
    train_set.drop('ATC Codes', axis = 1, inplace = True)
    train_set.drop('ATC_level2', axis = 1, inplace = True)
    train_set.drop('ATC_level3', axis = 1, inplace = True)
    train_set.drop('ATC_level4', axis = 1, inplace = True)
    train_set.drop('multiple_ATC', axis = 1, inplace = True)
    train_set = train_set.reset_index(drop=True)
    # Delete unnecessary columns from test set
    test_set.drop('Neutralized SMILES', axis = 1, inplace = True)
    test_set.drop('ATC Codes', axis = 1, inplace = True)
    test_set.drop('ATC_level2', axis = 1, inplace = True)
    test_set.drop('ATC_level3', axis = 1, inplace = True)
    test_set.drop('ATC_level4', axis = 1, inplace = True)
    test_set.drop('multiple_ATC', axis = 1, inplace = True)
    test_set = test_set.reset_index(drop=True)
    # Divide in X and y
    X_train = train_set.drop('ATC_level1', axis = 1)
    y_train = train_set['ATC_level1']
    X_test = test_set.drop('ATC_level1', axis = 1)
    y_test = test_set['ATC_level1']
    return X_train, y_train, X_test, y_test
def train_test_2(seed):
    train_set = pd.read_csv(f'train_set.csv')
    val_set = pd.read_csv(f'val_set.csv')
    test_set = pd.read_csv(f'test_set.csv')
    train_set = pd.concat([train_set, val_set], ignore_index=True)
    # Delete unnecessary columns 
    train_set.drop('Neutralized SMILES', axis = 1, inplace = True)
    train_set.drop('ATC Codes', axis = 1, inplace = True)
    train_set.drop('ATC_level3', axis = 1, inplace = True)
    train_set.drop('ATC_level4', axis = 1, inplace = True)
    train_set.drop('multiple_ATC', axis = 1, inplace = True)
    train_set = train_set.reset_index(drop=True)
    # Delete unnecessary columns 
    test_set.drop('Neutralized SMILES', axis = 1, inplace = True)
    test_set.drop('ATC Codes', axis = 1, inplace = True)
    test_set.drop('ATC_level3', axis = 1, inplace = True)
    test_set.drop('ATC_level4', axis = 1, inplace = True)
    test_set.drop('multiple_ATC', axis = 1, inplace = True)
    test_set = test_set.reset_index(drop=True)
    # Replicate compounds that have more than 1 ATC level 1 code
    new_rows = []

    for _, row in train_set.iterrows():
        ATC_level1_list = convert_string_list(row['ATC_level1'])
        for code in ATC_level1_list:
            new_row = row.copy()
            new_row['ATC_level1'] = code
            new_rows.append(new_row)

    new_train_set = pd.DataFrame(new_rows)
    new_train_set = new_train_set.reset_index(drop=True)
    # Delete level 1 letter from ATC_level2
    new_rows = [] 
    for _, row in new_train_set.iterrows():
        ATC_level2_list = convert_string_list(row['ATC_level2'])
        # Split ATC code if they have more than 1 code at level 2
        for code in ATC_level2_list:
            if code[0] == row['ATC_level1']:
                new_row = row.copy()
                new_row['ATC_level2'] = code[1:len(code)]
                new_rows.append(new_row)

    new_train_set2 = pd.DataFrame(new_rows)
    new_train_set2 = new_train_set2.reset_index(drop=True)
    
    new_test_set2 = test_set
    
    X_train = new_train_set2.drop('ATC_level2', axis = 1)
    y_train = new_train_set2['ATC_level2']
    X_test = new_test_set2.drop('ATC_level2', axis = 1)
    y_test = new_test_set2['ATC_level2']
    
    return X_train, y_train, X_test, y_test
def train_test_3(seed):
    train_set = pd.read_csv(f'train_set.csv')
    val_set = pd.read_csv(f'val_set.csv')
    test_set = pd.read_csv(f'test_set.csv')
    train_set = pd.concat([train_set, val_set], ignore_index=True)
    # Delete unnecessary columns 
    train_set.drop('Neutralized SMILES', axis = 1, inplace = True)
    train_set.drop('ATC Codes', axis = 1, inplace = True)
    train_set.drop('ATC_level1', axis = 1, inplace = True)
    train_set.drop('ATC_level4', axis = 1, inplace = True)
    train_set.drop('multiple_ATC', axis = 1, inplace = True)
    train_set = train_set.reset_index(drop=True)
    # Delete unnecessary columns 
    test_set.drop('Neutralized SMILES', axis = 1, inplace = True)
    test_set.drop('ATC Codes', axis = 1, inplace = True)
    test_set.drop('ATC_level1', axis = 1, inplace = True)
    test_set.drop('ATC_level4', axis = 1, inplace = True)
    test_set.drop('multiple_ATC', axis = 1, inplace = True)
    test_set = test_set.reset_index(drop=True)
    # Replicate compounds that have more than 1 ATC code
    new_rows = []

    for _, row in train_set.iterrows():
        ATC_level2_list = convert_string_list(row['ATC_level2'])
        for code in ATC_level2_list:
            new_row = row.copy()
            new_row['ATC_level2'] = code
            new_rows.append(new_row)

    new_train_set = pd.DataFrame(new_rows)
    new_train_set = new_train_set.reset_index(drop=True)
    # Delete level 1 letter from ATC_level2
    new_rows = [] 
    for _, row in new_train_set.iterrows():
        ATC_level3_list = convert_string_list(row['ATC_level3'])
        # Split ATC code if they have more than 1 code at level 2
        for code in ATC_level3_list:
            if code[0:3] == row['ATC_level2']:
                new_row = row.copy()
                new_row['ATC_level3'] = code[3:len(code)]
                new_rows.append(new_row)

    new_train_set2 = pd.DataFrame(new_rows)
    new_train_set2 = new_train_set2.reset_index(drop=True)

    new_test_set2 = test_set

    X_train = new_train_set2.drop('ATC_level3', axis = 1)
    y_train = new_train_set2['ATC_level3']
    X_test = new_test_set2.drop('ATC_level3', axis = 1)
    y_test = new_test_set2['ATC_level3']
    
    return X_train, y_train, X_test, y_test
def train_test_4(seed):
    train_set = pd.read_csv(f'train_set.csv')
    val_set = pd.read_csv(f'val_set.csv')
    test_set = pd.read_csv(f'test_set.csv')
    train_set = pd.concat([train_set, val_set], ignore_index=True)
    # Delete unnecessary columns 
    train_set.drop('Neutralized SMILES', axis = 1, inplace = True)
    train_set.drop('ATC Codes', axis = 1, inplace = True)
    train_set.drop('ATC_level1', axis = 1, inplace = True)
    train_set.drop('ATC_level2', axis = 1, inplace = True)
    train_set.drop('multiple_ATC', axis = 1, inplace = True)
    train_set = train_set.reset_index(drop=True)
    # Delete unnecessary columns 
    test_set.drop('Neutralized SMILES', axis = 1, inplace = True)
    test_set.drop('ATC Codes', axis = 1, inplace = True)
    test_set.drop('ATC_level1', axis = 1, inplace = True)
    test_set.drop('ATC_level2', axis = 1, inplace = True)
    test_set.drop('multiple_ATC', axis = 1, inplace = True)
    test_set = test_set.reset_index(drop=True)
    # Replicate compounds that have more than 1 ATC code
    new_rows = []

    for _, row in train_set.iterrows():
        ATC_level3_list = convert_string_list(row['ATC_level3'])
        for code in ATC_level3_list:
            new_row = row.copy()
            new_row['ATC_level3'] = code
            new_rows.append(new_row)

    new_train_set = pd.DataFrame(new_rows)
    new_train_set = new_train_set.reset_index(drop=True)
    # Delete level 1 letter from ATC_level2
    new_rows = [] 
    for _, row in new_train_set.iterrows():
        ATC_level4_list = convert_string_list(row['ATC_level4'])
        # Split ATC code if they have more than 1 code at level 2
        for code in ATC_level4_list:
            if code[0:4] == row['ATC_level3']:
                if code[4:len(code)] != '':
                    new_row = row.copy()
                    new_row['ATC_level4'] = code[4:len(code)]
                    new_rows.append(new_row)

    new_train_set2 = pd.DataFrame(new_rows)
    new_train_set2 = new_train_set2.reset_index(drop=True)

    new_test_set2 = test_set

    X_train = new_train_set2.drop('ATC_level4', axis = 1)
    y_train = new_train_set2['ATC_level4']
    X_test = new_test_set2.drop('ATC_level4', axis = 1)
    y_test = new_test_set2['ATC_level4']
    
    return X_train, y_train, X_test, y_test

# %%
def get_X_train_level2(X_train2, y_train2):
    # Get all available labels describing the level 1 ATC code
    labels2 = set()
    for code in y_train2:
        labels2.add(code)
            
    labels2 = sorted(list(labels2))
    y_labels_encoder2 = MultiLabelBinarizer()
    y_labels_encoder2.fit([labels2])
    encoded_y_train2 = y_labels_encoder2.transform(y_train2.values.reshape(-1, 1))
    
    atc_level1_labels2 = set()
    for _, row in X_train2.iterrows():
        atc_level1_labels2.add(row['ATC_level1'])
            
    atc_level1_labels2 = sorted(list(atc_level1_labels2))
    atc_level1_labels_encoder2 = MultiLabelBinarizer()
    atc_level1_labels_encoder2.fit([atc_level1_labels2])
    ATC_level11 = X_train2['ATC_level1']
    ATC_level1_2 = ATC_level11.copy()
    for index, lista in enumerate(ATC_level11):
        ATC_level1_2[index] = []
        ATC_level1_2[index].append(lista)
    categorical_atc2 = atc_level1_labels_encoder2.transform(ATC_level1_2)
    X_train2.drop(labels=['ATC_level1'], axis="columns", inplace=True)
    df_level1_2 = pd.DataFrame(categorical_atc2, columns=atc_level1_labels2)
    X_train2 = pd.concat([X_train2, df_level1_2], axis = 1)
    X_train2 = np.asarray(X_train2).astype(np.float32)
    encoded_y_train2 = np.asarray(encoded_y_train2).astype(np.float32)
    # Complete NaN values in each column with the median
    X_train2[pd.isna(X_train2)] = np.nanmedian(X_train2)
    # Define an instance of the MinMaxScaler
    scaler2 = MinMaxScaler()
    # Fit the scaler to the data and transform it
    X_train2 = scaler2.fit_transform(X_train2)
    return X_train2, encoded_y_train2, labels2, y_labels_encoder2, atc_level1_labels_encoder2, scaler2

def get_X_train_level3(X_train3, y_train3):
    # Get all available labels describing the level 1 ATC code
    labels3 = set()
    for code in y_train3:
        labels3.add(code)
            
    labels3 = sorted(list(labels3))
    y_labels_encoder3 = MultiLabelBinarizer()
    y_labels_encoder3.fit([labels3])
    encoded_y_train3 = y_labels_encoder3.transform(y_train3.values.reshape(-1, 1))
    
    atc_level1_labels3 = set()
    atc_level2_labels3 = set()
    for _, row in X_train3.iterrows():
        atc_level1_labels3.add(row['ATC_level2'][0:1])
        atc_level2_labels3.add(row['ATC_level2'][1:3])
    for _, row in X_test3.iterrows():
        lista = convert_string_list(row['ATC_level2'])
        for code in lista:
            atc_level1_labels3.add(code[0:1])
            atc_level2_labels3.add(code[1:3])
            
    atc_level1_labels3 = sorted(list(atc_level1_labels3))
    atc_level2_labels3 = sorted(list(atc_level2_labels3))
    atc_level1_labels_encoder3 = MultiLabelBinarizer()
    atc_level1_labels_encoder3.fit([atc_level1_labels3])
    atc_level2_labels_encoder3 = MultiLabelBinarizer()
    atc_level2_labels_encoder3.fit([atc_level2_labels3])
    ATC_level22 = X_train3['ATC_level2']
    ATC_level1_3 = ATC_level22.copy()
    ATC_level2_3 = ATC_level22.copy()
    for index, lista in enumerate(ATC_level22):
        ATC_level1_3[index] = []
        ATC_level1_3[index].append(lista[0:1])
    for index, lista in enumerate(ATC_level22):
        ATC_level2_3[index] = []
        ATC_level2_3[index].append(lista[1:3])
    X_train3.drop(labels=['ATC_level2'], axis="columns", inplace=True)
    categorical_atc1_3 = atc_level1_labels_encoder3.transform(ATC_level1_3)
    categorical_atc2_3 = atc_level2_labels_encoder3.transform(ATC_level2_3)
    df_level1_3 = pd.DataFrame(categorical_atc1_3, columns=atc_level1_labels3)
    df_level2_3 = pd.DataFrame(categorical_atc2_3, columns=atc_level2_labels3)
    X_train3 = pd.concat([X_train3, df_level1_3, df_level2_3], axis = 1)
    X_train3 = np.asarray(X_train3).astype(np.float32)
    encoded_y_train3 = np.asarray(encoded_y_train3).astype(np.float32)
    # Complete NaN values in each column with the median
    X_train3[pd.isna(X_train3)] = np.nanmedian(X_train3)
    # Define an instance of the MinMaxScaler
    scaler3 = MinMaxScaler()
    # Fit the scaler to the data and transform it
    X_train3 = scaler3.fit_transform(X_train3)
    return X_train3, encoded_y_train3, labels3, y_labels_encoder3, atc_level1_labels_encoder3, atc_level2_labels_encoder3, scaler3

def get_X_train_level4(X_train4, y_train4):
    # Get all available labels describing the level 1 ATC code
    labels4 = set()
    for code in y_train4:
        labels4.add(code)
            
    labels4 = sorted(list(labels4))
    y_labels_encoder4 = MultiLabelBinarizer()
    y_labels_encoder4.fit([labels4])
    encoded_y_train4 = y_labels_encoder4.transform(y_train4.values.reshape(-1, 1))
    
    atc_level1_labels4 = set()
    atc_level2_labels4 = set()
    atc_level3_labels4 = set()
    for _, row in X_train4.iterrows():
        atc_level1_labels4.add(row['ATC_level3'][0:1])
        atc_level2_labels4.add(row['ATC_level3'][1:3])
        atc_level3_labels4.add(row['ATC_level3'][3:4])
    for _, row in X_test4.iterrows():
        lista = convert_string_list(row['ATC_level3'])
        for code in lista:
            atc_level1_labels4.add(code[0:1])
            atc_level2_labels4.add(code[1:3])
            atc_level3_labels4.add(code[3:4])
    
    atc_level1_labels4 = sorted(list(atc_level1_labels4))
    atc_level2_labels4 = sorted(list(atc_level2_labels4))
    atc_level3_labels4 = sorted(list(atc_level3_labels4))
    atc_level1_labels_encoder4 = MultiLabelBinarizer()
    atc_level1_labels_encoder4.fit([atc_level1_labels4])
    atc_level2_labels_encoder4 = MultiLabelBinarizer()
    atc_level2_labels_encoder4.fit([atc_level2_labels4])
    atc_level3_labels_encoder4 = MultiLabelBinarizer()
    atc_level3_labels_encoder4.fit([atc_level3_labels4])
    ATC_level33 = X_train4['ATC_level3']
    ATC_level1_4 = ATC_level33.copy()
    for index, lista in enumerate(ATC_level33):
        ATC_level1_4[index] = []
        ATC_level1_4[index].append(lista[0:1])
    ATC_level2_4 = ATC_level33.copy()
    for index, lista in enumerate(ATC_level33):
        ATC_level2_4[index] = []
        ATC_level2_4[index].append(lista[1:3])
    ATC_level3_4 = ATC_level33.copy()
    for index, lista in enumerate(ATC_level33):
        ATC_level3_4[index] = []
        ATC_level3_4[index].append(lista[3:4])
    X_train4.drop(labels=['ATC_level3'], axis="columns", inplace=True)
    categorical_atc1_4 = atc_level1_labels_encoder4.transform(ATC_level1_4)
    categorical_atc2_4 = atc_level2_labels_encoder4.transform(ATC_level2_4)
    categorical_atc3_4 = atc_level3_labels_encoder4.transform(ATC_level3_4)
    df_level1_4 = pd.DataFrame(categorical_atc1_4, columns=atc_level1_labels4)
    df_level2_4 = pd.DataFrame(categorical_atc2_4, columns=atc_level2_labels4)
    df_level3_4 = pd.DataFrame(categorical_atc3_4, columns=atc_level3_labels4)
    X_train4 = pd.concat([X_train4, df_level1_4, df_level2_4, df_level3_4], axis = 1)
    X_train4 = np.asarray(X_train4).astype(np.float32)
    encoded_y_train4 = np.asarray(encoded_y_train4).astype(np.float32)
    # Complete NaN values in each column with the median
    X_train4[pd.isna(X_train4)] = np.nanmedian(X_train4)
    # Define an instance of the MinMaxScaler
    scaler4 = MinMaxScaler()
    # Fit the scaler to the data and transform it
    X_train4 = scaler4.fit_transform(X_train4)

    return X_train4, encoded_y_train4, labels4, y_labels_encoder4, atc_level1_labels_encoder4, atc_level2_labels_encoder4, atc_level3_labels_encoder4, scaler4

# %%
def test_set_level1(scaler1, X_test):
    X_test = np.asarray(X_test).astype(np.float32)
    X_test[pd.isna(X_test)] = np.nanmedian(X_test)
    X_test = scaler1.transform(X_test)
    return X_test

# %%
def test_set_level2(scaler2, X_test1, pred_df_level1, atc_level1_labels_encoder2):
    X_test1.drop(labels=['ATC_level1'], axis="columns", inplace=True)
    X_test1['ATC_level1'] = pred_df_level1['pred_1']
    ATC_level1 = X_test1['ATC_level1']
    categorical_atc = atc_level1_labels_encoder2.transform(ATC_level1)
    df_level1 = pd.DataFrame(categorical_atc, columns=atc_level1_labels_encoder2.classes_)
    X_test1 = pd.concat([X_test1, df_level1], axis = 1)
    X_test1.drop(labels=['ATC_level1'], axis="columns", inplace=True)

    X_test1 = np.asarray(X_test1).astype(np.float32)
    X_test1[pd.isna(X_test1)] = np.nanmedian(X_test1)
    X_test1 = scaler2.transform(X_test1)

    return X_test1

# %%
def test_set_level3(scaler3, X_test1, pred_df_level1, pred_df_level2, atc_level1_labels_encoder3, atc_level2_labels_encoder3):
    predicted_codes = []
    
    for index, pred1 in enumerate(pred_df_level1['pred_1']):
        pred2 = str(pred_df_level2.at[pred_df_level2.index[index], 'pred_2']).zfill(2)
        prediction = pred1 + '' + pred2
        predicted_codes.append(prediction)
        
    X_test1['ATC_level2'] = predicted_codes
    
    ATC_level22 = X_test1['ATC_level2']
    ATC_level1_3 = ATC_level22.copy()
    ATC_level2_3 = ATC_level22.copy()
    for index, atc in enumerate(ATC_level22):
        ATC_level1_3[index] = []
        ATC_level1_3[index].append(atc[0:1])
        ATC_level2_3[index] = []
        ATC_level2_3[index].append(atc[1:3])

    X_test1 = X_test1.drop(labels=['ATC_level2'], axis="columns")
    
    categorical_atc1_3 = atc_level1_labels_encoder3.transform(ATC_level1_3)
    categorical_atc2_3 = atc_level2_labels_encoder3.transform(ATC_level2_3)
    df_level1_3 = pd.DataFrame(categorical_atc1_3, columns=atc_level1_labels_encoder3.classes_)
    df_level2_3 = pd.DataFrame(categorical_atc2_3, columns=atc_level2_labels_encoder3.classes_)
    X_test1 = pd.concat([X_test1, df_level1_3, df_level2_3], axis = 1)                         
    
    X_test1 = np.asarray(X_test1).astype(np.float32)
    X_test1[pd.isna(X_test1)] = np.nanmedian(X_test1)
    X_test1 = scaler3.transform(X_test1)

    return X_test1

# %%
def test_set_level4(scaler4, X_test1, pred_df_level1, pred_df_level2, pred_df_level3, atc_level1_labels_encoder4, atc_level2_labels_encoder4, atc_level3_labels_encoder4):
    predicted_codes = []
    
    for index, pred1 in enumerate(pred_df_level1['pred_1']):
        pred2 = str(pred_df_level2.at[pred_df_level2.index[index], 'pred_2']).zfill(2)
        pred3 = pred_df_level3.at[pred_df_level3.index[index], 'pred_3']
        prediction = pred1 + '' + pred2 + '' + pred3
        predicted_codes.append(prediction)
        
    X_test1['ATC_level3'] = predicted_codes
    
    ATC_level33 = X_test1['ATC_level3']
    ATC_level1_4 = ATC_level33.copy()
    ATC_level2_4 = ATC_level33.copy()
    ATC_level3_4 = ATC_level33.copy()
    for index, atc in enumerate(ATC_level33):
        ATC_level1_4[index] = []
        ATC_level1_4[index].append(atc[0:1])
        ATC_level2_4[index] = []
        ATC_level2_4[index].append(atc[1:3])
        ATC_level3_4[index] = []
        ATC_level3_4[index].append(atc[3:4])

    X_test1 = X_test1.drop(labels=['ATC_level3'], axis="columns")

    categorical_atc1_4 = atc_level1_labels_encoder4.transform(ATC_level1_4)
    categorical_atc2_4 = atc_level2_labels_encoder4.transform(ATC_level2_4)
    categorical_atc3_4 = atc_level3_labels_encoder4.transform(ATC_level3_4)
    df_level1_4 = pd.DataFrame(categorical_atc1_4, columns=atc_level1_labels_encoder4.classes_)
    df_level2_4 = pd.DataFrame(categorical_atc2_4, columns=atc_level2_labels_encoder4.classes_)
    df_level3_4 = pd.DataFrame(categorical_atc3_4, columns=atc_level3_labels_encoder4.classes_)
    X_test1 = pd.concat([X_test1, df_level1_4, df_level2_4, df_level3_4], axis = 1)                         
    X_test1 = np.asarray(X_test1).astype(np.float32)
    X_test1[pd.isna(X_test1)] = np.nanmedian(X_test1)
    X_test1 = scaler4.transform(X_test1)

    return X_test1

# %% [markdown]
# ## PREDICTIONS

# %%
def generate_predictions(scaler1, scaler2, scaler3, scaler4, model1, X_test1, model2, X_test2, model3, X_test3, model4, X_test4, y_labels_encoder2, y_labels_encoder3, y_labels_encoder4, atc_level1_labels_encoder2, atc_level1_labels_encoder3, atc_level2_labels_encoder3, atc_level1_labels_encoder4, atc_level2_labels_encoder4, atc_level3_labels_encoder4, previous_predictions = None, index = None):
    """Genera predicciones para todos los niveles, o solo para un índice si se repite"""
    
    def sample_prediction(model, X_test, encoder, previous_predictions = None, index = None):
        """Calcula la predicción con probabilidad ponderada para un índice o todos"""
        if previous_predictions is None:
            # Primera vez: calcular todas las predicciones
            y_prob = model.predict(X_test)
            predictions = [
                random.choices(encoder.classes_, weights=row, k=1)[0] for row in y_prob
            ]
        else:
            # Mantener las predicciones anteriores y cambiar solo la del índice dado
            predictions = previous_predictions.copy()
            if index is not None:
                y_prob = model.predict(X_test)
                row = np.array(y_prob)[index]
                predictions[index] = random.choices(encoder.classes_, weights=row, k=1)[0]
    
        return predictions
    
    # Nivel 1
    X_test1 = test_set_level1(scaler1, X_test1)
    pred_1 = sample_prediction(model1, X_test1, mlb, previous_predictions['pred_1'] if previous_predictions is not None else None, index)
    pred_df_level1 = pd.DataFrame(pred_1, columns=['pred_1'])

    # Nivel 2
    X_test2 = test_set_level2(scaler2, X_test2, pred_df_level1, atc_level1_labels_encoder2)
    pred_2 = sample_prediction(model2, X_test2, y_labels_encoder2, previous_predictions['pred_2'] if previous_predictions is not None else None, index)
    pred_df_level2 = pd.DataFrame(pred_2, columns=['pred_2'])

    # Nivel 3
    X_test3 = test_set_level3(scaler3, X_test3, pred_df_level1, pred_df_level2, atc_level1_labels_encoder3, atc_level2_labels_encoder3)
    pred_3 = sample_prediction(model3, X_test3, y_labels_encoder3, previous_predictions['pred_3'] if previous_predictions is not None else None, index)
    pred_df_level3 = pd.DataFrame(pred_3, columns=['pred_3'])

    # Nivel 4
    X_test4 = test_set_level4(scaler4, X_test4, pred_df_level1, pred_df_level2, pred_df_level3, atc_level1_labels_encoder4, atc_level2_labels_encoder4, atc_level3_labels_encoder4)
    pred_4 = sample_prediction(model4, X_test4, y_labels_encoder4, previous_predictions['pred_4'] if previous_predictions is not None else None, index)
    pred_df_level4 = pd.DataFrame(pred_4, columns=['pred_4'])

    return pred_df_level1, pred_df_level2, pred_df_level3, pred_df_level4

# %%
# Predict probabilities
def random_predictions(scaler1, scaler2, scaler3, scaler4, model1, X_test1, model2, X_test2, model3, X_test3, model4, X_test4, y_labels_encoder2, y_labels_encoder3, y_labels_encoder4, atc_level1_labels_encoder2, atc_level1_labels_encoder3, atc_level2_labels_encoder3, atc_level1_labels_encoder4, atc_level2_labels_encoder4, atc_level3_labels_encoder4):
    final_predictions = [[] for _ in range(len(X_test1))]
    max_attempts = 30
    for i in range(10):
        pred_df_level1, pred_df_level2, pred_df_level3, pred_df_level4 = generate_predictions(scaler1, scaler2, scaler3, scaler4, model1, X_test1, model2, X_test2, model3, X_test3, model4, X_test4, y_labels_encoder2, y_labels_encoder3, y_labels_encoder4,  atc_level1_labels_encoder2, atc_level1_labels_encoder3, atc_level2_labels_encoder3, atc_level1_labels_encoder4, atc_level2_labels_encoder4, atc_level3_labels_encoder4)

        for index in range(len(pred_df_level1)):
            attempts = 0
            while attempts < max_attempts:
                pred1 = pred_df_level1.at[index, 'pred_1']
                pred2 = str(pred_df_level2.at[index, "pred_2"]).zfill(2)
                pred3 = pred_df_level3.at[index, "pred_3"]
                pred4 = pred_df_level4.at[index, "pred_4"]
                prediction = pred1 + pred2 + pred3 + pred4

                if prediction not in final_predictions[index]:
                    final_predictions[index].append(prediction)
                    break  # Salimos del bucle cuando obtenemos una predicción nueva

                print(f"Prediction {prediction} already found in {final_predictions[index]}, reclassifying index {index}...")
                previous_predictions = pd.concat([pred_df_level1, pred_df_level2, pred_df_level3, pred_df_level4], axis = 1)
                # Recalcular la clasificación completa solo para este índice
                pred_df_level1, pred_df_level2, pred_df_level3, pred_df_level4 = generate_predictions(scaler1, scaler2, scaler3, scaler4, model1, X_test1, model2, X_test2, model3, X_test3, model4, X_test4, y_labels_encoder2, y_labels_encoder3, y_labels_encoder4, atc_level1_labels_encoder2, atc_level1_labels_encoder3, atc_level2_labels_encoder3, atc_level1_labels_encoder4, atc_level2_labels_encoder4, atc_level3_labels_encoder4, previous_predictions, index)
                attempts += 1
    return final_predictions

# %%
seed=78
set_seeds(seed)
X_train1, y_train1, X_test1, y_test1 = train_test_1(seed)
X_train2, y_train2, X_test2, y_test2 = train_test_2(seed)
X_train3, y_train3, X_test3, y_test3 = train_test_3(seed)
X_train4, y_train4, X_test4, y_test4 = train_test_4(seed)
# LEVEL1
# Get all available labels describing the level 1 ATC code
labels1 = set()
for lista in y_train1:
    lista = convert_string_list(lista)
    for code in lista:
        labels1.add(code)
for lista in y_test1:
    lista = convert_string_list(lista)
    for code in lista:
        labels1.add(code)
        
labels1 = sorted(list(labels1))
mlb = MultiLabelBinarizer()
mlb.fit([labels1])
y_new = y_train1.copy()
for index, lista in enumerate(y_train1):
    y_new[index] = []
    lista = convert_string_list(lista)
    for i, label in enumerate(lista):
        y_new[index].append(lista[i])
y_categorical1 = mlb.transform(y_new)

X_train1 = np.asarray(X_train1).astype(np.float32)
y_categorical1 = np.asarray(y_categorical1).astype(np.float32)
# Complete NaN values in each column with the median
X_train1[pd.isna(X_train1)] = np.nanmedian(X_train1)
# Define an instance of the MinMaxScaler
scaler1 = MinMaxScaler()
# Fit the scaler to the data and transform it
X_train1 = scaler1.fit_transform(X_train1)

model1 = Sequential([
    (Dense(len(labels1), input_dim = X_train1.shape[1], activation = 'sigmoid'))
])

# Compile the model
model1.compile(
    loss = keras.losses.BinaryCrossentropy(),
    optimizer = keras.optimizers.Adam(learning_rate=0.005),
    metrics = ['binary_accuracy', 'binary_crossentropy']
)

# Define early stopping
callback = keras.callbacks.EarlyStopping(monitor='val_loss', patience = 5, verbose = 1)

# Train the model
history = model1.fit(
    X_train1, 
    y_categorical1, 
    epochs = 500, 
    batch_size = 32,
    validation_split = 0.15,
    callbacks = [callback], 
    verbose = 0
)
#LEVEL 2
X_train2, encoded_y_train2, labels2, y_labels_encoder2, atc_level1_labels_encoder2, scaler2 = get_X_train_level2(X_train2, y_train2)

model2 = Sequential([
    (Dense(len(labels2), input_dim = X_train2.shape[1], activation = 'sigmoid'))
])

model2.compile(
    loss = keras.losses.BinaryCrossentropy(),
    optimizer = keras.optimizers.Adam(learning_rate=0.005),
    metrics = ['binary_accuracy', 'binary_crossentropy']
)

callback = keras.callbacks.EarlyStopping(monitor='val_loss', patience = 5, verbose = 1)

history = model2.fit(
    X_train2, 
    encoded_y_train2, 
    epochs = 500, 
    batch_size = 32,
    validation_split = 0.15,
    callbacks = [callback], 
    verbose = 0
)

#LEVEL 3
X_train3, encoded_y_train3, labels3, y_labels_encoder3, atc_level1_labels_encoder3, atc_level2_labels_encoder3, scaler3 = get_X_train_level3(X_train3, y_train3)

model3 = Sequential([
    (Dense(len(labels3), input_dim = X_train3.shape[1], activation = 'sigmoid'))
])

model3.compile(
    loss = keras.losses.BinaryCrossentropy(), 
    optimizer = keras.optimizers.Adam(learning_rate=0.005),
    metrics = ['binary_accuracy', 'binary_crossentropy']
)

callback = keras.callbacks.EarlyStopping(monitor='val_loss', patience = 5, verbose = 1)

history = model3.fit(
    X_train3, 
    encoded_y_train3, 
    epochs = 500, 
    batch_size = 32,
    validation_split = 0.15,
    callbacks = [callback], 
    verbose = 0
)

#LEVEL 4
X_train4, encoded_y_train4, labels4, y_labels_encoder4, atc_level1_labels_encoder4, atc_level2_labels_encoder4, atc_level3_labels_encoder4, scaler4 = get_X_train_level4(X_train4, y_train4)

model4 = Sequential([
    (Dense(len(labels4), input_dim = X_train4.shape[1], activation = 'sigmoid'))
])

model4.compile(
    loss = keras.losses.BinaryCrossentropy(), 
    optimizer = keras.optimizers.Adam(learning_rate=0.005),
    metrics = ['binary_accuracy', 'binary_crossentropy']
)

callback = keras.callbacks.EarlyStopping(monitor='val_loss', patience = 5, verbose = 1)

history = model4.fit(
    X_train4, 
    encoded_y_train4, 
    epochs = 500, 
    batch_size = 32,
    validation_split = 0.15,
    callbacks = [callback], 
    verbose = 0
)

#TEST
X_test3.drop(labels=['ATC_level2'], axis="columns", inplace=True)
X_test4.drop(labels=['ATC_level3'], axis="columns", inplace = True)

predictions = random_predictions(scaler1, scaler2, scaler3, scaler4, model1, X_test1, model2, X_test2, model3, X_test3, model4, X_test4, y_labels_encoder2, y_labels_encoder3, y_labels_encoder4, atc_level1_labels_encoder2, atc_level1_labels_encoder3, atc_level2_labels_encoder3, atc_level1_labels_encoder4, atc_level2_labels_encoder4, atc_level3_labels_encoder4)
predictions_clean = []
for preds in predictions:
    interm = []
    for pred in preds:
        clean_pred = pred.replace('<START>', '').replace('<END>', '')
        if len(clean_pred) == 5:
            interm.append(clean_pred)
    if len(interm) == 10:
        predictions_clean.append(interm)
    else: 
        print("The model predicted less than 10 ATC codes of level 4 for a compound")
        predictions_clean.append(interm)
# Out:
# C:\Users\trini\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 51: early stopping
# C:\Users\trini\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 28: early stopping
# C:\Users\trini\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 32: early stopping
# C:\Users\trini\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 22: early stopping
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 849us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 749us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# Prediction L01XX already found in ['L01XX'], reclassifying index 8...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 804us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 950us/step
# Prediction B05AB already found in ['B05AB'], reclassifying index 13...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 746us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 758us/step
# Prediction J01DD already found in ['J01DD'], reclassifying index 59...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 754us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 729us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 799us/step
# Prediction A03FB already found in ['A03FB'], reclassifying index 78...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 883us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step
# Prediction S01GA already found in ['S01GA'], reclassifying index 140...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 697us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 801us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 701us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# Prediction J05AB already found in ['J05AB'], reclassifying index 173...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 777us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 827us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 776us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step
# Prediction J01DD already found in ['J01DD'], reclassifying index 230...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 846us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# Prediction J01DD already found in ['J01DD'], reclassifying index 234...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 749us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 847us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 801us/step
# Prediction J01DD already found in ['J01DD'], reclassifying index 234...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 701us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 751us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 751us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# Prediction N05AX already found in ['N05AX'], reclassifying index 258...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 777us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 900us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# Prediction J01DB already found in ['J01DB'], reclassifying index 376...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Prediction J01DC already found in ['J01DC'], reclassifying index 416...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 849us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# Prediction J01DC already found in ['J01DC'], reclassifying index 416...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 703us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 803us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 950us/step
# Prediction G01AA already found in ['G01AA'], reclassifying index 459...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 802us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 851us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 777us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 797us/step
# Prediction J01DD already found in ['J01DD'], reclassifying index 483...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 772us/step
# Prediction J01DD already found in ['J01DD'], reclassifying index 483...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 651us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 600us/step
# Prediction G04AA already found in ['G04AA'], reclassifying index 487...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 656us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 944us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 774us/step
# Prediction M02AA already found in ['M02AA'], reclassifying index 514...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 600us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 600us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 803us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 787us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 550us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 685us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 708us/step
# Prediction N05AX already found in ['L01XX', 'N05AX'], reclassifying index 8...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 600us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 704us/step
# Prediction L01EM already found in ['L01EM', 'L01EG'], reclassifying index 27...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 676us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 684us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 714us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# Prediction J01DC already found in ['J01DC', 'J01DB'], reclassifying index 48...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 698us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 596us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 594us/step
# Prediction N06AX already found in ['N06AX', 'G01AE'], reclassifying index 54...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 663us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 673us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 755us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 684us/step
# Prediction C04BA already found in ['C04BA', 'N04AM'], reclassifying index 55...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 772us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 701us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 841us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 769us/step
# Prediction N05BX already found in ['N05BX', 'N05BG'], reclassifying index 128...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 620us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 781us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 720us/step
# Prediction R06AX already found in ['R01AB', 'R06AX'], reclassifying index 161...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 653us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 649us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 754us/step
# Prediction N05BD already found in ['N05AD', 'N05BD'], reclassifying index 169...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 685us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 600us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# Prediction J01AD already found in ['J01AD', 'L01DD'], reclassifying index 187...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 550us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 550us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 600us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 714us/step
# Prediction J01AD already found in ['J01AD', 'L01DD'], reclassifying index 187...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 744us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 696us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 776us/step
# Prediction G01AC already found in ['G01AD', 'G01AC'], reclassifying index 229...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 817us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step
# Prediction J01DC already found in ['J01DD', 'J01DC'], reclassifying index 230...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 630us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 703us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 551us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 651us/step
# Prediction N05BA already found in ['N05BA', 'N01BA'], reclassifying index 321...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 740us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 651us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 697us/step
# Prediction N06AX already found in ['N06AX', 'N06AD'], reclassifying index 338...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 765us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 549us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 762us/step
# Prediction N06AX already found in ['N06AX', 'N06AD'], reclassifying index 338...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 596us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 731us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# Prediction S01FA already found in ['S01FA', 'S01AA'], reclassifying index 354...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 603us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 686us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# Prediction N05AD already found in ['N02AX', 'N05AD'], reclassifying index 356...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 796us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 740us/step
# Prediction R06AD already found in ['N06AA', 'R06AD'], reclassifying index 361...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 597us/step
# Prediction A03CA already found in ['A03CA', 'N05BA'], reclassifying index 434...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 899us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 651us/step
# Prediction N06BA already found in ['N06BA', 'N01XA'], reclassifying index 461...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 798us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# Prediction J01CR already found in ['J01CR', 'J01AR'], reclassifying index 464...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# Prediction J01DD already found in ['J01DD', 'J01CD'], reclassifying index 469...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 649us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 799us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 751us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 705us/step
# Prediction H03AB already found in ['G03AA', 'H03AB'], reclassifying index 496...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 851us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 775us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# Prediction A03AB already found in ['A03AB', 'D11AB'], reclassifying index 507...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 649us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 677us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 725us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# Prediction N06AX already found in ['N06AX', 'N07XX'], reclassifying index 522...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 704us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 751us/step
# Prediction B06AD already found in ['C06KD', 'B06AD'], reclassifying index 573...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 653us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 799us/step
# Prediction S01AB already found in ['C07AB', 'S01AB'], reclassifying index 607...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 697us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step
# Prediction R06AX already found in ['C01GX', 'R06AX'], reclassifying index 620...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 600us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 751us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 727us/step
# Prediction R06AX already found in ['C01GX', 'R06AX'], reclassifying index 620...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 651us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 751us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 791us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 753us/step
# Prediction L01CC already found in ['L01AC', 'S01CC', 'L01CC'], reclassifying index 26...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 697us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# Prediction S01AA already found in ['S01AA', 'P01DB', 'P01BB'], reclassifying index 34...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 749us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 712us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 702us/step
# Prediction D01AB already found in ['D01AB', 'J01AC', 'J01AF'], reclassifying index 63...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 701us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# Prediction B01AX already found in ['D01AE', 'B01AX', 'N02AX'], reclassifying index 69...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 701us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 758us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# Prediction J01AG already found in ['J01AG', 'D07AA', 'D06AA'], reclassifying index 72...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 797us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 812us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step
# Prediction N06AX already found in ['N06AX', 'R06AA', 'N06AE'], reclassifying index 83...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 753us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 827us/step
# Prediction N06AX already found in ['N06AX', 'N05BB', 'N05BX'], reclassifying index 90...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 859us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 804us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 745us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# Prediction G04AA already found in ['N05CA', 'L04BA', 'G04AA'], reclassifying index 94...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 825us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# Prediction J01XA already found in ['J01XA', 'J01XX', 'A01AA'], reclassifying index 105...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 798us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 753us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 803us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# Prediction S01FA already found in ['L01AA', 'L01FA', 'S01FA'], reclassifying index 106...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 746us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step
# Prediction M03AA already found in ['S01CA', 'M03AA', 'S01AX'], reclassifying index 196...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 746us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 856us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 847us/step
# Prediction G01AE already found in ['G01AE', 'A11AA', 'A06AX'], reclassifying index 199...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 697us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 751us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 776us/step
# Prediction N01AB already found in ['L01AB', 'N01AB', 'N01BB'], reclassifying index 204...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 802us/step
# Prediction J01DC already found in ['J01DD', 'J01DC', 'J01AR'], reclassifying index 230...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 851us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 751us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 801us/step
# Prediction J01DD already found in ['J01DD', 'J01AE', 'J01DC'], reclassifying index 234...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 801us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 804us/step
# Prediction J01CR already found in ['J01CR', 'J01CA', 'J05CR'], reclassifying index 281...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 900us/step
# Prediction J01CR already found in ['J01CR', 'J01CA', 'J05CR'], reclassifying index 281...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1000us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 825us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 950us/step
# Prediction D01AC already found in ['D01AH', 'P02AF', 'D01AC'], reclassifying index 312...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 711us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 999us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step
# Prediction N02BX already found in ['N03CA', 'N02BX', 'L01ED'], reclassifying index 335...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 897us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 701us/step
# Prediction J01FA already found in ['S01FA', 'S01AA', 'J01FA'], reclassifying index 354...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 801us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# Prediction J01DD already found in ['J01DB', 'J01DD', 'J09DA'], reclassifying index 400...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# Prediction G04AD already found in ['G01BB', 'G04AD', 'H01BB'], reclassifying index 415...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 746us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# Prediction J01DD already found in ['J01DC', 'J01DD', 'J01BC'], reclassifying index 416...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 802us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 751us/step
# Prediction P01BA already found in ['P02CX', 'P01BA', 'C01DB'], reclassifying index 424...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 696us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 896us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 702us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 796us/step
# Prediction C01FB already found in ['C08AA', 'D08AA', 'C01FB'], reclassifying index 449...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 696us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 754us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 646us/step
# Prediction N05BB already found in ['P01CB', 'N05BF', 'N05BB'], reclassifying index 451...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 797us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 675us/step
# Prediction G01AB already found in ['G01AA', 'G01AB', 'G01DC'], reclassifying index 459...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 721us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 776us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 852us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 647us/step
# Prediction J01DD already found in ['J01DD', 'J01DB', 'J01DC'], reclassifying index 483...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# Prediction J01DD already found in ['J01DD', 'J01DB', 'J01DC'], reclassifying index 483...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 875us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 950us/step
# Prediction R06AB already found in ['R05AA', 'N06AA', 'R06AB'], reclassifying index 523...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 727us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# Prediction N06AA already found in ['R05AA', 'N06AA', 'R06AB'], reclassifying index 523...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 900us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 950us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# Prediction N05AB already found in ['R05AA', 'N05AB', 'N05BB'], reclassifying index 550...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 897us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 726us/step
# Prediction J01DD already found in ['J01DC', 'J01DD', 'J01AB'], reclassifying index 570...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 849us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 950us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 976us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# Prediction J01DD already found in ['J01DC', 'J01DD', 'J01AB'], reclassifying index 570...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 900us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 801us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 649us/step
# Prediction J01DD already found in ['J01DC', 'J01DD', 'J01AB'], reclassifying index 570...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 716us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 777us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 788us/step
# Prediction M02AB already found in ['M01BC', 'D01AA', 'M02AB'], reclassifying index 614...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 798us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 903us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 823us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 727us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 709us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# Prediction L01AA already found in ['L01BA', 'L01AA', 'L01BF', 'L01AB'], reclassifying index 3...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 704us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 798us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 825us/step
# Prediction N06BX already found in ['N05AY', 'N06BX', 'L01EB', 'R06DB'], reclassifying index 6...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 754us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 825us/step
# Prediction B05AB already found in ['B05AB', 'A11GB', 'P02AG', 'D11AC'], reclassifying index 13...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 726us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 701us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# Prediction A03BB already found in ['S01BB', 'R06AB', 'S01BA', 'A03BB'], reclassifying index 21...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 950us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step
# Prediction J05AD already found in ['J05AD', 'G04CD', 'C05DB', 'P01AD'], reclassifying index 42...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 747us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 801us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 765us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# Prediction J01DD already found in ['J01DC', 'J01DB', 'J01DX', 'J01DD'], reclassifying index 48...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 797us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step
# Prediction J01DD already found in ['J01DC', 'J01DB', 'J01DX', 'J01DD'], reclassifying index 48...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 746us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# Prediction J01DC already found in ['J01DC', 'J01DB', 'J01DX', 'J01DD'], reclassifying index 48...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# Prediction J01DC already found in ['J01DC', 'J01DB', 'J01DX', 'J01DD'], reclassifying index 48...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Prediction C02CA already found in ['N03BC', 'N02BA', 'S03CA', 'C02CA'], reclassifying index 51...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# Prediction G01AE already found in ['N06AX', 'G01AE', 'N01AD', 'C01AG'], reclassifying index 54...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 851us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step
# Prediction J01DD already found in ['J01DD', 'J01ED', 'A01DB', 'J01DE'], reclassifying index 59...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# Prediction J01DD already found in ['J01DD', 'J01ED', 'A01DB', 'J01DE'], reclassifying index 59...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 899us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 760us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 759us/step
# Prediction R05AD already found in ['R05AD', 'R05AB', 'R05DB', 'N06AA'], reclassifying index 60...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 799us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# Prediction R05AD already found in ['R05AD', 'R05AB', 'R05DB', 'N06AA'], reclassifying index 60...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 646us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 698us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step
# Prediction G04AD already found in ['D08AX', 'D01XX', 'L05BB', 'G04AD'], reclassifying index 71...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 736us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 701us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# Prediction R03AD already found in ['A03FB', 'S03BB', 'R01AB', 'R03AD'], reclassifying index 78...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 746us/step
# Prediction J01XA already found in ['J01XA', 'J01XX', 'A01AA', 'J01AA'], reclassifying index 105...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 851us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 699us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# Prediction J01XA already found in ['J01XA', 'J01XX', 'A01AA', 'J01AA'], reclassifying index 105...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 751us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 775us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 747us/step
# Prediction J01AA already found in ['J01XA', 'J01XX', 'A01AA', 'J01AA'], reclassifying index 105...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 746us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# Prediction C08AA already found in ['C01FA', 'C01BB', 'C01BA', 'C08AA'], reclassifying index 113...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 726us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1000us/step
# Prediction R05BA already found in ['N05AB', 'N05BD', 'R05BA', 'R06AA'], reclassifying index 138...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 799us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 622us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# Prediction L01AE already found in ['L01AE', 'L01XX', 'A05AD', 'L01CE'], reclassifying index 166...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 697us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 875us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 797us/step
# Prediction G01AE already found in ['P01FA', 'S01ED', 'A10BA', 'G01AE'], reclassifying index 170...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 746us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# Prediction J01AD already found in ['J01AD', 'L01DD', 'J01DD', 'J01BB'], reclassifying index 187...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 600us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 651us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 646us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 799us/step
# Prediction N05CB already found in ['N05AM', 'N05BB', 'N05BA', 'N05CB'], reclassifying index 189...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 853us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# Prediction R06AD already found in ['N06BX', 'R01AK', 'R06AD', 'N02BD'], reclassifying index 192...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 749us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 726us/step
# Prediction L01XX already found in ['P01AX', 'L01XX', 'A06EX', 'A10AK'], reclassifying index 202...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 646us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step
# Prediction N01AB already found in ['L01AB', 'N01AB', 'N01BB', 'N03AB'], reclassifying index 204...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# Prediction N05AB already found in ['N05BB', 'C02AA', 'N05AB', 'C05AB'], reclassifying index 212...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 766us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# Prediction H05AX already found in ['H05CX', 'H05AX', 'H02CX', 'S01AE'], reclassifying index 228...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 701us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 925us/step
# Prediction N05AA already found in ['N05AA', 'N06BA', 'C05BA', 'N05BA'], reclassifying index 236...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# Prediction G03AA already found in ['G03AA', 'H03CA', 'H02CB', 'H03CB'], reclassifying index 264...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 976us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step
# Prediction J01CR already found in ['J01CA', 'J01CX', 'J01AF', 'J01CR'], reclassifying index 270...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 860us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 950us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 900us/step
# Prediction J01CR already found in ['J01CA', 'J01CX', 'J01AF', 'J01CR'], reclassifying index 270...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 827us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 900us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 876us/step
# Prediction J01CR already found in ['J01CR', 'J01CA', 'J05CR', 'J01AR'], reclassifying index 281...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 878us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 900us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 900us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 780us/step
# Prediction J01CR already found in ['J01CR', 'J01CA', 'J05CR', 'J01AR'], reclassifying index 281...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 765us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 799us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 950us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 877us/step
# Prediction J01AR already found in ['J01CR', 'J01CA', 'J05CR', 'J01AR'], reclassifying index 281...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 847us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 854us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 825us/step
# Prediction J01CR already found in ['J01CR', 'J01CA', 'J05CR', 'J01AR'], reclassifying index 281...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 709us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1000us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 853us/step
# Prediction R05AA already found in ['G01GX', 'N06BA', 'R04AD', 'R05AA'], reclassifying index 320...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 851us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 801us/step
# Prediction G02LA already found in ['J05AX', 'G02LA', 'P02LX', 'P01AA'], reclassifying index 349...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step
# Prediction J01AB already found in ['D11AA', 'D01AY', 'H05AA', 'J01AB'], reclassifying index 357...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 803us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step
# Prediction J01DB already found in ['J01DB', 'J01CD', 'J01DC', 'J04AD'], reclassifying index 376...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 801us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# Prediction N05CM already found in ['L01AE', 'N05CM', 'N02AG', 'L01AF'], reclassifying index 381...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 753us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 754us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 749us/step
# Prediction V01AX already found in ['L01XD', 'V01AX', 'V03AC', 'C01CD'], reclassifying index 420...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 799us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# Prediction M03AC already found in ['C03CA', 'M03AA', 'M09AB', 'M03AC'], reclassifying index 435...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 777us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 795us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 804us/step
# Prediction N05AX already found in ['N05BB', 'N05AX', 'C04AB', 'B05AA'], reclassifying index 440...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 877us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 900us/step
# Prediction S01AD already found in ['S01EB', 'S01AD', 'D01AB', 'C03AA'], reclassifying index 445...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 899us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 721us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# Prediction M01AB already found in ['P01BF', 'A02BC', 'N06AX', 'M01AB'], reclassifying index 454...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 749us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 799us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 744us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 812us/step
# Prediction G01AA already found in ['G01AA', 'G01AB', 'G01DC', 'G01AC'], reclassifying index 459...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 845us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 804us/step
# Prediction N06AX already found in ['N06BA', 'N01XA', 'N06AX', 'R03GA'], reclassifying index 461...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 775us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 774us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# Prediction A11AA already found in ['C02BC', 'A05BA', 'H03XX', 'A11AA'], reclassifying index 466...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 900us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 699us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 697us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 776us/step
# Prediction R03BC already found in ['N06AX', 'R06AB', 'R03BC', 'R06AD'], reclassifying index 482...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 703us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# Prediction N05AD already found in ['R05CA', 'A05AG', 'A06AX', 'N05AD'], reclassifying index 485...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 876us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 797us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# Prediction L01EX already found in ['B05AA', 'J01ED', 'L01EX', 'L01BC'], reclassifying index 486...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 851us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step
# Prediction S01GX already found in ['P01BB', 'P01BA', 'S01GX', 'R05AD'], reclassifying index 493...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 803us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 701us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 876us/step
# Prediction S01GX already found in ['P01BB', 'P01BA', 'S01GX', 'R05AD'], reclassifying index 493...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 896us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 801us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 900us/step
# Prediction N05CM already found in ['N05CM', 'N05AA', 'G01FB', 'G03BB'], reclassifying index 501...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 751us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 749us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 727us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step
# Prediction J01EB already found in ['N05CA', 'J01EB', 'S01EX', 'N05CB'], reclassifying index 516...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 751us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 849us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# Prediction G03BA already found in ['G03FB', 'G03BA', 'G03FA', 'G03AA'], reclassifying index 542...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 900us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 875us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 847us/step
# Prediction G03AA already found in ['G03FB', 'G03BA', 'G03FA', 'G03AA'], reclassifying index 542...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 901us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 851us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 851us/step
# Prediction M02AB already found in ['G03CA', 'M02AB', 'P02BC', 'N03BG'], reclassifying index 543...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 776us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 745us/step
# Prediction P03AB already found in ['H01AX', 'J01AR', 'P03AB', 'N06AA'], reclassifying index 560...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 900us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# Prediction C05CA already found in ['C01CD', 'N05CX', 'C05CA', 'C01FD'], reclassifying index 563...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 751us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 778us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 950us/step
# Prediction G01AE already found in ['N01AD', 'N05BD', 'N05AD', 'G01AE'], reclassifying index 566...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 797us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 827us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# Prediction J01DC already found in ['J01DC', 'J01DD', 'J01AB', 'J01BC'], reclassifying index 570...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 747us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 799us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# Prediction J01DD already found in ['J01DC', 'J01DD', 'J01AB', 'J01BC'], reclassifying index 570...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 801us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 902us/step
# Prediction N01AB already found in ['L01AB', 'L01XX', 'N05AM', 'N01AB'], reclassifying index 628...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 796us/step
# Prediction R06AD already found in ['G01GB', 'G03BC', 'R06AD', 'N06BA'], reclassifying index 633...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 699us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# Prediction J01AR already found in ['J01AR', 'J01CE', 'J01CA', 'J01DA', 'S01CA'], reclassifying index 1...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 797us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 746us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 777us/step
# Prediction A03BA already found in ['S01BB', 'R06AB', 'S01BA', 'A03BB', 'A03BA'], reclassifying index 21...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 753us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# Prediction J01DD already found in ['J01DC', 'J01DB', 'J01DX', 'J01DD', 'J01AD'], reclassifying index 48...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 754us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 801us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 797us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# Prediction S02CA already found in ['N03BC', 'N02BA', 'S03CA', 'C02CA', 'S02CA'], reclassifying index 51...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 747us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 825us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 676us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# Prediction J01DD already found in ['J01DD', 'J01ED', 'A01DB', 'J01DE', 'J01AD'], reclassifying index 59...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 747us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 801us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# Prediction G01AA already found in ['J01AG', 'D07AA', 'D06AA', 'G01AA', 'G01FB'], reclassifying index 72...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 975us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 701us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 799us/step
# Prediction R06AB already found in ['N06AX', 'R06AA', 'N06AE', 'R06AB', 'D06AA'], reclassifying index 83...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 820us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# Prediction C05DB already found in ['C05DB', 'P01AA', 'C05AB', 'C01DA', 'D05AE'], reclassifying index 98...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# Prediction C02BA already found in ['C03CX', 'A11AX', 'C03AA', 'C01CB', 'C02BA'], reclassifying index 100...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 747us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 775us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# Prediction J01AA already found in ['J01XA', 'J01XX', 'A01AA', 'J01AA', 'S01XA'], reclassifying index 105...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 877us/step
# Prediction A01AA already found in ['J01XA', 'J01XX', 'A01AA', 'J01AA', 'S01XA'], reclassifying index 105...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 801us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 675us/step
# Prediction G01BC already found in ['G01BC', 'H03AB', 'H03CC', 'G03AA', 'G03FB'], reclassifying index 125...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 876us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 653us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 729us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# Prediction C05AB already found in ['G01AE', 'C05AB', 'G01AD', 'D05AX', 'G03AC'], reclassifying index 146...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 747us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# Prediction C08CA already found in ['C09AB', 'C10BX', 'C08CA', 'C01CA', 'L01AF'], reclassifying index 158...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 651us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 673us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 904us/step
# Prediction N06AX already found in ['R06AB', 'D04BC', 'N06BX', 'G01AC', 'N06AX'], reclassifying index 160...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 753us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# Prediction L01EB already found in ['J01AD', 'L01DD', 'J01DD', 'J01BB', 'L01EB'], reclassifying index 187...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 651us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# Prediction J01AD already found in ['J01AD', 'L01DD', 'J01DD', 'J01BB', 'L01EB'], reclassifying index 187...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 597us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 899us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# Prediction D07AB already found in ['D07BC', 'D02BA', 'S01AA', 'D07AB', 'H05BB'], reclassifying index 197...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 747us/step
# Prediction J01DD already found in ['J01DD', 'J01AE', 'J01DC', 'J01DB', 'A01DC'], reclassifying index 234...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 797us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 795us/step
# Prediction J01DD already found in ['J01DD', 'J01AE', 'J01DC', 'J01DB', 'A01DC'], reclassifying index 234...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 727us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# Prediction S01FB already found in ['L01ED', 'A05AD', 'L02BB', 'S01ED', 'S01FB'], reclassifying index 240...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 647us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# Prediction J01DD already found in ['J01DB', 'J09AX', 'J05DB', 'J01DD', 'J01DC'], reclassifying index 246...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 699us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 775us/step
# Prediction J01DD already found in ['J01DB', 'J09AX', 'J05DB', 'J01DD', 'J01DC'], reclassifying index 246...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 762us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# Prediction J01DD already found in ['J01DB', 'J09AX', 'J05DB', 'J01DD', 'J01DC'], reclassifying index 246...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 799us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 726us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 681us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# Prediction J01DD already found in ['J01DB', 'J09AX', 'J05DB', 'J01DD', 'J01DC'], reclassifying index 246...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 900us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# ...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 747us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 703us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 799us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 952us/step
# Prediction P01BB already found in ['R03AA', 'P01BB', 'S02BA', 'L01EX', 'L01BC', 'S01BC', 'P01BX', 'N05AX', 'R01GX'], reclassifying index 323...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 695us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# Prediction P03AB already found in ['P03AB', 'P03BX', 'P01AA', 'P03AK', 'P01BB', 'A05AB', 'P01BX', 'P01AF', 'P03BC'], reclassifying index 331...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 747us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# Prediction N05CA already found in ['N03CB', 'N05CB', 'N05AX', 'N05CA', 'G01BB', 'D11AX', 'D08AX', 'A11AB', 'R05AB'], reclassifying index 340...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 647us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 797us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 649us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 603us/step
# Prediction S01BA already found in ['C07CA', 'L01AB', 'L02AB', 'H01AC', 'G01AD', 'L01BB', 'S01BC', 'D07AB', 'S01BA'], reclassifying index 366...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 699us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 803us/step
# Prediction A01BA already found in ['A10AA', 'L01AE', 'A02BB', 'A06AA', 'G01AX', 'A07AB', 'A01BA', 'H05BB', 'H05AB'], reclassifying index 374...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 704us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 949us/step
# Prediction R05AB already found in ['R05CD', 'N02AX', 'S01BB', 'R05AB', 'R06AB', 'N05CD', 'A11HA', 'P03BB', 'C04BX'], reclassifying index 390...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 653us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 703us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 698us/step
# Prediction R05CD already found in ['R05CD', 'N02AX', 'S01BB', 'R05AB', 'R06AB', 'N05CD', 'A11HA', 'P03BB', 'C04BX'], reclassifying index 390...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1000us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# Prediction H01CC already found in ['H01XX', 'H01CC', 'H01CB', 'L01CC', 'L01XE', 'S05CA', 'H01BB', 'H09BA', 'L01XX'], reclassifying index 395...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 853us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 747us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 847us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# Prediction J01DB already found in ['J01DB', 'J01DD', 'J09DA', 'J11DC', 'J01DC', 'J01DA', 'J01CD', 'J09DB', 'J01DX'], reclassifying index 400...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 752us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 854us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 747us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 697us/step
# Prediction J01DC already found in ['J01DB', 'J01DD', 'J09DA', 'J11DC', 'J01DC', 'J01DA', 'J01CD', 'J09DB', 'J01DX'], reclassifying index 400...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 730us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 729us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 900us/step
# Prediction B01AA already found in ['C08CA', 'P02AA', 'P02AX', 'B01AA', 'H02CA', 'D08AA', 'C02AC', 'B05XA', 'B02AA'], reclassifying index 403...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 699us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 751us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 701us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 803us/step
# Prediction B02AA already found in ['C08CA', 'P02AA', 'P02AX', 'B01AA', 'H02CA', 'D08AA', 'C02AC', 'B05XA', 'B02AA'], reclassifying index 403...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 698us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 903us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 852us/step
# Prediction J01DX already found in ['J01DC', 'J01DD', 'J01BC', 'J01DB', 'J01AD', 'J05AX', 'J01DX', 'J05DB', 'J05DX'], reclassifying index 416...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 703us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 749us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# Prediction J01DC already found in ['J01DC', 'J01DD', 'J01BC', 'J01DB', 'J01AD', 'J05AX', 'J01DX', 'J05DB', 'J05DX'], reclassifying index 416...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 753us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 803us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# Prediction V01AD already found in ['L01XD', 'V01AX', 'V03AC', 'C01CD', 'V01AD', 'N05AD', 'B05XA', 'C01AC', 'C01DD'], reclassifying index 420...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 593us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 698us/step
# Prediction C03AA already found in ['C03CA', 'M03AA', 'M09AB', 'M03AC', 'A03BC', 'C03AA', 'M09AX', 'C09EB', 'R09CC'], reclassifying index 435...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 576us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 601us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 951us/step
# Prediction B01AC already found in ['D11AA', 'B01AA', 'B01XA', 'N05AB', 'D05AB', 'N05AX', 'B01AC', 'G04BD', 'D04AB'], reclassifying index 436...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 678us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 727us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 613us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# Prediction H01BC already found in ['R03DA', 'R02AB', 'H01BC', 'S01BC', 'S01BD', 'R01AB', 'R05DD', 'S01AD', 'S01DA'], reclassifying index 441...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 625us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 698us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 725us/step
# Prediction J01CD already found in ['J01CR', 'J01AR', 'J01CD', 'J01CE', 'J01CA', 'J01DB', 'J01CF', 'J01DD', 'J05CR'], reclassifying index 464...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 751us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 751us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 626us/step
# Prediction A03EB already found in ['A11AH', 'A03AC', 'L01AC', 'A02CC', 'M03BB', 'A03EB', 'C03EL', 'M03AH', 'C03EA'], reclassifying index 474...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 777us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 678us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step
# Prediction R03AB already found in ['N06AX', 'R06AB', 'R03BC', 'R06AD', 'R03AB', 'P01BA', 'R06BX', 'A03AB', 'R03DB'], reclassifying index 482...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 782us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 751us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# Prediction J01DD already found in ['J01DD', 'J01DB', 'J01DC', 'S01DC', 'S01DA', 'J05DD', 'J01DA', 'J01AC', 'H01DC'], reclassifying index 483...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 600us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 796us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 600us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 675us/step
# Prediction J01DB already found in ['J01DD', 'J01DB', 'J01DC', 'S01DC', 'S01DA', 'J05DD', 'J01DA', 'J01AC', 'H01DC'], reclassifying index 483...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 749us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 702us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 851us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 777us/step
# Prediction S01GX already found in ['P01BB', 'P01BA', 'S01GX', 'R05AD', 'R03AX', 'N05BA', 'S01EX', 'N01AC', 'C05AX'], reclassifying index 493...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 595us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 600us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 600us/step
# Prediction G03AA already found in ['G03AA', 'H03AB', 'L03DB', 'G03BB', 'H01BA', 'G03CC', 'G01AA', 'H03AC', 'G03FA'], reclassifying index 496...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 600us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# Prediction G03AA already found in ['G03AA', 'H03AB', 'L03DB', 'G03BB', 'H01BA', 'G03CC', 'G01AA', 'H03AC', 'G03FA'], reclassifying index 496...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 758us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 804us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 705us/step
# Prediction N05AA already found in ['N05CM', 'N05AA', 'G01FB', 'G03BB', 'G03AB', 'G03CA', 'G03AA', 'N03CC', 'N03AA'], reclassifying index 501...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 760us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# Prediction C10BX already found in ['C10BX', 'C09BX', 'M01AX', 'J01AC', 'M09AA', 'J05AB', 'C07AX', 'M09BA', 'D10BB'], reclassifying index 502...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 797us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 675us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# Prediction N06AX already found in ['N06AX', 'D04AC', 'R06AX', 'H01FB', 'R05AL', 'R05AB', 'R06AD', 'D01BA', 'R01AD'], reclassifying index 512...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 600us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# Prediction N06AF already found in ['R05AA', 'N06AA', 'R06AB', 'N05AM', 'N05AA', 'R05CA', 'N06AD', 'N05CD', 'N06AF'], reclassifying index 523...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 751us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 603us/step
# Prediction B01BA already found in ['M03AA', 'B03BA', 'S03BA', 'B03AA', 'B01BE', 'B01AE', 'M03BA', 'B03AE', 'B01BA'], reclassifying index 533...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 704us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 704us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 754us/step
# Prediction B03BA already found in ['M03AA', 'B03BA', 'S03BA', 'B03AA', 'B01BE', 'B01AE', 'M03BA', 'B03AE', 'B01BA'], reclassifying index 533...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 701us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 754us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 753us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# Prediction B03BA already found in ['M03AA', 'B03BA', 'S03BA', 'B03AA', 'B01BE', 'B01AE', 'M03BA', 'B03AE', 'B01BA'], reclassifying index 533...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# Prediction B03BA already found in ['M03AA', 'B03BA', 'S03BA', 'B03AA', 'B01BE', 'B01AE', 'M03BA', 'B03AE', 'B01BA'], reclassifying index 533...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 703us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 847us/step
# Prediction B03BA already found in ['M03AA', 'B03BA', 'S03BA', 'B03AA', 'B01BE', 'B01AE', 'M03BA', 'B03AE', 'B01BA'], reclassifying index 533...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 646us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# Prediction B03BA already found in ['M03AA', 'B03BA', 'S03BA', 'B03AA', 'B01BE', 'B01AE', 'M03BA', 'B03AE', 'B01BA'], reclassifying index 533...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 751us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 753us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# Prediction M03BA already found in ['M03AA', 'B03BA', 'S03BA', 'B03AA', 'B01BE', 'B01AE', 'M03BA', 'B03AE', 'B01BA'], reclassifying index 533...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 797us/step
# Prediction B03BA already found in ['M03AA', 'B03BA', 'S03BA', 'B03AA', 'B01BE', 'B01AE', 'M03BA', 'B03AE', 'B01BA'], reclassifying index 533...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 796us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 701us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 806us/step
# Prediction J01MB already found in ['R05CA', 'P02AC', 'N01BD', 'J01AD', 'J05AE', 'D01MA', 'P01BB', 'J01MB', 'R05AB'], reclassifying index 535...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 701us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 746us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# Prediction G01GB already found in ['S01GX', 'D06AX', 'C02BA', 'G01BE', 'C09BA', 'G01GB', 'R03AC', 'R06BX', 'S01BA'], reclassifying index 539...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 898us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 702us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 651us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# Prediction A06AA already found in ['A11AG', 'D06AX', 'H01AX', 'H06AX', 'A06AA', 'H01AB', 'A06AX', 'A06AB', 'J01AX'], reclassifying index 554...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 902us/step
# Prediction H01AX already found in ['A11AG', 'D06AX', 'H01AX', 'H06AX', 'A06AA', 'H01AB', 'A06AX', 'A06AB', 'J01AX'], reclassifying index 554...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 698us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 803us/step
# Prediction H01AX already found in ['A11AG', 'D06AX', 'H01AX', 'H06AX', 'A06AA', 'H01AB', 'A06AX', 'A06AB', 'J01AX'], reclassifying index 554...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 648us/step
# Prediction J01DD already found in ['J01DC', 'J01DD', 'J01AB', 'J01BC', 'J01DB', 'J05DD', 'A01DD', 'R01DA', 'A01CD'], reclassifying index 570...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 747us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 796us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 696us/step
# Prediction J01DD already found in ['J01DC', 'J01DD', 'J01AB', 'J01BC', 'J01DB', 'J05DD', 'A01DD', 'R01DA', 'A01CD'], reclassifying index 570...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 784us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 753us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 799us/step
# Prediction N05AD already found in ['N05AD', 'S01BA', 'N05AC', 'A02BB', 'R05AA', 'G01AD', 'A11AA', 'N04BA', 'N01BG'], reclassifying index 592...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 694us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 600us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# Prediction G01AF already found in ['R05AD', 'L01AX', 'D01AC', 'C05AD', 'D01AB', 'L01XX', 'N05AB', 'C07AC', 'G01AF'], reclassifying index 608...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 801us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# Prediction N06BX already found in ['M02AE', 'N05AX', 'N06AX', 'D11AX', 'N03AD', 'N06BX', 'N05BH', 'G03AX', 'A02AD'], reclassifying index 627...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 696us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 751us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 924us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# Prediction R06AX already found in ['R06AX', 'A03EA', 'D06AX', 'A02BB', 'R06AD', 'S01XB', 'C09AA', 'C02AB', 'S01GA'], reclassifying index 629...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 699us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 954us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 801us/step
# Prediction J01AB already found in ['J01AB', 'R05DB', 'J01XB', 'J01XA', 'L01AF', 'A10BA', 'L01XY', 'J01RA', 'A07AB'], reclassifying index 634...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 698us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 747us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 803us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 754us/step
# Prediction N05CB already found in ['N03BX', 'R05AX', 'N05CA', 'R03BB', 'D11CX', 'N01BD', 'N06CB', 'N05CB', 'C01AA'], reclassifying index 639...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 701us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 746us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 753us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 900us/step

# %%
precisions1, recalls1, f1s1 = defined_metrics.complete_metrics(predictions_clean, f'test_set.csv', 'ATC Codes', 1)
precisions2, recalls2, f1s2 = defined_metrics.complete_metrics(predictions_clean, f'test_set.csv', 'ATC Codes', 2)
precisions3, recalls3, f1s3 = defined_metrics.complete_metrics(predictions_clean, f'test_set.csv', 'ATC Codes', 3)
precisions4, recalls4, f1s4 = defined_metrics.complete_metrics(predictions_clean, f'test_set.csv', 'ATC Codes', 4)
precisions5, recalls5, f1s5 = defined_metrics.complete_metrics(predictions_clean, f'test_set.csv', 'ATC Codes', 5)
precisions6, recalls6, f1s6 = defined_metrics.complete_metrics(predictions_clean, f'test_set.csv', 'ATC Codes', 6)
precisions7, recalls7, f1s7 = defined_metrics.complete_metrics(predictions_clean, f'test_set.csv', 'ATC Codes', 7)
precisions8, recalls8, f1s8 = defined_metrics.complete_metrics(predictions_clean, f'test_set.csv', 'ATC Codes', 8)
precisions9, recalls9, f1s9 = defined_metrics.complete_metrics(predictions_clean, f'test_set.csv', 'ATC Codes', 9)
precisions10, recalls10, f1s10 = defined_metrics.complete_metrics(predictions_clean, f'test_set.csv', 'ATC Codes', 10)

precisions_average1 = sum(precisions1)/len(precisions1)
recalls_average1 = sum(recalls1)/len(recalls1)
f1s_average1 = sum(f1s1)/len(f1s1)

precisions_average2 = sum(precisions2)/len(precisions2)
recalls_average2 = sum(recalls2)/len(recalls2)
f1s_average2 = sum(f1s2)/len(f1s2)

precisions_average3 = sum(precisions3)/len(precisions3)
recalls_average3 = sum(recalls3)/len(recalls3)
f1s_average3 = sum(f1s3)/len(f1s3)

precisions_average4 = sum(precisions4)/len(precisions4)
recalls_average4 = sum(recalls4)/len(recalls4)
f1s_average4 = sum(f1s4)/len(f1s4)

precisions_average5 = sum(precisions5)/len(precisions5)
recalls_average5 = sum(recalls5)/len(recalls5)
f1s_average5 = sum(f1s5)/len(f1s5)

precisions_average6 = sum(precisions6)/len(precisions6)
recalls_average6 = sum(recalls6)/len(recalls6)
f1s_average6 = sum(f1s6)/len(f1s6)

precisions_average7 = sum(precisions7)/len(precisions7)
recalls_average7 = sum(recalls7)/len(recalls7)
f1s_average7 = sum(f1s7)/len(f1s7)

precisions_average8 = sum(precisions8)/len(precisions8)
recalls_average8 = sum(recalls8)/len(recalls8)
f1s_average8 = sum(f1s8)/len(f1s8)

precisions_average9 = sum(precisions9)/len(precisions9)
recalls_average9 = sum(recalls9)/len(recalls9)
f1s_average9 = sum(f1s9)/len(f1s9)

precisions_average10 = sum(precisions10)/len(precisions10)
recalls_average10 = sum(recalls10)/len(recalls10)
f1s_average10 = sum(f1s10)/len(f1s10)

# %%
precisions_average_k = []
precisions_average_k.append(precisions_average1)
precisions_average_k.append(precisions_average2)
precisions_average_k.append(precisions_average3)
precisions_average_k.append(precisions_average4)
precisions_average_k.append(precisions_average5)
precisions_average_k.append(precisions_average6)
precisions_average_k.append(precisions_average7)
precisions_average_k.append(precisions_average8)
precisions_average_k.append(precisions_average9)
precisions_average_k.append(precisions_average10)
recalls_average_k = []
recalls_average_k.append(recalls_average1)
recalls_average_k.append(recalls_average2)
recalls_average_k.append(recalls_average3)
recalls_average_k.append(recalls_average4)
recalls_average_k.append(recalls_average5)
recalls_average_k.append(recalls_average6)
recalls_average_k.append(recalls_average7)
recalls_average_k.append(recalls_average8)
recalls_average_k.append(recalls_average9)
recalls_average_k.append(recalls_average10)
f1s_average_k = []
f1s_average_k.append(f1s_average1)
f1s_average_k.append(f1s_average2)
f1s_average_k.append(f1s_average3)
f1s_average_k.append(f1s_average4)
f1s_average_k.append(f1s_average5)
f1s_average_k.append(f1s_average6)
f1s_average_k.append(f1s_average7)
f1s_average_k.append(f1s_average8)
f1s_average_k.append(f1s_average9)
f1s_average_k.append(f1s_average10)

# %%
df_results = pd.read_csv("df_metrics.csv")
new_rows = pd.DataFrame(columns=["model", "precision", "recall", "f1"])
new_rows["precision"] = precisions_average_k
new_rows["recall"] = recalls_average_k
new_rows["f1"] = f1s_average_k
new_rows["model"] = "Neural Network"
df_results = pd.concat([df_results , new_rows], ignore_index=True)
df_results.to_csv("df_metrics.csv", index= False)
