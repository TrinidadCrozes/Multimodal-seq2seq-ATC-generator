# %%
import os
import sys
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '../..')))
from seq2seq import *

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from collections import defaultdict
import seaborn as sns

from sklearn import preprocessing
from sklearn.utils import class_weight
from sklearn.preprocessing import StandardScaler, MinMaxScaler, MultiLabelBinarizer
from sklearn.model_selection import train_test_split 
from sklearn.metrics import precision_recall_curve, average_precision_score, multilabel_confusion_matrix, classification_report

import tensorflow as tf
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout

import random

# %%
def set_seeds(seed):
    np.random.seed(seed)
    random.seed(seed)
    keras.utils.set_random_seed(seed)
    tf.random.set_seed(seed)                
    os.environ["PYTHONHASHSEED"] = str(seed) 
    os.environ["TF_DETERMINISTIC_OPS"] = "1" 
    os.environ["TF_CUDNN_DETERMINISTIC"] = "1" 
# Convert a string that simulates a list to a real list
def convert_string_list(element):
    # Delete [] of the string
    element = element[1:len(element)-1]
    # Create a list that contains each code as e.g. 'A'
    ATC_list = list(element.split(', '))
    for index, code in enumerate(ATC_list):
        # Delete '' of the code
        ATC_list[index] = code[1:len(code)-1]
    return ATC_list

# %% [markdown]
# ## SETS

# %%
def train_test_1(seed):
    train_set = pd.read_csv(f'Datasets/train_set{seed}.csv')
    val_set = pd.read_csv(f'Datasets/val_set{seed}.csv')
    test_set = pd.read_csv(f'Datasets/test_set{seed}.csv')
    train_set = pd.concat([train_set, val_set], ignore_index=True)
    # Delete unnecessary columns from train set
    train_set.drop('Neutralized SMILES', axis = 1, inplace = True)
    train_set.drop('ATC Codes', axis = 1, inplace = True)
    train_set.drop('ATC_level2', axis = 1, inplace = True)
    train_set.drop('ATC_level3', axis = 1, inplace = True)
    train_set.drop('ATC_level4', axis = 1, inplace = True)
    train_set.drop('multiple_ATC', axis = 1, inplace = True)
    train_set = train_set.reset_index(drop=True)
    # Delete unnecessary columns from test set
    test_set.drop('Neutralized SMILES', axis = 1, inplace = True)
    test_set.drop('ATC Codes', axis = 1, inplace = True)
    test_set.drop('ATC_level2', axis = 1, inplace = True)
    test_set.drop('ATC_level3', axis = 1, inplace = True)
    test_set.drop('ATC_level4', axis = 1, inplace = True)
    test_set.drop('multiple_ATC', axis = 1, inplace = True)
    test_set = test_set.reset_index(drop=True)
    # Divide in X and y
    X_train = train_set.drop('ATC_level1', axis = 1)
    y_train = train_set['ATC_level1']
    X_test = test_set.drop('ATC_level1', axis = 1)
    y_test = test_set['ATC_level1']
    return X_train, y_train, X_test, y_test
def train_test_2(seed):
    train_set = pd.read_csv(f'Datasets/train_set{seed}.csv')
    val_set = pd.read_csv(f'Datasets/val_set{seed}.csv')
    test_set = pd.read_csv(f'Datasets/test_set{seed}.csv')
    train_set = pd.concat([train_set, val_set], ignore_index=True)
    # Delete unnecessary columns 
    train_set.drop('Neutralized SMILES', axis = 1, inplace = True)
    train_set.drop('ATC Codes', axis = 1, inplace = True)
    train_set.drop('ATC_level3', axis = 1, inplace = True)
    train_set.drop('ATC_level4', axis = 1, inplace = True)
    train_set.drop('multiple_ATC', axis = 1, inplace = True)
    train_set = train_set.reset_index(drop=True)
    # Delete unnecessary columns 
    test_set.drop('Neutralized SMILES', axis = 1, inplace = True)
    test_set.drop('ATC Codes', axis = 1, inplace = True)
    test_set.drop('ATC_level3', axis = 1, inplace = True)
    test_set.drop('ATC_level4', axis = 1, inplace = True)
    test_set.drop('multiple_ATC', axis = 1, inplace = True)
    test_set = test_set.reset_index(drop=True)
    # Replicate compounds that have more than 1 ATC level 1 code
    new_rows = []

    for _, row in train_set.iterrows():
        ATC_level1_list = convert_string_list(row['ATC_level1'])
        for code in ATC_level1_list:
            new_row = row.copy()
            new_row['ATC_level1'] = code
            new_rows.append(new_row)

    new_train_set = pd.DataFrame(new_rows)
    new_train_set = new_train_set.reset_index(drop=True)
    # Delete level 1 letter from ATC_level2
    new_rows = [] 
    for _, row in new_train_set.iterrows():
        ATC_level2_list = convert_string_list(row['ATC_level2'])
        # Split ATC code if they have more than 1 code at level 2
        for code in ATC_level2_list:
            if code[0] == row['ATC_level1']:
                new_row = row.copy()
                new_row['ATC_level2'] = code[1:len(code)]
                new_rows.append(new_row)

    new_train_set2 = pd.DataFrame(new_rows)
    new_train_set2 = new_train_set2.reset_index(drop=True)
    
    new_test_set2 = test_set
    
    X_train = new_train_set2.drop('ATC_level2', axis = 1)
    y_train = new_train_set2['ATC_level2']
    X_test = new_test_set2.drop('ATC_level2', axis = 1)
    y_test = new_test_set2['ATC_level2']
    
    return X_train, y_train, X_test, y_test
def train_test_3(seed):
    train_set = pd.read_csv(f'Datasets/train_set{seed}.csv')
    val_set = pd.read_csv(f'Datasets/val_set{seed}.csv')
    test_set = pd.read_csv(f'Datasets/test_set{seed}.csv')
    train_set = pd.concat([train_set, val_set], ignore_index=True)
    # Delete unnecessary columns 
    train_set.drop('Neutralized SMILES', axis = 1, inplace = True)
    train_set.drop('ATC Codes', axis = 1, inplace = True)
    train_set.drop('ATC_level1', axis = 1, inplace = True)
    train_set.drop('ATC_level4', axis = 1, inplace = True)
    train_set.drop('multiple_ATC', axis = 1, inplace = True)
    train_set = train_set.reset_index(drop=True)
    # Delete unnecessary columns 
    test_set.drop('Neutralized SMILES', axis = 1, inplace = True)
    test_set.drop('ATC Codes', axis = 1, inplace = True)
    test_set.drop('ATC_level1', axis = 1, inplace = True)
    test_set.drop('ATC_level4', axis = 1, inplace = True)
    test_set.drop('multiple_ATC', axis = 1, inplace = True)
    test_set = test_set.reset_index(drop=True)
    # Replicate compounds that have more than 1 ATC code
    new_rows = []

    for _, row in train_set.iterrows():
        ATC_level2_list = convert_string_list(row['ATC_level2'])
        for code in ATC_level2_list:
            new_row = row.copy()
            new_row['ATC_level2'] = code
            new_rows.append(new_row)

    new_train_set = pd.DataFrame(new_rows)
    new_train_set = new_train_set.reset_index(drop=True)
    # Delete level 1 letter from ATC_level2
    new_rows = [] 
    for _, row in new_train_set.iterrows():
        ATC_level3_list = convert_string_list(row['ATC_level3'])
        # Split ATC code if they have more than 1 code at level 2
        for code in ATC_level3_list:
            if code[0:3] == row['ATC_level2']:
                new_row = row.copy()
                new_row['ATC_level3'] = code[3:len(code)]
                new_rows.append(new_row)

    new_train_set2 = pd.DataFrame(new_rows)
    new_train_set2 = new_train_set2.reset_index(drop=True)

    new_test_set2 = test_set

    X_train = new_train_set2.drop('ATC_level3', axis = 1)
    y_train = new_train_set2['ATC_level3']
    X_test = new_test_set2.drop('ATC_level3', axis = 1)
    y_test = new_test_set2['ATC_level3']
    
    return X_train, y_train, X_test, y_test
def train_test_4(seed):
    train_set = pd.read_csv(f'Datasets/train_set{seed}.csv')
    val_set = pd.read_csv(f'Datasets/val_set{seed}.csv')
    test_set = pd.read_csv(f'Datasets/test_set{seed}.csv')
    train_set = pd.concat([train_set, val_set], ignore_index=True)
    # Delete unnecessary columns 
    train_set.drop('Neutralized SMILES', axis = 1, inplace = True)
    train_set.drop('ATC Codes', axis = 1, inplace = True)
    train_set.drop('ATC_level1', axis = 1, inplace = True)
    train_set.drop('ATC_level2', axis = 1, inplace = True)
    train_set.drop('multiple_ATC', axis = 1, inplace = True)
    train_set = train_set.reset_index(drop=True)
    # Delete unnecessary columns 
    test_set.drop('Neutralized SMILES', axis = 1, inplace = True)
    test_set.drop('ATC Codes', axis = 1, inplace = True)
    test_set.drop('ATC_level1', axis = 1, inplace = True)
    test_set.drop('ATC_level2', axis = 1, inplace = True)
    test_set.drop('multiple_ATC', axis = 1, inplace = True)
    test_set = test_set.reset_index(drop=True)
    # Replicate compounds that have more than 1 ATC code
    new_rows = []

    for _, row in train_set.iterrows():
        ATC_level3_list = convert_string_list(row['ATC_level3'])
        for code in ATC_level3_list:
            new_row = row.copy()
            new_row['ATC_level3'] = code
            new_rows.append(new_row)

    new_train_set = pd.DataFrame(new_rows)
    new_train_set = new_train_set.reset_index(drop=True)
    # Delete level 1 letter from ATC_level2
    new_rows = [] 
    for _, row in new_train_set.iterrows():
        ATC_level4_list = convert_string_list(row['ATC_level4'])
        # Split ATC code if they have more than 1 code at level 2
        for code in ATC_level4_list:
            if code[0:4] == row['ATC_level3']:
                if code[4:len(code)] != '':
                    new_row = row.copy()
                    new_row['ATC_level4'] = code[4:len(code)]
                    new_rows.append(new_row)

    new_train_set2 = pd.DataFrame(new_rows)
    new_train_set2 = new_train_set2.reset_index(drop=True)

    new_test_set2 = test_set

    X_train = new_train_set2.drop('ATC_level4', axis = 1)
    y_train = new_train_set2['ATC_level4']
    X_test = new_test_set2.drop('ATC_level4', axis = 1)
    y_test = new_test_set2['ATC_level4']
    
    return X_train, y_train, X_test, y_test

# %%
def get_X_train_level2(X_train2, y_train2):
    # Get all available labels describing the level 1 ATC code
    labels2 = set()
    for code in y_train2:
        labels2.add(code)
            
    labels2 = sorted(list(labels2))
    y_labels_encoder2 = MultiLabelBinarizer()
    y_labels_encoder2.fit([labels2])
    encoded_y_train2 = y_labels_encoder2.transform(y_train2.values.reshape(-1, 1))
    
    atc_level1_labels2 = set()
    for _, row in X_train2.iterrows():
        atc_level1_labels2.add(row['ATC_level1'])
            
    atc_level1_labels2 = sorted(list(atc_level1_labels2))
    atc_level1_labels_encoder2 = MultiLabelBinarizer()
    atc_level1_labels_encoder2.fit([atc_level1_labels2])
    ATC_level11 = X_train2['ATC_level1']
    ATC_level1_2 = ATC_level11.copy()
    for index, lista in enumerate(ATC_level11):
        ATC_level1_2[index] = []
        ATC_level1_2[index].append(lista)
    categorical_atc2 = atc_level1_labels_encoder2.transform(ATC_level1_2)
    X_train2.drop(labels=['ATC_level1'], axis="columns", inplace=True)
    df_level1_2 = pd.DataFrame(categorical_atc2, columns=atc_level1_labels2)
    X_train2 = pd.concat([X_train2, df_level1_2], axis = 1)
    X_train2 = np.asarray(X_train2).astype(np.float32)
    encoded_y_train2 = np.asarray(encoded_y_train2).astype(np.float32)
    # Complete NaN values in each column with the median
    X_train2[pd.isna(X_train2)] = np.nanmedian(X_train2)
    # Define an instance of the MinMaxScaler
    scaler2 = MinMaxScaler()
    # Fit the scaler to the data and transform it
    X_train2 = scaler2.fit_transform(X_train2)
    return X_train2, encoded_y_train2, labels2, y_labels_encoder2, atc_level1_labels_encoder2, scaler2

def get_X_train_level3(X_train3, y_train3):
    # Get all available labels describing the level 1 ATC code
    labels3 = set()
    for code in y_train3:
        labels3.add(code)
            
    labels3 = sorted(list(labels3))
    y_labels_encoder3 = MultiLabelBinarizer()
    y_labels_encoder3.fit([labels3])
    encoded_y_train3 = y_labels_encoder3.transform(y_train3.values.reshape(-1, 1))
    
    atc_level1_labels3 = set()
    atc_level2_labels3 = set()
    for _, row in X_train3.iterrows():
        atc_level1_labels3.add(row['ATC_level2'][0:1])
        atc_level2_labels3.add(row['ATC_level2'][1:3])
    for _, row in X_test3.iterrows():
        lista = convert_string_list(row['ATC_level2'])
        for code in lista:
            atc_level1_labels3.add(code[0:1])
            atc_level2_labels3.add(code[1:3])
            
    atc_level1_labels3 = sorted(list(atc_level1_labels3))
    atc_level2_labels3 = sorted(list(atc_level2_labels3))
    atc_level1_labels_encoder3 = MultiLabelBinarizer()
    atc_level1_labels_encoder3.fit([atc_level1_labels3])
    atc_level2_labels_encoder3 = MultiLabelBinarizer()
    atc_level2_labels_encoder3.fit([atc_level2_labels3])
    ATC_level22 = X_train3['ATC_level2']
    ATC_level1_3 = ATC_level22.copy()
    ATC_level2_3 = ATC_level22.copy()
    for index, lista in enumerate(ATC_level22):
        ATC_level1_3[index] = []
        ATC_level1_3[index].append(lista[0:1])
    for index, lista in enumerate(ATC_level22):
        ATC_level2_3[index] = []
        ATC_level2_3[index].append(lista[1:3])
    X_train3.drop(labels=['ATC_level2'], axis="columns", inplace=True)
    categorical_atc1_3 = atc_level1_labels_encoder3.transform(ATC_level1_3)
    categorical_atc2_3 = atc_level2_labels_encoder3.transform(ATC_level2_3)
    df_level1_3 = pd.DataFrame(categorical_atc1_3, columns=atc_level1_labels3)
    df_level2_3 = pd.DataFrame(categorical_atc2_3, columns=atc_level2_labels3)
    X_train3 = pd.concat([X_train3, df_level1_3, df_level2_3], axis = 1)
    X_train3 = np.asarray(X_train3).astype(np.float32)
    encoded_y_train3 = np.asarray(encoded_y_train3).astype(np.float32)
    # Complete NaN values in each column with the median
    X_train3[pd.isna(X_train3)] = np.nanmedian(X_train3)
    # Define an instance of the MinMaxScaler
    scaler3 = MinMaxScaler()
    # Fit the scaler to the data and transform it
    X_train3 = scaler3.fit_transform(X_train3)
    return X_train3, encoded_y_train3, labels3, y_labels_encoder3, atc_level1_labels_encoder3, atc_level2_labels_encoder3, scaler3

def get_X_train_level4(X_train4, y_train4):
    # Get all available labels describing the level 1 ATC code
    labels4 = set()
    for code in y_train4:
        labels4.add(code)
            
    labels4 = sorted(list(labels4))
    y_labels_encoder4 = MultiLabelBinarizer()
    y_labels_encoder4.fit([labels4])
    encoded_y_train4 = y_labels_encoder4.transform(y_train4.values.reshape(-1, 1))
    
    atc_level1_labels4 = set()
    atc_level2_labels4 = set()
    atc_level3_labels4 = set()
    for _, row in X_train4.iterrows():
        atc_level1_labels4.add(row['ATC_level3'][0:1])
        atc_level2_labels4.add(row['ATC_level3'][1:3])
        atc_level3_labels4.add(row['ATC_level3'][3:4])
    for _, row in X_test4.iterrows():
        lista = convert_string_list(row['ATC_level3'])
        for code in lista:
            atc_level1_labels4.add(code[0:1])
            atc_level2_labels4.add(code[1:3])
            atc_level3_labels4.add(code[3:4])
    
    atc_level1_labels4 = sorted(list(atc_level1_labels4))
    atc_level2_labels4 = sorted(list(atc_level2_labels4))
    atc_level3_labels4 = sorted(list(atc_level3_labels4))
    atc_level1_labels_encoder4 = MultiLabelBinarizer()
    atc_level1_labels_encoder4.fit([atc_level1_labels4])
    atc_level2_labels_encoder4 = MultiLabelBinarizer()
    atc_level2_labels_encoder4.fit([atc_level2_labels4])
    atc_level3_labels_encoder4 = MultiLabelBinarizer()
    atc_level3_labels_encoder4.fit([atc_level3_labels4])
    ATC_level33 = X_train4['ATC_level3']
    ATC_level1_4 = ATC_level33.copy()
    for index, lista in enumerate(ATC_level33):
        ATC_level1_4[index] = []
        ATC_level1_4[index].append(lista[0:1])
    ATC_level2_4 = ATC_level33.copy()
    for index, lista in enumerate(ATC_level33):
        ATC_level2_4[index] = []
        ATC_level2_4[index].append(lista[1:3])
    ATC_level3_4 = ATC_level33.copy()
    for index, lista in enumerate(ATC_level33):
        ATC_level3_4[index] = []
        ATC_level3_4[index].append(lista[3:4])
    X_train4.drop(labels=['ATC_level3'], axis="columns", inplace=True)
    categorical_atc1_4 = atc_level1_labels_encoder4.transform(ATC_level1_4)
    categorical_atc2_4 = atc_level2_labels_encoder4.transform(ATC_level2_4)
    categorical_atc3_4 = atc_level3_labels_encoder4.transform(ATC_level3_4)
    df_level1_4 = pd.DataFrame(categorical_atc1_4, columns=atc_level1_labels4)
    df_level2_4 = pd.DataFrame(categorical_atc2_4, columns=atc_level2_labels4)
    df_level3_4 = pd.DataFrame(categorical_atc3_4, columns=atc_level3_labels4)
    X_train4 = pd.concat([X_train4, df_level1_4, df_level2_4, df_level3_4], axis = 1)
    X_train4 = np.asarray(X_train4).astype(np.float32)
    encoded_y_train4 = np.asarray(encoded_y_train4).astype(np.float32)
    # Complete NaN values in each column with the median
    X_train4[pd.isna(X_train4)] = np.nanmedian(X_train4)
    # Define an instance of the MinMaxScaler
    scaler4 = MinMaxScaler()
    # Fit the scaler to the data and transform it
    X_train4 = scaler4.fit_transform(X_train4)

    return X_train4, encoded_y_train4, labels4, y_labels_encoder4, atc_level1_labels_encoder4, atc_level2_labels_encoder4, atc_level3_labels_encoder4, scaler4

# %%
def test_set_level1(scaler1, X_test):
    X_test = np.asarray(X_test).astype(np.float32)
    X_test[pd.isna(X_test)] = np.nanmedian(X_test)
    X_test = scaler1.transform(X_test)
    return X_test

# %%
def test_set_level2(scaler2, X_test1, pred_df_level1, atc_level1_labels_encoder2):
    X_test1.drop(labels=['ATC_level1'], axis="columns", inplace=True)
    X_test1['ATC_level1'] = pred_df_level1['pred_1']
    ATC_level1 = X_test1['ATC_level1']
    categorical_atc = atc_level1_labels_encoder2.transform(ATC_level1)
    df_level1 = pd.DataFrame(categorical_atc, columns=atc_level1_labels_encoder2.classes_)
    X_test1 = pd.concat([X_test1, df_level1], axis = 1)
    X_test1.drop(labels=['ATC_level1'], axis="columns", inplace=True)

    X_test1 = np.asarray(X_test1).astype(np.float32)
    X_test1[pd.isna(X_test1)] = np.nanmedian(X_test1)
    X_test1 = scaler2.transform(X_test1)

    return X_test1

# %%
def test_set_level3(scaler3, X_test1, pred_df_level1, pred_df_level2, atc_level1_labels_encoder3, atc_level2_labels_encoder3):
    predicted_codes = []
    
    for index, pred1 in enumerate(pred_df_level1['pred_1']):
        pred2 = str(pred_df_level2.at[pred_df_level2.index[index], 'pred_2']).zfill(2)
        prediction = pred1 + '' + pred2
        predicted_codes.append(prediction)
        
    X_test1['ATC_level2'] = predicted_codes
    
    ATC_level22 = X_test1['ATC_level2']
    ATC_level1_3 = ATC_level22.copy()
    ATC_level2_3 = ATC_level22.copy()
    for index, atc in enumerate(ATC_level22):
        ATC_level1_3[index] = []
        ATC_level1_3[index].append(atc[0:1])
        ATC_level2_3[index] = []
        ATC_level2_3[index].append(atc[1:3])

    X_test1 = X_test1.drop(labels=['ATC_level2'], axis="columns")
    
    categorical_atc1_3 = atc_level1_labels_encoder3.transform(ATC_level1_3)
    categorical_atc2_3 = atc_level2_labels_encoder3.transform(ATC_level2_3)
    df_level1_3 = pd.DataFrame(categorical_atc1_3, columns=atc_level1_labels_encoder3.classes_)
    df_level2_3 = pd.DataFrame(categorical_atc2_3, columns=atc_level2_labels_encoder3.classes_)
    X_test1 = pd.concat([X_test1, df_level1_3, df_level2_3], axis = 1)                         
    
    X_test1 = np.asarray(X_test1).astype(np.float32)
    X_test1[pd.isna(X_test1)] = np.nanmedian(X_test1)
    X_test1 = scaler3.transform(X_test1)

    return X_test1

# %%
def test_set_level4(scaler4, X_test1, pred_df_level1, pred_df_level2, pred_df_level3, atc_level1_labels_encoder4, atc_level2_labels_encoder4, atc_level3_labels_encoder4):
    predicted_codes = []
    
    for index, pred1 in enumerate(pred_df_level1['pred_1']):
        pred2 = str(pred_df_level2.at[pred_df_level2.index[index], 'pred_2']).zfill(2)
        pred3 = pred_df_level3.at[pred_df_level3.index[index], 'pred_3']
        prediction = pred1 + '' + pred2 + '' + pred3
        predicted_codes.append(prediction)
        
    X_test1['ATC_level3'] = predicted_codes
    
    ATC_level33 = X_test1['ATC_level3']
    ATC_level1_4 = ATC_level33.copy()
    ATC_level2_4 = ATC_level33.copy()
    ATC_level3_4 = ATC_level33.copy()
    for index, atc in enumerate(ATC_level33):
        ATC_level1_4[index] = []
        ATC_level1_4[index].append(atc[0:1])
        ATC_level2_4[index] = []
        ATC_level2_4[index].append(atc[1:3])
        ATC_level3_4[index] = []
        ATC_level3_4[index].append(atc[3:4])

    X_test1 = X_test1.drop(labels=['ATC_level3'], axis="columns")

    categorical_atc1_4 = atc_level1_labels_encoder4.transform(ATC_level1_4)
    categorical_atc2_4 = atc_level2_labels_encoder4.transform(ATC_level2_4)
    categorical_atc3_4 = atc_level3_labels_encoder4.transform(ATC_level3_4)
    df_level1_4 = pd.DataFrame(categorical_atc1_4, columns=atc_level1_labels_encoder4.classes_)
    df_level2_4 = pd.DataFrame(categorical_atc2_4, columns=atc_level2_labels_encoder4.classes_)
    df_level3_4 = pd.DataFrame(categorical_atc3_4, columns=atc_level3_labels_encoder4.classes_)
    X_test1 = pd.concat([X_test1, df_level1_4, df_level2_4, df_level3_4], axis = 1)                         
    X_test1 = np.asarray(X_test1).astype(np.float32)
    X_test1[pd.isna(X_test1)] = np.nanmedian(X_test1)
    X_test1 = scaler4.transform(X_test1)

    return X_test1

# %% [markdown]
# ## PREDICTIONS

# %%
def generate_predictions(scaler1, scaler2, scaler3, scaler4, model1, X_test1, model2, X_test2, model3, X_test3, model4, X_test4, y_labels_encoder2, y_labels_encoder3, y_labels_encoder4, atc_level1_labels_encoder2, atc_level1_labels_encoder3, atc_level2_labels_encoder3, atc_level1_labels_encoder4, atc_level2_labels_encoder4, atc_level3_labels_encoder4, previous_predictions = None, index = None):
    """Genera predicciones para todos los niveles, o solo para un índice si se repite"""
    
    def sample_prediction(model, X_test, encoder, previous_predictions = None, index = None):
        """Calcula la predicción con probabilidad ponderada para un índice o todos"""
        if previous_predictions is None:
            # Primera vez: calcular todas las predicciones
            y_prob = model.predict(X_test)
            predictions = [
                random.choices(encoder.classes_, weights=row, k=1)[0] for row in y_prob
            ]
        else:
            # Mantener las predicciones anteriores y cambiar solo la del índice dado
            predictions = previous_predictions.copy()
            if index is not None:
                y_prob = model.predict(X_test)
                row = np.array(y_prob)[index]
                predictions[index] = random.choices(encoder.classes_, weights=row, k=1)[0]
    
        return predictions
    
    # Nivel 1
    X_test1 = test_set_level1(scaler1, X_test1)
    pred_1 = sample_prediction(model1, X_test1, mlb, previous_predictions['pred_1'] if previous_predictions is not None else None, index)
    pred_df_level1 = pd.DataFrame(pred_1, columns=['pred_1'])

    # Nivel 2
    X_test2 = test_set_level2(scaler2, X_test2, pred_df_level1, atc_level1_labels_encoder2)
    pred_2 = sample_prediction(model2, X_test2, y_labels_encoder2, previous_predictions['pred_2'] if previous_predictions is not None else None, index)
    pred_df_level2 = pd.DataFrame(pred_2, columns=['pred_2'])

    # Nivel 3
    X_test3 = test_set_level3(scaler3, X_test3, pred_df_level1, pred_df_level2, atc_level1_labels_encoder3, atc_level2_labels_encoder3)
    pred_3 = sample_prediction(model3, X_test3, y_labels_encoder3, previous_predictions['pred_3'] if previous_predictions is not None else None, index)
    pred_df_level3 = pd.DataFrame(pred_3, columns=['pred_3'])

    # Nivel 4
    X_test4 = test_set_level4(scaler4, X_test4, pred_df_level1, pred_df_level2, pred_df_level3, atc_level1_labels_encoder4, atc_level2_labels_encoder4, atc_level3_labels_encoder4)
    pred_4 = sample_prediction(model4, X_test4, y_labels_encoder4, previous_predictions['pred_4'] if previous_predictions is not None else None, index)
    pred_df_level4 = pd.DataFrame(pred_4, columns=['pred_4'])

    return pred_df_level1, pred_df_level2, pred_df_level3, pred_df_level4

# %%
# Predict probabilities
def random_predictions(scaler1, scaler2, scaler3, scaler4, model1, X_test1, model2, X_test2, model3, X_test3, model4, X_test4, y_labels_encoder2, y_labels_encoder3, y_labels_encoder4, atc_level1_labels_encoder2, atc_level1_labels_encoder3, atc_level2_labels_encoder3, atc_level1_labels_encoder4, atc_level2_labels_encoder4, atc_level3_labels_encoder4):
    final_predictions = [[] for _ in range(len(X_test1))]
    max_attempts = 30
    for i in range(3):
        pred_df_level1, pred_df_level2, pred_df_level3, pred_df_level4 = generate_predictions(scaler1, scaler2, scaler3, scaler4, model1, X_test1, model2, X_test2, model3, X_test3, model4, X_test4, y_labels_encoder2, y_labels_encoder3, y_labels_encoder4,  atc_level1_labels_encoder2, atc_level1_labels_encoder3, atc_level2_labels_encoder3, atc_level1_labels_encoder4, atc_level2_labels_encoder4, atc_level3_labels_encoder4)

        for index in range(len(pred_df_level1)):
            attempts = 0
            while attempts < max_attempts:
                pred1 = pred_df_level1.at[index, 'pred_1']
                pred2 = str(pred_df_level2.at[index, "pred_2"]).zfill(2)
                pred3 = pred_df_level3.at[index, "pred_3"]
                pred4 = pred_df_level4.at[index, "pred_4"]
                prediction = pred1 + pred2 + pred3 + pred4

                if prediction not in final_predictions[index]:
                    final_predictions[index].append(prediction)
                    break  # Salimos del bucle cuando obtenemos una predicción nueva

                print(f"Prediction {prediction} already found in {final_predictions[index]}, reclassifying index {index}...")
                previous_predictions = pd.concat([pred_df_level1, pred_df_level2, pred_df_level3, pred_df_level4], axis = 1)
                # Recalcular la clasificación completa solo para este índice
                pred_df_level1, pred_df_level2, pred_df_level3, pred_df_level4 = generate_predictions(scaler1, scaler2, scaler3, scaler4, model1, X_test1, model2, X_test2, model3, X_test3, model4, X_test4, y_labels_encoder2, y_labels_encoder3, y_labels_encoder4, atc_level1_labels_encoder2, atc_level1_labels_encoder3, atc_level2_labels_encoder3, atc_level1_labels_encoder4, atc_level2_labels_encoder4, atc_level3_labels_encoder4, previous_predictions, index)
                attempts += 1
    return final_predictions

# %%
seeds = [42, 123, 47899, 2025, 1, 20, 99, 1020, 345, 78] 
columns = [
    'Seed', 
    'Precision', 'Recall', 'F1',
    'Precision_level3', 'Recall_level3', 'F1_level3',
    'Precision_level2', 'Recall_level2', 'F1_level2',
    'Precision level 1', 'Precision level 2', 'Precision level 3', 'Precision level 4',
    'Recall level 1', 'Recall level 2', 'Recall level 3', 'Recall level 4',
    '#Compounds that have at least one match'
]

metrics_df = pd.DataFrame(columns=columns)

for seed in seeds:
    set_seeds(seed)
    X_train1, y_train1, X_test1, y_test1 = train_test_1(seed)
    X_train2, y_train2, X_test2, y_test2 = train_test_2(seed)
    X_train3, y_train3, X_test3, y_test3 = train_test_3(seed)
    X_train4, y_train4, X_test4, y_test4 = train_test_4(seed)
    # LEVEL1
    # Get all available labels describing the level 1 ATC code
    labels1 = set()
    for lista in y_train1:
        lista = convert_string_list(lista)
        for code in lista:
            labels1.add(code)
    for lista in y_test1:
        lista = convert_string_list(lista)
        for code in lista:
            labels1.add(code)
            
    labels1 = sorted(list(labels1))
    mlb = MultiLabelBinarizer()
    mlb.fit([labels1])
    y_new = y_train1.copy()
    for index, lista in enumerate(y_train1):
        y_new[index] = []
        lista = convert_string_list(lista)
        for i, label in enumerate(lista):
            y_new[index].append(lista[i])
    y_categorical1 = mlb.transform(y_new)
    
    X_train1 = np.asarray(X_train1).astype(np.float32)
    y_categorical1 = np.asarray(y_categorical1).astype(np.float32)
    # Complete NaN values in each column with the median
    X_train1[pd.isna(X_train1)] = np.nanmedian(X_train1)
    # Define an instance of the MinMaxScaler
    scaler1 = MinMaxScaler()
    # Fit the scaler to the data and transform it
    X_train1 = scaler1.fit_transform(X_train1)
    
    model1 = Sequential([
        (Dense(len(labels1), input_dim = X_train1.shape[1], activation = 'sigmoid'))
    ])
    
    # Compile the model
    model1.compile(
        loss = keras.losses.BinaryCrossentropy(),
        optimizer = keras.optimizers.Adam(learning_rate=0.005),
        metrics = ['binary_accuracy', 'binary_crossentropy']
    )
    
    # Define early stopping
    callback = keras.callbacks.EarlyStopping(monitor='val_loss', patience = 5, verbose = 1)
    
    # Train the model
    history = model1.fit(
        X_train1, 
        y_categorical1, 
        epochs = 500, 
        batch_size = 32,
        validation_split = 0.15,
        callbacks = [callback], 
        verbose = 0
    )
    #LEVEL 2
    X_train2, encoded_y_train2, labels2, y_labels_encoder2, atc_level1_labels_encoder2, scaler2 = get_X_train_level2(X_train2, y_train2)
    
    model2 = Sequential([
        (Dense(len(labels2), input_dim = X_train2.shape[1], activation = 'sigmoid'))
    ])
    
    model2.compile(
        loss = keras.losses.BinaryCrossentropy(),
        optimizer = keras.optimizers.Adam(learning_rate=0.005),
        metrics = ['binary_accuracy', 'binary_crossentropy']
    )
    
    callback = keras.callbacks.EarlyStopping(monitor='val_loss', patience = 5, verbose = 1)
    
    history = model2.fit(
        X_train2, 
        encoded_y_train2, 
        epochs = 500, 
        batch_size = 32,
        validation_split = 0.15,
        callbacks = [callback], 
        verbose = 0
    )
    
    #LEVEL 3
    X_train3, encoded_y_train3, labels3, y_labels_encoder3, atc_level1_labels_encoder3, atc_level2_labels_encoder3, scaler3 = get_X_train_level3(X_train3, y_train3)
    
    model3 = Sequential([
        (Dense(len(labels3), input_dim = X_train3.shape[1], activation = 'sigmoid'))
    ])
    
    model3.compile(
        loss = keras.losses.BinaryCrossentropy(), 
        optimizer = keras.optimizers.Adam(learning_rate=0.005),
        metrics = ['binary_accuracy', 'binary_crossentropy']
    )
    
    callback = keras.callbacks.EarlyStopping(monitor='val_loss', patience = 5, verbose = 1)
    
    history = model3.fit(
        X_train3, 
        encoded_y_train3, 
        epochs = 500, 
        batch_size = 32,
        validation_split = 0.15,
        callbacks = [callback], 
        verbose = 0
    )
    
    #LEVEL 4
    X_train4, encoded_y_train4, labels4, y_labels_encoder4, atc_level1_labels_encoder4, atc_level2_labels_encoder4, atc_level3_labels_encoder4, scaler4 = get_X_train_level4(X_train4, y_train4)
    
    model4 = Sequential([
        (Dense(len(labels4), input_dim = X_train4.shape[1], activation = 'sigmoid'))
    ])
    
    model4.compile(
        loss = keras.losses.BinaryCrossentropy(), 
        optimizer = keras.optimizers.Adam(learning_rate=0.005),
        metrics = ['binary_accuracy', 'binary_crossentropy']
    )
    
    callback = keras.callbacks.EarlyStopping(monitor='val_loss', patience = 5, verbose = 1)
    
    history = model4.fit(
        X_train4, 
        encoded_y_train4, 
        epochs = 500, 
        batch_size = 32,
        validation_split = 0.15,
        callbacks = [callback], 
        verbose = 0
    )
    
    #TEST
    X_test3.drop(labels=['ATC_level2'], axis="columns", inplace=True)
    X_test4.drop(labels=['ATC_level3'], axis="columns", inplace = True)

    predictions = random_predictions(scaler1, scaler2, scaler3, scaler4, model1, X_test1, model2, X_test2, model3, X_test3, model4, X_test4, y_labels_encoder2, y_labels_encoder3, y_labels_encoder4, atc_level1_labels_encoder2, atc_level1_labels_encoder3, atc_level2_labels_encoder3, atc_level1_labels_encoder4, atc_level2_labels_encoder4, atc_level3_labels_encoder4)
    predictions_clean = []
    counter4_lessthan3 = 0
    for preds in predictions:
        interm = []
        for pred in preds:
            clean_pred = pred.replace('<START>', '').replace('<END>', '')
            if len(clean_pred) == 5:
                interm.append(clean_pred)
        if len(interm) == 3:
            predictions_clean.append(interm)
        else:
            counter4_lessthan3 += 1
            predictions_clean.append(interm)
    print(f"The model predicted less than 3 ATC codes of level 4 for {counter4_lessthan3} compounds")                 
    predictions_clean_level3 = []
    counter3_lessthan3 = 0
    for preds in predictions:
        interm = []
        for pred in preds:
            clean_pred = pred.replace('<START>', '').replace('<END>', '')
            pred_3 = clean_pred[0:4]
            if len(pred_3) == 4 and pred_3 not in interm:
                interm.append(pred_3)
        if len(interm) == 3:
            predictions_clean_level3.append(interm)
        else:
            counter3_lessthan3 += 1
            predictions_clean_level3.append(interm)
    print(f"The model predicted less than 3 ATC codes of level 3 for {counter3_lessthan3} compounds")       
    predictions_clean_level2 = []
    counter2_lessthan3 = 0
    for preds in predictions:
        interm = []
        for pred in preds:
            clean_pred = pred.replace('<START>', '').replace('<END>', '')
            pred_2 = clean_pred[0:3]
            if len(pred_2) == 3 and pred_2 not in interm:
                interm.append(pred_2)
        if len(interm) == 3:
            predictions_clean_level2.append(interm)
        else:
            counter2_lessthan3 += 1
            predictions_clean_level2.append(interm)
    print(f"The model predicted less than 3 ATC codes of level 2 for {counter2_lessthan3} compounds")       
    precision_1, precision_2, precision_3, precision_4 = defined_metrics.precision(predictions_clean, f'Datasets/test_set{seed}.csv', 'ATC Codes')
    recall_1, recall_2, recall_3, recall_4, counter_compound_match = defined_metrics.recall(predictions_clean, f'Datasets/test_set{seed}.csv', 'ATC Codes')
    precisions, recalls, f1s = defined_metrics.complete_metrics(predictions_clean, f'Datasets/test_set{seed}.csv', 'ATC Codes', 3)
    precisions_level3, recalls_level3, f1s_level3 = defined_metrics.complete_metrics_level3(predictions_clean_level3, f'Datasets/test_set{seed}.csv', 'ATC Codes', 3)
    precisions_level2, recalls_level2, f1s_level2 = defined_metrics.complete_metrics_level2(predictions_clean_level2, f'Datasets/test_set{seed}.csv', 'ATC Codes', 3)
    precisions_average = sum(precisions)/len(precisions)
    recalls_average = sum(recalls)/len(recalls)
    f1s_average = sum(f1s)/len(f1s)

    precisions_average_level3 = sum(precisions_level3)/len(precisions_level3)
    recalls_average_level3 = sum(recalls_level3)/len(recalls_level3)
    f1s_average_level3 = sum(f1s_level3)/len(f1s_level3)

    precisions_average_level2 = sum(precisions_level2)/len(precisions_level2)
    recalls_average_level2 = sum(recalls_level2)/len(recalls_level2)
    f1s_average_level2 = sum(f1s_level2)/len(f1s_level2)
    
    precisions_average_level3 = sum(precisions_level3)/len(precisions_level3)
    recalls_average_level3 = sum(recalls_level3)/len(recalls_level3)
    f1s_average_level3 = sum(f1s_level3)/len(f1s_level3)
        
    metrics = {
        'Precision': precisions_average, 
        'Recall': recalls_average,
        'F1': f1s_average,
        'Precision_level3': precisions_average_level3, 
        'Recall_level3': recalls_average_level3,
        'F1_level3': f1s_average_level3,
        'Precision_level2': precisions_average_level2, 
        'Recall_level2': recalls_average_level2,
        'F1_level2': f1s_average_level2,
        'Precision level 1': precision_1,
        'Precision level 2': precision_2,
        'Precision level 3': precision_3,
        'Precision level 4': precision_4,
        'Recall level 1': recall_1,
        'Recall level 2': recall_2,
        'Recall level 3': recall_3,
        'Recall level 4': recall_4,
        '#Compounds that have at least one match': counter_compound_match
    }
    
    # Build the row
    row = {
        'Seed': seed,
        **metrics
    }
    
    metrics_df = pd.concat([metrics_df, pd.DataFrame([row])], ignore_index=True)

metrics_df.to_csv("neuralnetwork_metrics.csv", index=False)
print("Mean:", metrics_df.mean(numeric_only=True))
print("Std:", metrics_df.std(numeric_only=True))
# Out:
# C:\Users\trini\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 15: early stopping
# C:\Users\trini\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 30: early stopping
# C:\Users\trini\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 26: early stopping
# C:\Users\trini\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 41: early stopping
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 624us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 776us/step
# Prediction A03AB already found in ['A03AB'], reclassifying index 47...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 822us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 726us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 799us/step
# Prediction G04AD already found in ['G04AD'], reclassifying index 133...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 701us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 711us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 645us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 717us/step
# Prediction N05CD already found in ['N05CD'], reclassifying index 144...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 702us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 744us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 815us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# Prediction A03BC already found in ['A03BC'], reclassifying index 147...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 603us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 681us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 697us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# Prediction C03DA already found in ['C03DA'], reclassifying index 260...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 693us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step
# Prediction S01AA already found in ['S01AA'], reclassifying index 320...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 603us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 633us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 638us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 621us/step
# Prediction S01AA already found in ['S01AA'], reclassifying index 320...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 778us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 713us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 736us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 687us/step
# Prediction J05AE already found in ['J05AE'], reclassifying index 331...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 549us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 694us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# Prediction J01DC already found in ['J01DC'], reclassifying index 412...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 711us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 744us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 654us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 675us/step
# Prediction N05BA already found in ['N05BA'], reclassifying index 422...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 950us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 676us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 663us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# Prediction D07AC already found in ['D07AC'], reclassifying index 428...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 744us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 695us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 770us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 745us/step
# Prediction N01AB already found in ['N01AB'], reclassifying index 435...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 648us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 596us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 697us/step
# Prediction J01CA already found in ['J01CA'], reclassifying index 457...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 674us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 674us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 808us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 689us/step
# Prediction N01AB already found in ['N01AB'], reclassifying index 487...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 697us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 641us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 600us/step
# Prediction N01AB already found in ['N01AB'], reclassifying index 487...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 757us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 599us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 752us/step
# Prediction N06BX already found in ['N06BX'], reclassifying index 568...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 714us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 698us/step
# Prediction N05BD already found in ['N05BD'], reclassifying index 573...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 724us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 811us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# Prediction J01CA already found in ['J01CA'], reclassifying index 583...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 714us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 743us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 649us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 747us/step
# Prediction A03BA already found in ['A03BA'], reclassifying index 587...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 698us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 737us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 668us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 743us/step
# Prediction J01ED already found in ['J01ED'], reclassifying index 611...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 698us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 715us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 812us/step
# Prediction J01MA already found in ['J01MA'], reclassifying index 625...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 710us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 596us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 704us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 665us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 767us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 605us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 755us/step
# Prediction N05CA already found in ['N03BA', 'N05CA'], reclassifying index 19...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 675us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 600us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 686us/step
# Prediction A07AA already found in ['J02AA', 'A07AA'], reclassifying index 27...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 687us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 720us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 703us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 841us/step
# Prediction N01AB already found in ['N01AB', 'N02AB'], reclassifying index 51...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 675us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 751us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 697us/step
# Prediction N05BA already found in ['C05CA', 'N05BA'], reclassifying index 56...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 696us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 621us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 744us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 674us/step
# Prediction A03BB already found in ['A03BB', 'C07BB'], reclassifying index 75...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 704us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 702us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 657us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 603us/step
# Prediction N05BA already found in ['N05CD', 'N05BA'], reclassifying index 144...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 777us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 835us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 844us/step
# Prediction N05BA already found in ['N05CD', 'N05BA'], reclassifying index 144...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 669us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 716us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 773us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 695us/step
# Prediction A02BD already found in ['L01EF', 'A02BD'], reclassifying index 237...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 600us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 675us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 661us/step
# Prediction J05AE already found in ['C09AA', 'J05AE'], reclassifying index 244...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 674us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 652us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 760us/step
# Prediction A03AB already found in ['M03AB', 'A03AB'], reclassifying index 326...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 701us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 777us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 803us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 675us/step
# Prediction A03AB already found in ['M03AB', 'A03AB'], reclassifying index 326...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 747us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 701us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# Prediction J05AF already found in ['J05AF', 'J01AF'], reclassifying index 391...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 690us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 879us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 703us/step
# Prediction R03AC already found in ['N06CX', 'R03AC'], reclassifying index 400...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 802us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 712us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 801us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Prediction J01DD already found in ['J01DC', 'J01DD'], reclassifying index 412...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 801us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 647us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 784us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 769us/step
# Prediction J01DC already found in ['J01DC', 'J01DD'], reclassifying index 412...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 702us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 743us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 887us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 749us/step
# Prediction J01DD already found in ['J01DC', 'J01DD'], reclassifying index 412...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 598us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 615us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 772us/step
# Prediction J01DC already found in ['J01DC', 'J01DD'], reclassifying index 412...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 669us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 779us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 804us/step
# Prediction A03BB already found in ['A03AB', 'A03BB'], reclassifying index 418...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 742us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 760us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 696us/step
# Prediction J01CA already found in ['J01CA', 'J01CF'], reclassifying index 457...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 600us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 698us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# Prediction M02AB already found in ['M02AB', 'M01AE'], reclassifying index 468...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 693us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 786us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 651us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 755us/step
# Prediction R01AC already found in ['R01AC', 'S01AA'], reclassifying index 485...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 674us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 780us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 900us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 769us/step
# Prediction G01BD already found in ['G01BD', 'A03BC'], reclassifying index 492...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 738us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 787us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 647us/step
# Prediction A16AA already found in ['J04AA', 'A16AA'], reclassifying index 509...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 727us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 654us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 771us/step
# Prediction J01CA already found in ['J01CA', 'A10BB'], reclassifying index 583...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 789us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 709us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# Prediction C02CC already found in ['C02CD', 'C02CC'], reclassifying index 584...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 648us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 733us/step
# Prediction C02CC already found in ['C02CD', 'C02CC'], reclassifying index 584...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 680us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 653us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 784us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 698us/step
# Prediction R06AX already found in ['R06AX', 'C03AX'], reclassifying index 593...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 620us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 727us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 797us/step
# Prediction M01AB already found in ['G01AD', 'M01AB'], reclassifying index 630...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 719us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 680us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 947us/step
# The model predicted less than 3 ATC codes of level 4 for 0 compounds
# The model predicted less than 3 ATC codes of level 3 for 49 compounds
# The model predicted less than 3 ATC codes of level 2 for 128 compounds
# C:\Users\trini\AppData\Local\Temp\ipykernel_30492\1969361349.py:248: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   metrics_df = pd.concat([metrics_df, pd.DataFrame([row])], ignore_index=True)
# C:\Users\trini\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 50: early stopping
# C:\Users\trini\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 29: early stopping
# C:\Users\trini\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 21: early stopping
# C:\Users\trini\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 21: early stopping
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 721us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 600us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 600us/step
# Prediction J01AE already found in ['J01AE'], reclassifying index 59...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 674us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 773us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step
# Prediction J01DI already found in ['J01DI'], reclassifying index 112...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 665us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 799us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# Prediction C08AA already found in ['C08AA'], reclassifying index 133...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 763us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 651us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 600us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# Prediction J05AB already found in ['J05AB'], reclassifying index 272...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 745us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 801us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 669us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 731us/step
# Prediction D07AB already found in ['D07AB'], reclassifying index 277...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 756us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 611us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 600us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 724us/step
# Prediction J01DI already found in ['J01DI'], reclassifying index 315...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 731us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 756us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 811us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# Prediction D04AD already found in ['D04AD'], reclassifying index 319...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 738us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 550us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 713us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 604us/step
# Prediction N05BA already found in ['N05BA'], reclassifying index 462...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 759us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 785us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 730us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 900us/step
# Prediction N05BA already found in ['N05BA'], reclassifying index 462...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 721us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 677us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 550us/step
# Prediction J01DX already found in ['J01DX'], reclassifying index 539...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 703us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 600us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 618us/step
# Prediction N05AB already found in ['N05AB'], reclassifying index 596...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 723us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 713us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 703us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 771us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 617us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 723us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 782us/step
# Prediction A11AX already found in ['A11AX', 'J01AF'], reclassifying index 19...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 653us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 696us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step
# Prediction N06AA already found in ['N04BX', 'N06AA'], reclassifying index 43...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 864us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 647us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 740us/step
# Prediction C01EB already found in ['C01EB', 'L01BB'], reclassifying index 54...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 950us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 696us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# Prediction J01AA already found in ['J01AA', 'J01AX'], reclassifying index 58...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 797us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 599us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 652us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 659us/step
# Prediction J01AA already found in ['J01AA', 'J01AX'], reclassifying index 58...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# Prediction J01DB already found in ['L01ED', 'J01DB'], reclassifying index 64...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 701us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 742us/step
# Prediction J01DD already found in ['L01DD', 'J01DD'], reclassifying index 74...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 647us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 601us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 762us/step
# Prediction J01AP already found in ['J01AP', 'J05AP'], reclassifying index 80...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 640us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 698us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 755us/step
# Prediction G03CC already found in ['G03AA', 'G03CC'], reclassifying index 89...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 721us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 725us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# Prediction L02EA already found in ['L02EA', 'L01EX'], reclassifying index 140...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 600us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 729us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 735us/step
# Prediction A08AJ already found in ['A08AJ', 'D08AA'], reclassifying index 156...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 746us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 684us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 735us/step
# Prediction C08CA already found in ['C08CA', 'C08AA'], reclassifying index 181...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 718us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 695us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 802us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 619us/step
# Prediction J01AB already found in ['J01AB', 'J05AD'], reclassifying index 201...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 628us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 801us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 691us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 892us/step
# Prediction R06AX already found in ['R06AX', 'A10BB'], reclassifying index 222...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 600us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 751us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 806us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 690us/step
# Prediction L01EX already found in ['L01EB', 'L01EX'], reclassifying index 245...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 877us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 745us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 757us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# Prediction D07AB already found in ['D01AC', 'D07AB'], reclassifying index 253...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 745us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 812us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 935us/step
# Prediction H01BB already found in ['H01BB', 'A01DA'], reclassifying index 314...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 849us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 832us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step
# Prediction J01DI already found in ['J01DI', 'S01AI'], reclassifying index 315...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 799us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 798us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 900us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step
# Prediction J01RA already found in ['J01RA', 'J01DD'], reclassifying index 416...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 867us/step
# Prediction J01AD already found in ['J01DC', 'J01AD'], reclassifying index 424...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 820us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 762us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 807us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# Prediction R06AB already found in ['R06AB', 'R01AE'], reclassifying index 456...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 737us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 701us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 864us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 950us/step
# Prediction J01DI already found in ['J01DD', 'J01DI'], reclassifying index 492...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 661us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 773us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 774us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 666us/step
# Prediction J05AP already found in ['J05AP', 'L01AD'], reclassifying index 498...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 741us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 687us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 721us/step
# Prediction J05AP already found in ['J05AP', 'L01AD'], reclassifying index 498...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 720us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 680us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step
# Prediction J04AA already found in ['J04AA', 'C08FA'], reclassifying index 538...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 669us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 708us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 725us/step
# Prediction S01EB already found in ['G01BE', 'S01EB'], reclassifying index 546...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 753us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 723us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 784us/step
# Prediction N05AB already found in ['N05AB', 'J01XJ'], reclassifying index 582...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 728us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 730us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 762us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 678us/step
# Prediction N05AB already found in ['N05AB', 'J01XJ'], reclassifying index 582...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 637us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 793us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 811us/step
# Prediction D11AX already found in ['C08AA', 'D11AX'], reclassifying index 587...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 751us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 799us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 755us/step
# Prediction R06AX already found in ['N04AJ', 'R06AX'], reclassifying index 600...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 794us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 694us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 900us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# The model predicted less than 3 ATC codes of level 4 for 0 compounds
# The model predicted less than 3 ATC codes of level 3 for 80 compounds
# The model predicted less than 3 ATC codes of level 2 for 180 compounds
# C:\Users\trini\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 34: early stopping
# C:\Users\trini\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 24: early stopping
# C:\Users\trini\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 18: early stopping
# C:\Users\trini\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 22: early stopping
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 716us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 772us/step
# Prediction J01DC already found in ['J01DC'], reclassifying index 40...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 718us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 630us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 699us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 722us/step
# Prediction J01DC already found in ['J01DC'], reclassifying index 40...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 651us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 759us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 823us/step
# Prediction N05BA already found in ['N05BA'], reclassifying index 59...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 596us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 695us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 720us/step
# Prediction N01AC already found in ['N01AC'], reclassifying index 155...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 740us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 757us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 721us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 806us/step
# Prediction N05BA already found in ['N05BA'], reclassifying index 185...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 738us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 674us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 584us/step
# Prediction N05BA already found in ['N05BA'], reclassifying index 185...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 647us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 702us/step
# Prediction N05BA already found in ['N05BA'], reclassifying index 185...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 763us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 600us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 677us/step
# Prediction J01DC already found in ['J01DC'], reclassifying index 188...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 695us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 754us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 702us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 782us/step
# Prediction J01DC already found in ['J01DC'], reclassifying index 188...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 600us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 759us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 811us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Prediction L01XX already found in ['L01XX'], reclassifying index 258...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 752us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 693us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 734us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 735us/step
# Prediction J01CA already found in ['J01CA'], reclassifying index 377...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 767us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 648us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 746us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 603us/step
# Prediction P03AC already found in ['P03AC'], reclassifying index 454...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 704us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 691us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 743us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 702us/step
# Prediction C01DA already found in ['C01DA'], reclassifying index 483...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 673us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 747us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 720us/step
# Prediction J02AC already found in ['J02AC'], reclassifying index 492...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 730us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 795us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 671us/step
# Prediction J01DC already found in ['J01DC'], reclassifying index 502...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 711us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 736us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 704us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# Prediction L01XX already found in ['L01XX'], reclassifying index 576...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 729us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 771us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 803us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 701us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 792us/step
# Prediction J05FA already found in ['C07AC', 'J05FA'], reclassifying index 27...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 697us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# Prediction J01DC already found in ['J01DC', 'J01DB'], reclassifying index 37...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 791us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 600us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 600us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 659us/step
# Prediction J01DB already found in ['J01DC', 'J01DB'], reclassifying index 37...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 746us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 753us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 690us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 712us/step
# Prediction J01DC already found in ['J01DA', 'J01DC'], reclassifying index 72...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 742us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 672us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 631us/step
# Prediction M01AB already found in ['A07AA', 'M01AB'], reclassifying index 97...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 749us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Prediction N01AB already found in ['N01AC', 'N01AB'], reclassifying index 155...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 631us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 687us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 663us/step
# Prediction N01AB already found in ['N01AC', 'N01AB'], reclassifying index 155...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 707us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 688us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 670us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 737us/step
# Prediction M01AB already found in ['M01AB', 'A03DB'], reclassifying index 168...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 732us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 827us/step
# Prediction J01DC already found in ['J01BC', 'J01DC'], reclassifying index 176...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 701us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 698us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 710us/step
# Prediction J01DC already found in ['J01BC', 'J01DC'], reclassifying index 176...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 775us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 788us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 600us/step
# Prediction J01DC already found in ['J01BC', 'J01DC'], reclassifying index 176...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 631us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 693us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 740us/step
# Prediction J01DC already found in ['J01BC', 'J01DC'], reclassifying index 176...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 725us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 698us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 757us/step
# Prediction D07AC already found in ['A07BC', 'D07AC'], reclassifying index 268...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 662us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 717us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 900us/step
# Prediction H02AB already found in ['H02AB', 'H02AA'], reclassifying index 293...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 701us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 756us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 697us/step
# Prediction G01AC already found in ['D07AB', 'G01AC'], reclassifying index 305...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 647us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 687us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 747us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# Prediction M01AC already found in ['M01AC', 'M01BB'], reclassifying index 362...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 646us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 777us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 642us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 612us/step
# Prediction J01CA already found in ['J01CA', 'A01CA'], reclassifying index 377...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 687us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# Prediction P01AC already found in ['G01AF', 'P01AC'], reclassifying index 395...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 648us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 754us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 738us/step
# Prediction N05AX already found in ['C02AX', 'N05AX'], reclassifying index 402...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 718us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 664us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# Prediction J01DC already found in ['J07AC', 'J01DC'], reclassifying index 404...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 730us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 633us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 744us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# Prediction J01DC already found in ['J01DC', 'J01DB'], reclassifying index 502...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 785us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 653us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 697us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 727us/step
# Prediction J01DC already found in ['J01DC', 'J01DB'], reclassifying index 510...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 600us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 950us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 603us/step
# Prediction A07BA already found in ['G01AE', 'A07BA'], reclassifying index 596...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 732us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 746us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 649us/step
# Prediction J01CR already found in ['G01CD', 'J01CR'], reclassifying index 601...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 599us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 775us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 801us/step
# Prediction A07DX already found in ['C02LG', 'A07DX'], reclassifying index 615...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 710us/step
# Prediction J01DC already found in ['J01CB', 'J01DC'], reclassifying index 637...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 753us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 697us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 753us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 780us/step
# The model predicted less than 3 ATC codes of level 4 for 0 compounds
# The model predicted less than 3 ATC codes of level 3 for 62 compounds
# The model predicted less than 3 ATC codes of level 2 for 171 compounds
# C:\Users\trini\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 24: early stopping
# C:\Users\trini\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 28: early stopping
# C:\Users\trini\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 22: early stopping
# C:\Users\trini\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 20: early stopping
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 765us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 784us/step
# Prediction L01CC already found in ['L01CC'], reclassifying index 15...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 600us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 657us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 663us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 742us/step
# Prediction C08CA already found in ['C08CA'], reclassifying index 39...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 697us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 809us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 701us/step
# Prediction N05AB already found in ['N05AB'], reclassifying index 208...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 732us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 757us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# Prediction N06AX already found in ['N06AX'], reclassifying index 238...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 792us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 600us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 755us/step
# Prediction J05AE already found in ['J05AE'], reclassifying index 326...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 787us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 554us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 736us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 787us/step
# Prediction N05AB already found in ['N05AB'], reclassifying index 419...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 690us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 698us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 643us/step
# Prediction A11AA already found in ['A11AA'], reclassifying index 426...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 701us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 647us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 703us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 688us/step
# Prediction C09CB already found in ['C09CB'], reclassifying index 491...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 770us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 701us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 801us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 785us/step
# Prediction L01AB already found in ['L01AB'], reclassifying index 500...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 667us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 647us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# Prediction L01CA already found in ['L01CA'], reclassifying index 510...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 600us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 827us/step
# Prediction L01CA already found in ['L01CA'], reclassifying index 510...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 717us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 776us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 711us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 599us/step
# Prediction J05AE already found in ['J05AE'], reclassifying index 555...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 661us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 752us/step
# Prediction J01CR already found in ['J01CR'], reclassifying index 588...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 721us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 701us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 651us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Prediction J01CR already found in ['J01CR'], reclassifying index 603...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 699us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 788us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 665us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 801us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 935us/step
# Prediction M05AA already found in ['A06AX', 'M05AA'], reclassifying index 10...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 746us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 603us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# Prediction L01CC already found in ['L01CC', 'L01CA'], reclassifying index 15...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 669us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 753us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 993us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 724us/step
# Prediction L01CA already found in ['L01CC', 'L01CA'], reclassifying index 15...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 699us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 696us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 746us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# Prediction L01CC already found in ['L01CC', 'L01CA'], reclassifying index 15...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 600us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 755us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# Prediction L01CA already found in ['L01CC', 'L01CA'], reclassifying index 15...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 697us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 646us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 694us/step
# Prediction J01AD already found in ['J01AD', 'J01AX'], reclassifying index 30...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 661us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 715us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 795us/step
# Prediction C01DB already found in ['C05CA', 'C01DB'], reclassifying index 103...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 768us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 712us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 636us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 745us/step
# Prediction J05DB already found in ['J01AC', 'J05DB'], reclassifying index 104...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 600us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 712us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 803us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 797us/step
# Prediction R03DA already found in ['R06DX', 'R03DA'], reclassifying index 118...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 823us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 856us/step
# Prediction R03AB already found in ['C05CA', 'R03AB'], reclassifying index 137...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 950us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 725us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 754us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 778us/step
# Prediction J01AD already found in ['J01AD', 'J01AC'], reclassifying index 150...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 788us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 599us/step
# Prediction J01MA already found in ['J01MA', 'L01AB'], reclassifying index 263...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 712us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 702us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 792us/step
# Prediction M01AA already found in ['M01AA', 'M05BC'], reclassifying index 266...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 710us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 685us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 849us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# Prediction J01DB already found in ['J05CA', 'J01DB'], reclassifying index 289...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 698us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 600us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 698us/step
# Prediction J01DB already found in ['J05CA', 'J01DB'], reclassifying index 289...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 694us/step
# ...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 743us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 719us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step
# Prediction L01AX already found in ['L01AX', 'R03AA'], reclassifying index 620...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 679us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 702us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 789us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 753us/step
# Prediction J01CA already found in ['J01CR', 'J01CA'], reclassifying index 631...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 746us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 751us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 751us/step
# Prediction D09AA already found in ['D09AA', 'N02CA'], reclassifying index 632...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 749us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 717us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# Prediction J01EB already found in ['J05AP', 'J01EB'], reclassifying index 639...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 747us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 707us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 704us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# The model predicted less than 3 ATC codes of level 4 for 0 compounds
# The model predicted less than 3 ATC codes of level 3 for 94 compounds
# The model predicted less than 3 ATC codes of level 2 for 176 compounds
# C:\Users\trini\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 51: early stopping
# C:\Users\trini\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 28: early stopping
# C:\Users\trini\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 32: early stopping
# C:\Users\trini\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 22: early stopping
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 676us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 781us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 792us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 697us/step
# Prediction L01XX already found in ['L01XX'], reclassifying index 8...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 701us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 600us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 611us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 765us/step
# Prediction B05AB already found in ['B05AB'], reclassifying index 13...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 702us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 725us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 790us/step
# Prediction J01DD already found in ['J01DD'], reclassifying index 59...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 763us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 770us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 600us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 859us/step
# Prediction A03FB already found in ['A03FB'], reclassifying index 78...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 695us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 704us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 663us/step
# Prediction S01GA already found in ['S01GA'], reclassifying index 140...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 753us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 749us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 732us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 646us/step
# Prediction J05AB already found in ['J05AB'], reclassifying index 173...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 772us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 713us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 801us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 656us/step
# Prediction J01DD already found in ['J01DD'], reclassifying index 230...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 664us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 596us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 704us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 847us/step
# Prediction J01DD already found in ['J01DD'], reclassifying index 234...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 742us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 793us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 655us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# Prediction J01DD already found in ['J01DD'], reclassifying index 234...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 694us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 747us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 751us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 746us/step
# Prediction N05AX already found in ['N05AX'], reclassifying index 258...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 737us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 695us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 875us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 704us/step
# Prediction J01DB already found in ['J01DB'], reclassifying index 376...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 732us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 770us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 789us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 813us/step
# Prediction J01DC already found in ['J01DC'], reclassifying index 416...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 752us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 699us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 801us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 929us/step
# Prediction J01DC already found in ['J01DC'], reclassifying index 416...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 697us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 696us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 687us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 701us/step
# Prediction G01AA already found in ['G01AA'], reclassifying index 459...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 741us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 775us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 804us/step
# Prediction J01DD already found in ['J01DD'], reclassifying index 483...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 796us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 731us/step
# Prediction J01DD already found in ['J01DD'], reclassifying index 483...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 752us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 746us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 741us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 840us/step
# Prediction G04AA already found in ['G04AA'], reclassifying index 487...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 624us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 699us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 749us/step
# Prediction M02AA already found in ['M02AA'], reclassifying index 514...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 852us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 697us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 665us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 673us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 784us/step
# Prediction N05AX already found in ['L01XX', 'N05AX'], reclassifying index 8...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 713us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 665us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 744us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 820us/step
# Prediction L01EM already found in ['L01EM', 'L01EG'], reclassifying index 27...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 842us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 900us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 725us/step
# Prediction J01DC already found in ['J01DC', 'J01DB'], reclassifying index 48...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 758us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 900us/step
# Prediction N06AX already found in ['N06AX', 'G01AE'], reclassifying index 54...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 816us/step
# Prediction C04BA already found in ['C04BA', 'N04AM'], reclassifying index 55...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 751us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 749us/step
# Prediction N05BX already found in ['N05BX', 'N05BG'], reclassifying index 128...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 900us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 871us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 744us/step
# Prediction R06AX already found in ['R01AB', 'R06AX'], reclassifying index 161...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 751us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 726us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 644us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step
# Prediction N05BD already found in ['N05AD', 'N05BD'], reclassifying index 169...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 767us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 701us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# Prediction J01AD already found in ['J01AD', 'L01DD'], reclassifying index 187...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 714us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# Prediction J01AD already found in ['J01AD', 'L01DD'], reclassifying index 187...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 686us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 797us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 698us/step
# Prediction G01AC already found in ['G01AD', 'G01AC'], reclassifying index 229...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 755us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 685us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step
# Prediction J01DC already found in ['J01DD', 'J01DC'], reclassifying index 230...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 698us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 604us/step
# Prediction N05BA already found in ['N05BA', 'N01BA'], reclassifying index 321...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 770us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 762us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 738us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 797us/step
# Prediction N06AX already found in ['N06AX', 'N06AD'], reclassifying index 338...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 671us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 649us/step
# Prediction N06AX already found in ['N06AX', 'N06AD'], reclassifying index 338...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 799us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 791us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 900us/step
# Prediction S01FA already found in ['S01FA', 'S01AA'], reclassifying index 354...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 782us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 816us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 701us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# Prediction N05AD already found in ['N02AX', 'N05AD'], reclassifying index 356...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 786us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 646us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# Prediction R06AD already found in ['N06AA', 'R06AD'], reclassifying index 361...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 749us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 772us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 788us/step
# Prediction A03CA already found in ['A03CA', 'N05BA'], reclassifying index 434...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 774us/step
# Prediction N06BA already found in ['N06BA', 'N01XA'], reclassifying index 461...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 787us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 760us/step
# Prediction J01CR already found in ['J01CR', 'J01AR'], reclassifying index 464...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 600us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# Prediction J01DD already found in ['J01DD', 'J01CD'], reclassifying index 469...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 724us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 758us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 900us/step
# Prediction H03AB already found in ['G03AA', 'H03AB'], reclassifying index 496...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 709us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 849us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 730us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# Prediction A03AB already found in ['A03AB', 'D11AB'], reclassifying index 507...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 648us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 796us/step
# Prediction N06AX already found in ['N06AX', 'N07XX'], reclassifying index 522...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 809us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 804us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 759us/step
# Prediction B06AD already found in ['C06KD', 'B06AD'], reclassifying index 573...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 747us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 654us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# Prediction S01AB already found in ['C07AB', 'S01AB'], reclassifying index 607...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 775us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 747us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# Prediction R06AX already found in ['C01GX', 'R06AX'], reclassifying index 620...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 650us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step
# Prediction R06AX already found in ['C01GX', 'R06AX'], reclassifying index 620...
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 654us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 697us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 743us/step
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 900us/step
# The model predicted less than 3 ATC codes of level 4 for 0 compounds
# The model predicted less than 3 ATC codes of level 3 for 68 compounds
# The model predicted less than 3 ATC codes of level 2 for 159 compounds
# Mean: Precision            0.026687
# Recall               0.061691
# F1                   0.035511
# Precision_level3     0.075961
# Recall_level3        0.161146
# F1_level3            0.098314
# Precision_level2     0.142394
# Recall_level2        0.276960
# F1_level2            0.178365
# Precision level 1    0.307477
# Precision level 2    0.457877
# Precision level 3    0.518331
# Precision level 4    0.348937
# Recall level 1       0.520236
# Recall level 2       0.532818
# Recall level 3       0.574722
# Recall level 4       0.384843
# dtype: float64
# Std: Precision            0.002760
# Recall               0.006049
# F1                   0.003546
# Precision_level3     0.006668
# Recall_level3        0.013393
# F1_level3            0.008475
# Precision_level2     0.011304
# Recall_level2        0.017349
# F1_level2            0.012136
# Precision level 1    0.019745
# Precision level 2    0.023909
# Precision level 3    0.025970
# Precision level 4    0.058531
# Recall level 1       0.029033
# Recall level 2       0.022535
# Recall level 3       0.026272
# Recall level 4       0.047824
# dtype: float64
